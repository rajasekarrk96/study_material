# %% [markdown]
# # Full Notes: Introduction to Equations
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Solve one-step and two-step equations.
# - Verify solutions by substitution.

# %% [markdown]
# ## Professional Context
# Essential algebra used in data science feature engineering and formula derivation.

# %% [markdown]
# ## Key Concepts
# - Understand variable isolation
# - Balance both sides of equations

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
# Example: one-step equation
x = 9 - 4
print('x =', x)

# Example: two-step equation
x = (10 + 2) / 3
print('x =', x)

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import pandas as pd
df = pd.DataFrame({'x': range(-5, 6)})
df['y'] = 2 * df['x'] + 1
df.head()

# %% [markdown]
# ## Tasks
# - Solve 3 single-variable equations and verify results with Python.
# - Plot the starter dataset and annotate the slope and intercept.
# - Explain why substitution is a good validation step.

# %% [markdown]
# ## Expected Deliverables
# - Code cells with solved equations
# - Plot of the linear relation
# - Short markdown explanation
