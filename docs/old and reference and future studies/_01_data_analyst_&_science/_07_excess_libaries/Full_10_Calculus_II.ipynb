# %% [markdown]
# # Full Notes: Calculus II
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Compute integrals and partial derivatives.
# - Interpret gradients in ML.

# %% [markdown]
# ## Professional Context
# Integrals and partials are used in loss functions and optimization algorithms.

# %% [markdown]
# ## Key Concepts
# - Use sympy for calculus
# - Visualize integrals

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import sympy as sp
x = sp.symbols('x')
print('integral =', sp.integrate(x**2,(x,0,3)))

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import sympy as sp
x,y = sp.symbols('x y')
g = x**2*y + sp.sin(y)
print('dg/dx =', sp.diff(g, x))
print('dg/dy =', sp.diff(g, y))

# %% [markdown]
# ## Tasks
# - Compute a definite integral.
# - Derive partial derivatives of a two-variable function.
# - Explain the gradient in a simple optimization context.

# %% [markdown]
# ## Expected Deliverables
# - Integral calculation
# - Partial derivatives
# - Optimization note
