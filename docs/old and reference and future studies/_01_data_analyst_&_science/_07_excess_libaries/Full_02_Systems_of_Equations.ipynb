# %% [markdown]
# # Full Notes: Systems of Equations
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Represent systems as linear equations.
# - Solve using elimination and matrix methods.

# %% [markdown]
# ## Professional Context
# Data scientists use systems for calibration, resource allocation, and model constraints.

# %% [markdown]
# ## Key Concepts
# - Write equations in matrix form
# - Use NumPy for linear solvers

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import numpy as np
A = np.array([[2, 1], [1, -1]])
b = np.array([10, 2])
solution = np.linalg.solve(A, b)
print('solution =', solution)

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import numpy as np
import numpy as np
A = np.array([[2,1],[1,-1]])
print('A=', A)
print('b=', b)

# %% [markdown]
# ## Tasks
# - Solve the system manually and with NumPy.
# - Write a solver function that handles singular matrices.
# - Describe no-solution and infinite-solution cases.

# %% [markdown]
# ## Expected Deliverables
# - Solver function code
# - Worked examples
# - Edge-case explanation
