# %% [markdown]
# # Full Notes: Linear Combination
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Compute linear combinations.
# - Understand span and independence.

# %% [markdown]
# ## Professional Context
# Linear combinations are the basis of feature construction and PCA.

# %% [markdown]
# ## Key Concepts
# - Generate spans
# - Check rank of vector sets

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import numpy as np
v1 = np.array([1,0])
v2 = np.array([0,1])
comb = 3*v1 + (-2)*v2
print('comb =', comb)

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import numpy as np
v1 = np.array([1,0])
v2 = np.array([0,1])
print('v1=',v1)
print('v2=',v2)

# %% [markdown]
# ## Tasks
# - Express a target vector as a linear combination if possible.
# - Check whether two vectors are independent.
# - Relate the concept to PCA component construction.

# %% [markdown]
# ## Expected Deliverables
# - Combination examples
# - Independence check
# - PCA connection note
