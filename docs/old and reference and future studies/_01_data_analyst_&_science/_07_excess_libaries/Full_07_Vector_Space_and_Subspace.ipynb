# %% [markdown]
# # Full Notes: Vector Space and Subspace
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Understand vector space axioms.
# - Test subspace closure and independence.

# %% [markdown]
# ## Professional Context
# Subspaces appear in PCA, null spaces, and feature selection.

# %% [markdown]
# ## Key Concepts
# - Check closure properties
# - Relate rank to independence

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import numpy as np
u = np.array([1,2])
v = np.array([2,4])
rank = np.linalg.matrix_rank(np.column_stack((u,v)))
print('rank =', rank)

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import numpy as np
u = np.array([1,2])
v = np.array([2,4])
print('u=',u)
print('v=',v)

# %% [markdown]
# ## Tasks
# - Show `u` and `v` are linearly dependent.
# - Explain why they do not form a basis of R2.
# - Describe a subspace example relevant to ML features.

# %% [markdown]
# ## Expected Deliverables
# - Rank test code
# - Basis explanation
# - ML subspace note
