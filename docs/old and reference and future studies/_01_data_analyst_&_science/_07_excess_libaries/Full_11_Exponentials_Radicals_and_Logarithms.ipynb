# %% [markdown]
# # Full Notes: Exponentials, Radicals and Logarithms
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Apply exponent and log rules.
# - Use logs for data transformation.

# %% [markdown]
# ## Professional Context
# Logs are used in normalization, scaling, and transforming skewed data.

# %% [markdown]
# ## Key Concepts
# - Solve exponent equations
# - Apply logarithmic transforms

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import math
print('2**5 =', 2**5)
print('sqrt(16) =', math.sqrt(16))
print('log10(100) =', math.log10(100))

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import numpy as np
vals = np.array([1,10,100,1000])
transformed = np.log10(vals)
print('values=', vals)
print('log10=', transformed)

# %% [markdown]
# ## Tasks
# - Solve exponential equations using logs.
# - Transform skewed positive data with log scale.
# - Explain why logs are useful in model building.

# %% [markdown]
# ## Expected Deliverables
# - Solved examples
# - Log-transformed data output
# - Practical use summary
