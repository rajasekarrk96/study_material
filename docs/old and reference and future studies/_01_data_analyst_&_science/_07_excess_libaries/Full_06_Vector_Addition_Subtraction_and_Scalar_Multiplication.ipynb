# %% [markdown]
# # Full Notes: Vector Addition, Subtraction, and Scalar Multiplication
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Perform vector arithmetic.
# - Interpret geometric effects of scaling.

# %% [markdown]
# ## Professional Context
# Vectors are the mathematical language of features, embeddings, and spatial data.

# %% [markdown]
# ## Key Concepts
# - Add and scale vectors
# - Plot vector arrows

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import numpy as np
v = np.array([2,3])
w = np.array([1,-1])
print('v+w =', v+w)
print('v-w =', v-w)
print('3*v =', 3*v)

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import numpy as np
v = np.array([2,3])
w = np.array([1,-1])
print('v=',v)
print('w=',w)

# %% [markdown]
# ## Tasks
# - Compute addition, subtraction, and scalar multiplication.
# - Create a plot showing vector translation.
# - Explain how scalar sign changes direction.

# %% [markdown]
# ## Expected Deliverables
# - Arithmetic code
# - Vector plot
# - Geometric explanation
