# %% [markdown]
# # Full Notes: Linear Equation Systems
# This notebook delivers clear professional notes for data science learning, from basics to applied tasks.

# %% [markdown]
# ## Learning Objectives
# - Solve 3x3 linear systems.
# - Understand determinant and uniqueness.

# %% [markdown]
# ## Professional Context
# Large systems appear in linear regression normal equations and network flows.

# %% [markdown]
# ## Key Concepts
# - Use matrix determinants
# - Understand solution uniqueness

# %% [markdown]
# ## Starter Code Examples
# Run these examples to see the core ideas in action.

# %%
import numpy as np
A = np.array([[2,3,-1],[1,-1,2],[3,1,1]])
b = np.array([5,4,6])
print('det(A)=', np.linalg.det(A))
print('solution=', np.linalg.solve(A,b))

# %% [markdown]
# ## Starter Data
# Generate or inspect a small dataset relevant to the topic.

# %%
import numpy as np
import numpy as np
A = np.array([[2,3,-1],[1,-1,2],[3,1,1]])
print('A=', A)
print('b=', b)

# %% [markdown]
# ## Tasks
# - Implement educational Gaussian elimination.
# - Generate random solvable systems and verify solutions.
# - Discuss why singular matrices break unique solutions.

# %% [markdown]
# ## Expected Deliverables
# - Gaussian elimination code
# - Random system test results
# - Short analytical note
