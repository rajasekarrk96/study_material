# %% [markdown]
# # Basic libraries

# %%
# importing libraries
import pandas as pd
import scipy
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Other Libraries

# %% [markdown]
# # Importing data from source

# %%
data=pd.read_csv("C:/Users/Rajasekar/OneDrive/_12_DATA_ANALYST/_99_data sets/owid-covid-data.csv")

# %% [markdown]
# # View data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377007 entries, 0 to 377006
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   iso_code                            377007 non-null  object
#  1   continent                           358941 non-null  object
#  2   location                            377007 non-null  object
#  3   date                                377007 non-null  object
#  4   population_density                  320354 non-null  float64
#  5   total_cases                         338085 non-null  float64
#  6   new_cases                           366116 non-null  float64
#  7   new_cases_smoothed                  364886 non-null  float64
#  8   total_deaths                        316113 non-null  float64
#  9   new_deaths                          366124 non-null  float64
#  10  new_deaths_smoothed                 364894 non-null  float64
# ...

# %% [markdown]
# # Making with buffer will not give error

# %%
from io import StringIO

# Create a StringIO buffer to capture the printed output
buffer = StringIO()

# Redirect the output to the buffer
data.info(buf=buffer)

# Get the value from the buffer
data_info_string = buffer.getvalue()

# Print or manipulate the string as needed
print(data_info_string)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377007 entries, 0 to 377006
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   iso_code                            377007 non-null  object
#  1   continent                           358941 non-null  object
#  2   location                            377007 non-null  object
#  3   date                                377007 non-null  object
#  4   population_density                  320354 non-null  float64
#  5   total_cases                         338085 non-null  float64
#  6   new_cases                           366116 non-null  float64
#  7   new_cases_smoothed                  364886 non-null  float64
#  8   total_deaths                        316113 non-null  float64
#  9   new_deaths                          366124 non-null  float64
#  10  new_deaths_smoothed                 364894 non-null  float64
# ...

# %% [markdown]
# # View All Collumns

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population_density',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning:<!--topic-->

# %% [markdown]
# # Handling missing data:<!--subtopic-->

# %% [markdown]
# # Count total number of rows

# %%
total_rows = len(data)
print("Total number of rows:", total_rows)
# Out:
# Total number of rows: 377007

# %%
data.isnull().sum()
# Out:
# iso_code                                   0
# continent                              18066
# location                                   0
# date                                       0
# population_density                     56653
# total_cases                            38922
# new_cases                              10891
# new_cases_smoothed                     12121
# total_deaths                           60894
# new_deaths                             10883
# new_deaths_smoothed                    12113
# total_cases_per_million                38922
# new_cases_per_million                  10891
# new_cases_smoothed_per_million         12121
# total_deaths_per_million               60894
# new_deaths_per_million                 10883
# new_deaths_smoothed_per_million        12113
# reproduction_rate                     192190
# icu_patients                          338574
# icu_patients_per_million              338574
# hosp_patients                         337075
# ...

# %% [markdown]
# # Count not null values

# %%
data.count()
# Out:
# iso_code                              377007
# continent                             377007
# location                              377007
# date                                  377007
# population_density                    320354
# total_cases                           338085
# new_cases                             366116
# new_cases_smoothed                    364886
# total_deaths                          316113
# new_deaths                            366124
# new_deaths_smoothed                   364894
# total_cases_per_million               338085
# new_cases_per_million                 366116
# new_cases_smoothed_per_million        364886
# total_deaths_per_million              316113
# new_deaths_per_million                366124
# new_deaths_smoothed_per_million       364894
# reproduction_rate                     184817
# icu_patients                           38433
# icu_patients_per_million               38433
# hosp_patients                          39932
# ...

# %% [markdown]
# # Drop unwanted columns

# %%
# List of columns to drop
columns_to_drop = ['iso_code', 'continent', 'location', 'date', 
                   'total_cases_per_million', 'new_cases_per_million', 
                   'new_cases_smoothed_per_million', 'total_deaths_per_million', 
                   'new_deaths_per_million', 'new_deaths_smoothed_per_million']

# Drop the columns
data.drop(columns=columns_to_drop, inplace=True)

# %%
data.isnull().sum()
# Out:
# population_density                    0
# total_cases                           0
# new_cases                             0
# new_cases_smoothed                    0
# total_deaths                          0
# new_deaths                            0
# new_deaths_smoothed                   0
# reproduction_rate                     0
# icu_patients                          0
# icu_patients_per_million              0
# hosp_patients                         0
# hosp_patients_per_million             0
# weekly_icu_admissions                 0
# weekly_icu_admissions_per_million     0
# weekly_hosp_admissions                0
# weekly_hosp_admissions_per_million    0
# dtype: int64

# %%
data["total_cases"].fillna(0, inplace=True)

# %%
# Specify the columns you want to fill NaN values with zero
columns_to_fill_zero = ['population_density', 'total_cases', 'new_cases', 'new_cases_smoothed',
                        'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'reproduction_rate',
                        'icu_patients', 'icu_patients_per_million', 'hosp_patients',
                        'hosp_patients_per_million', 'weekly_icu_admissions',
                        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
                        'weekly_hosp_admissions_per_million']

# Fill NaN values with zero in specified columns
data[columns_to_fill_zero] = data[columns_to_fill_zero].fillna(0)

# %%
data = data[(data['new_cases'] != 0) & (data['new_cases_smoothed'] != 0)]

# %% [markdown]
# # Save to csv

# %%
data.to_csv('covid_full_data.csv', index=False)

# %% [markdown]
# # Handling outliers:<!--subtopic-->

# %% [markdown]
# # Removing duplicates:<!--subtopic-->

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# # Data Transformation:<!--topic-->
# # use and one normalization or standardization

# %% [markdown]
# # Standardization:<!--subtopic-->

# %%
from sklearn.preprocessing import StandardScaler

# Assuming 'data' is your DataFrame containing the data to be standardized

# Select the columns to be standardized
columns_to_standardize = ['population_density', 'total_cases', 'new_cases', 'new_cases_smoothed',
                          'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'reproduction_rate',
                          'icu_patients', 'icu_patients_per_million', 'hosp_patients',
                          'hosp_patients_per_million', 'weekly_icu_admissions',
                          'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
                          'weekly_hosp_admissions_per_million']

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(data[columns_to_standardize])

# Make a copy of the selected columns and transform them
data.loc[:, columns_to_standardize] = scaler.transform(data[columns_to_standardize].copy())

# Display the standardized DataFrame
print(data)
# Out:
#         population_density  total_cases  new_cases  new_cases_smoothed  \
# 56               -0.168125    -0.179623  -0.113471           -0.113471
# 70               -0.168125    -0.179623  -0.113464           -0.113464
# 77               -0.168125    -0.179622  -0.113449           -0.113449
# 84               -0.168125    -0.179621  -0.113381           -0.113381
# 91               -0.168125    -0.179617  -0.113224           -0.113224
# ...                    ...          ...        ...                 ...
# 376964           -0.176035    -0.174065  -0.113441           -0.113441
# 376978           -0.176035    -0.174064  -0.113410           -0.113410
# 376985           -0.176035    -0.174063  -0.113357           -0.113357
# 376992           -0.176035    -0.174061  -0.113397           -0.113397
# 376999           -0.176035    -0.174061  -0.113430           -0.113430
#
#         total_deaths  new_deaths  new_deaths_smoothed  reproduction_rate  \
# ...

# %% [markdown]
# # Encoding categorical variables:<!--subtopic-->

# %% [markdown]
# not required

# %% [markdown]
# # Scikit-learn(Python):<!--subtopic-->

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Assuming 'data' is your DataFrame containing the data

# Select the independent variables (features)
independent_cols = ['population_density', 'total_cases', 'new_cases_smoothed',
                    'total_deaths', 'new_deaths', 'new_deaths_smoothed', 'reproduction_rate',
                    'icu_patients', 'icu_patients_per_million', 'hosp_patients',
                    'hosp_patients_per_million', 'weekly_icu_admissions',
                    'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
                    'weekly_hosp_admissions_per_million']

# Select the dependent variable (target)
dependent_col = ['new_cases']

# Split the data into independent and dependent variables
X = data[independent_cols]
y = data[dependent_col]

# Standardize the independent variables (features)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Optionally, you can split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Display the shapes of the arrays (optional)
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (31322, 15)
# X_test shape: (7831, 15)
# y_train shape: (31322, 1)
# y_test shape: (7831, 1)
