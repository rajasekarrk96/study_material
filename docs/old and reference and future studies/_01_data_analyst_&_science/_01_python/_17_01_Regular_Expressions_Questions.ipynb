# %% [markdown]
# # Python Regular Expressions Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Find First Digits
#
# **Problem description:** Use `re.search` to find the first group of digits in a string and return it.
#
# **Input format:** `text: str`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# text = 'Room 12, Floor 5'
# ```
#
# **Sample Output:**
# ```python
# '12'
# ```
#
# **Constraints:** Return None when no digits are present.

# %%
def find_first_digits(text: str) -> str | None:
    pass

# %% [markdown]
# ## Q2. Find All Digits
#
# **Problem description:** Use `re.findall` to return all digit groups from a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'A1 B22 C333'
# ```
#
# **Sample Output:**
# ```python
# ['1', '22', '333']
# ```
#
# **Constraints:** The string may contain zero or more digit groups.

# %%
def find_all_digits(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q3. Starts With Digits
#
# **Problem description:** Use `re.match` to return True if a string starts with digits, otherwise False.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = '123abc'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Return False when the string does not start with digits.

# %%
def starts_with_digits(text: str) -> bool:
    pass

# %% [markdown]
# ## Q4. Full Digits Only
#
# **Problem description:** Use `re.fullmatch` to return True if a string contains only digits, otherwise False.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = '12345'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Return False for mixed content.

# %%
def full_digits_only(text: str) -> bool:
    pass

# %% [markdown]
# ## Q5. Extract Lowercase Vowels
#
# **Problem description:** Use a character class to return all lowercase vowels in a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'education'
# ```
#
# **Sample Output:**
# ```python
# ['e', 'u', 'a', 'i', 'o']
# ```
#
# **Constraints:** Match lowercase vowels only.

# %%
def extract_lowercase_vowels(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q6. Split On Comma Semicolon
#
# **Problem description:** Use `re.split` to split text on commas or semicolons and return the cleaned parts.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'python, sql; excel'
# ```
#
# **Sample Output:**
# ```python
# ['python', 'sql', 'excel']
# ```
#
# **Constraints:** Allow optional spaces after separators.

# %%
def split_on_comma_semicolon(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q7. Replace Digits With X
#
# **Problem description:** Use `re.sub` to replace all digit groups in a string with 'X'.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'Order 123 shipped on 2026-04-27'
# ```
#
# **Sample Output:**
# ```python
# 'Order X shipped on X-X-X'
# ```
#
# **Constraints:** Replace every matched digit group.

# %%
def replace_digits_with_x(text: str) -> str:
    pass

# %% [markdown]
# ## Q8. Find Simple Email
#
# **Problem description:** Use regex to return the first simple email-like match from text.
#
# **Input format:** `text: str`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# text = 'Contact asha@test.com now'
# ```
#
# **Sample Output:**
# ```python
# 'asha@test.com'
# ```
#
# **Constraints:** Return None if no email-like match exists.

# %%
def find_simple_email(text: str) -> str | None:
    pass

# %% [markdown]
# ## Q9. Count Words With P
#
# **Problem description:** Use regex to return all words starting with lowercase 'p'.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'python pandas sql powerbi'
# ```
#
# **Sample Output:**
# ```python
# ['python', 'pandas', 'powerbi']
# ```
#
# **Constraints:** Match lowercase p only.

# %%
def count_words_with_p(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q10. Literal Dot Count
#
# **Problem description:** Use regex to find all literal dots in a string and return their count.
#
# **Input format:** `text: str`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# text = 'report.v1.txt'
# ```
#
# **Sample Output:**
# ```python
# 2
# ```
#
# **Constraints:** Match literal dot characters only.

# %%
def literal_dot_count(text: str) -> int:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Extract Email User Domain
#
# **Problem description:** Use capturing groups to extract the username and domain from a simple `.com` email and return them as a tuple.
#
# **Input format:** `email: str`
#
# **Output format:** `tuple[str, str] | None`
#
# **Sample Input:**
# ```python
# email = 'asha@test.com'
# ```
#
# **Sample Output:**
# ```python
# ('asha', 'test')
# ```
#
# **Constraints:** Return None if the pattern does not match.

# %%
def extract_email_user_domain(email: str) -> tuple[str, str] | None:
    pass

# %% [markdown]
# ## Q12. Named Group Date
#
# **Problem description:** Use named groups to extract year, month, and day from a date string `YYYY-MM-DD` and return them in a dictionary.
#
# **Input format:** `text: str`
#
# **Output format:** `dict[str, str] | None`
#
# **Sample Input:**
# ```python
# text = '2026-04-27'
# ```
#
# **Sample Output:**
# ```python
# {'year': '2026', 'month': '04', 'day': '27'}
# ```
#
# **Constraints:** Return None if the date format does not match.

# %%
def named_group_date(text: str) -> dict[str, str] | None:
    pass

# %% [markdown]
# ## Q13. Greedy Vs Non Greedy
#
# **Problem description:** Use non-greedy matching to return all `<b>...</b>` segments separately from a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = '<b>one</b><b>two</b>'
# ```
#
# **Sample Output:**
# ```python
# ['<b>one</b>', '<b>two</b>']
# ```
#
# **Constraints:** Use a non-greedy quantifier.

# %%
def greedy_vs_non_greedy(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q14. Case Insensitive Python
#
# **Problem description:** Use `re.IGNORECASE` to return all case variations of the word 'python' in a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'Python PYTHON python'
# ```
#
# **Sample Output:**
# ```python
# ['Python', 'PYTHON', 'python']
# ```
#
# **Constraints:** Match only the word python in any case.

# %%
def case_insensitive_python(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q15. Phone Format Check
#
# **Problem description:** Use `re.fullmatch` to validate a phone number in the format `123-456-7890`.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = '123-456-7890'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Return False for invalid formats.

# %%
def phone_format_check(text: str) -> bool:
    pass

# %% [markdown]
# ## Q16. Extract Hashtags
#
# **Problem description:** Use regex to return all hashtag words like `#python` from a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'Learn #python and #sql today'
# ```
#
# **Sample Output:**
# ```python
# ['#python', '#sql']
# ```
#
# **Constraints:** Hashtag words contain letters, digits, or underscores.

# %%
def extract_hashtags(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q17. Split Multiple Semicolons
#
# **Problem description:** Use `re.split` to split text on one or more semicolons.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'a;;b;c;;;d'
# ```
#
# **Sample Output:**
# ```python
# ['a', 'b', 'c', 'd']
# ```
#
# **Constraints:** Ignore empty pieces caused by repeated separators.

# %%
def split_multiple_semicolons(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q18. Find Word Boundaries
#
# **Problem description:** Use word boundaries to return matches of the whole word `cat` only.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'cat scatter bobcat cat'
# ```
#
# **Sample Output:**
# ```python
# ['cat', 'cat']
# ```
#
# **Constraints:** Do not match inside larger words.

# %%
def find_word_boundaries(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q19. Mask Long Numbers
#
# **Problem description:** Use `re.sub` to replace any digit sequence of length 4 or more with `####`.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'Call 1234 or 9876543210 now'
# ```
#
# **Sample Output:**
# ```python
# 'Call #### or #### now'
# ```
#
# **Constraints:** Shorter digit groups should stay unchanged.

# %%
def mask_long_numbers(text: str) -> str:
    pass

# %% [markdown]
# ## Q20. Extract Repeated Spaces
#
# **Problem description:** Use regex to find all runs of two or more spaces.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'a  b   c    d'
# ```
#
# **Sample Output:**
# ```python
# ['  ', '   ', '    ']
# ```
#
# **Constraints:** Match only spaces, not tabs.

# %%
def extract_repeated_spaces(text: str) -> list[str]:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Compile Reusable Pattern
#
# **Problem description:** Use `re.compile` to create a reusable `.com` email pattern and return all matches from text.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'a@test.com b@data.com c@test.org'
# ```
#
# **Sample Output:**
# ```python
# ['a@test.com', 'b@data.com']
# ```
#
# **Constraints:** Match only `.com` email-like values.

# %%
def compile_reusable_pattern(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q22. Multiline Start Words
#
# **Problem description:** Use `re.MULTILINE` and `^` to return all words that start each line.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'alpha\nbeta\ngamma'
# ```
#
# **Sample Output:**
# ```python
# ['alpha', 'beta', 'gamma']
# ```
#
# **Constraints:** Match the first word of every line.

# %%
def multiline_start_words(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q23. Dotall Block Match
#
# **Problem description:** Use `re.DOTALL` to match text between `<start>` and `<end>` even across newlines.
#
# **Input format:** `text: str`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# text = '<start>line1\nline2<end>'
# ```
#
# **Sample Output:**
# ```python
# '<start>line1\nline2<end>'
# ```
#
# **Constraints:** Return None if the block is not found.

# %%
def dotall_block_match(text: str) -> str | None:
    pass

# %% [markdown]
# ## Q24. Extract Decimal Numbers
#
# **Problem description:** Use regex to return all decimal numbers like `12.5` or `3.14` from a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'Values 12.5 and 3.14 are here'
# ```
#
# **Sample Output:**
# ```python
# ['12.5', '3.14']
# ```
#
# **Constraints:** Do not return plain integers for this task.

# %%
def extract_decimal_numbers(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q25. Validate Identifier
#
# **Problem description:** Use regex to validate a Python-like identifier: starts with letter or underscore, followed by letters, digits, or underscores.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = '_value1'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Return False for invalid identifiers.

# %%
def validate_identifier(text: str) -> bool:
    pass

# %% [markdown]
# ## Q26. Swap Name Order
#
# **Problem description:** Use capturing groups and `re.sub` to convert `'Asha Sharma'` into `'Sharma, Asha'`.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'Asha Sharma'
# ```
#
# **Sample Output:**
# ```python
# 'Sharma, Asha'
# ```
#
# **Constraints:** Assume exactly two words with letters only.

# %%
def swap_name_order(text: str) -> str:
    pass

# %% [markdown]
# ## Q27. Repeated Word Detection
#
# **Problem description:** Use a backreference to detect repeated consecutive words like `'go go'` and return True if found.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = 'go go stop'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Check for immediate repeated words only.

# %%
def repeated_word_detection(text: str) -> bool:
    pass

# %% [markdown]
# ## Q28. Extract HTML Title
#
# **Problem description:** Use regex with a capturing group to extract the text inside `<title>...</title>`.
#
# **Input format:** `text: str`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# text = '<title>Python Notes</title>'
# ```
#
# **Sample Output:**
# ```python
# 'Python Notes'
# ```
#
# **Constraints:** Return None if no title tag is found.

# %%
def extract_html_title(text: str) -> str | None:
    pass

# %% [markdown]
# ## Q29. Find Non Greedy Quotes
#
# **Problem description:** Use non-greedy matching to return all quoted strings separately.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'He said "hi" and "bye"'
# ```
#
# **Sample Output:**
# ```python
# ['"hi"', '"bye"']
# ```
#
# **Constraints:** Use a non-greedy quantifier.

# %%
def find_non_greedy_quotes(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q30. Strict Hex Color
#
# **Problem description:** Use regex to validate a hex color code like `#1A2B3C`.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = '#1A2B3C'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Allow exactly 6 hexadecimal digits after `#`.

# %%
def strict_hex_color(text: str) -> bool:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Extract Emails From Text
#
# **Problem description:** Use regex to return all email-like values from a block of text.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'Mail a@test.com and b@site.org today'
# ```
#
# **Sample Output:**
# ```python
# ['a@test.com', 'b@site.org']
# ```
#
# **Constraints:** Match basic email-like formats only.

# %%
def extract_emails_from_text(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q32. Log Error Code Parser
#
# **Problem description:** Use regex to extract all error codes like `E101` or `E502` from log text.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'ERROR E101 then ERROR E502'
# ```
#
# **Sample Output:**
# ```python
# ['E101', 'E502']
# ```
#
# **Constraints:** An error code starts with `E` followed by digits.

# %%
def log_error_code_parser(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q33. Date Normalizer
#
# **Problem description:** Use regex substitution to convert dates from `DD/MM/YYYY` to `YYYY-MM-DD`.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = '27/04/2026'
# ```
#
# **Sample Output:**
# ```python
# '2026-04-27'
# ```
#
# **Constraints:** Assume the input contains exactly one date in that format.

# %%
def date_normalizer(text: str) -> str:
    pass

# %% [markdown]
# ## Q34. Password Rule Check
#
# **Problem description:** Use regex to validate a password that has at least one uppercase letter, one lowercase letter, one digit, and minimum length 8.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text = 'Asha2026'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Return False for invalid passwords.

# %%
def password_rule_check(text: str) -> bool:
    pass

# %% [markdown]
# ## Q35. Markdown Heading Extractor
#
# **Problem description:** Use regex with `re.MULTILINE` to extract all Markdown headings like `# Title` or `## Subtitle` line by line.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = '# Title\nText\n## Subtitle'
# ```
#
# **Sample Output:**
# ```python
# ['# Title', '## Subtitle']
# ```
#
# **Constraints:** Return full heading lines.

# %%
def markdown_heading_extractor(text: str) -> list[str]:
    pass
