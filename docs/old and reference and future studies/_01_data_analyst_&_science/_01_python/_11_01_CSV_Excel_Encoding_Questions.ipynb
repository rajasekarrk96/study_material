# %% [markdown]
# # CSV, Excel, and Encoding Questions
#
# No solutions in this notebook.

# %% [markdown]
# ## Section 1: Basic Questions

# %% [markdown]
# ### Q1. Basic Problem 1
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q2. Basic Problem 2
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q3. Basic Problem 3
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q4. Basic Problem 4
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q5. Basic Problem 5
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q6. Basic Problem 6
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q7. Basic Problem 7
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q8. Basic Problem 8
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q9. Basic Problem 9
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q10. Basic Problem 10
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ## Section 2: Intermediate Questions

# %% [markdown]
# ### Q11. Intermediate Problem 11
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q12. Intermediate Problem 12
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q13. Intermediate Problem 13
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q14. Intermediate Problem 14
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q15. Intermediate Problem 15
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q16. Intermediate Problem 16
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q17. Intermediate Problem 17
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q18. Intermediate Problem 18
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q19. Intermediate Problem 19
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q20. Intermediate Problem 20
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ## Section 3: Advanced Questions

# %% [markdown]
# ### Q21. Advanced Problem 21
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q22. Advanced Problem 22
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q23. Advanced Problem 23
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q24. Advanced Problem 24
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q25. Advanced Problem 25
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q26. Advanced Problem 26
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q27. Advanced Problem 27
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q28. Advanced Problem 28
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q29. Advanced Problem 29
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q30. Advanced Problem 30
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ## Section 4: Real-world Problems

# %% [markdown]
# ### Q31. Real-world Problem 31
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q32. Real-world Problem 32
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q33. Real-world Problem 33
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q34. Real-world Problem 34
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required

# %% [markdown]
# ### Q35. Real-world Problem 35
# **Problem Description**
# Work with CSV/Excel/encoding data to produce correct transformed output.
#
# **Input Format**
# Text/csv rows (or equivalent list of records) provided to your function/script.
#
# **Output Format**
# Return or print the required transformed rows/value exactly.
#
# **Sample Input**
# `records = [{"name":"Asha","age":"22"}, {"name":"Ravi","age":"24"}]`
#
# **Sample Output**
# `[{"name":"ASHA","age":22}, {"name":"RAVI","age":24}]`
#
# **Constraints (if applicable)**
# - Must handle empty values safely
# - Must preserve row order unless asked to sort
# - Use explicit encoding when file I/O is required
