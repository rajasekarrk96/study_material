# %% [markdown]
# # Advanced OOP Questions
#
# This notebook contains structured practice questions from beginner to advanced level.
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ### Q1. Simple Inheritance
#
# **Level:** Basic
#
# **Problem description:**
# Create a parent class `Animal` with a `name` attribute and a child class `Dog` that returns `<name> says Woof`.
#
# **Input format:**
# One string name.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# Bruno
# ```
#
# **Sample Output:**
# ```text
# Bruno says Woof
# ```
#
# **Constraints:**
# Name is a non-empty string.

# %%
class Animal:
    pass

class Dog(Animal):
    pass

# %% [markdown]
# ### Q2. Use super in Constructor
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Person` class and a `Teacher` child class that uses `super()` to store `name` and also stores `subject`.
#
# **Input format:**
# One string name and one string subject.
#
# **Output format:**
# A tuple.
#
# **Sample Input:**
# ```text
# Anita Math
# ```
#
# **Sample Output:**
# ```text
# ('Anita', 'Math')
# ```
#
# **Constraints:**
# Both values are non-empty strings.

# %%
class Person:
    pass

class Teacher(Person):
    pass

# %% [markdown]
# ### Q3. Method Overriding
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Notification` parent class and an `EmailNotification` child class that overrides `send()`.
#
# **Input format:**
# No external input required beyond object creation.
#
# **Output format:**
# Two strings from two method calls.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Sending a notification / Sending an email notification
# ```
#
# **Constraints:**
# Focus on override behavior.

# %%
class Notification:
    pass

class EmailNotification(Notification):
    pass

# %% [markdown]
# ### Q4. Len With Dunder
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Playlist` class that supports `len(object)` using `__len__()`.
#
# **Input format:**
# A list of song strings.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# ['Song A', 'Song B']
# ```
#
# **Sample Output:**
# ```text
# 2
# ```
#
# **Constraints:**
# List may be empty.

# %%
class Playlist:
    pass

# %% [markdown]
# ### Q5. Friendly String
#
# **Level:** Basic
#
# **Problem description:**
# Create a `StudentProfile` class where `print(object)` returns `Student(name=Asha, marks=91)` style text.
#
# **Input format:**
# One string and one integer.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# Asha 91
# ```
#
# **Sample Output:**
# ```text
# Student(name=Asha, marks=91)
# ```
#
# **Constraints:**
# Marks are integers.

# %%
class StudentProfile:
    pass

# %% [markdown]
# ### Q6. Compare Two Books
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Book` class where two books are equal when title and author match.
#
# **Input format:**
# Two title-author pairs.
#
# **Output format:**
# A boolean.
#
# **Sample Input:**
# ```text
# same data twice
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# Title and author are strings.

# %%
class Book:
    pass

# %% [markdown]
# ### Q7. Static Temperature Conversion
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Temperature` class with a static method that converts Celsius to Fahrenheit.
#
# **Input format:**
# One numeric Celsius value.
#
# **Output format:**
# One numeric Fahrenheit value.
#
# **Sample Input:**
# ```text
# 25
# ```
#
# **Sample Output:**
# ```text
# 77.0
# ```
#
# **Constraints:**
# Input can be int or float.

# %%
class Temperature:
    pass

# %% [markdown]
# ### Q8. Class Method From String
#
# **Level:** Basic
#
# **Problem description:**
# Create an `Employee` class with a class method `from_string('Aman-50000')`.
#
# **Input format:**
# One formatted string.
#
# **Output format:**
# A tuple.
#
# **Sample Input:**
# ```text
# Aman-50000
# ```
#
# **Sample Output:**
# ```text
# ('Aman', 50000)
# ```
#
# **Constraints:**
# Input uses exactly one hyphen.

# %%
class Employee:
    pass

# %% [markdown]
# ### Q9. Protected Attribute Reader
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Wallet` class with `_amount` and a public method that returns it.
#
# **Input format:**
# One integer amount.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# 2500
# ```
#
# **Sample Output:**
# ```text
# 2500
# ```
#
# **Constraints:**
# Amount is non-negative.

# %%
class Wallet:
    pass

# %% [markdown]
# ### Q10. Private PIN Check
#
# **Level:** Basic
#
# **Problem description:**
# Create a `SecureAccount` class with a private-style PIN and a method that checks if an entered PIN matches.
#
# **Input format:**
# One integer stored pin and one integer entered pin.
#
# **Output format:**
# A boolean.
#
# **Sample Input:**
# ```text
# 1234 then 1234
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# PIN values are integers.

# %%
class SecureAccount:
    pass

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ### Q11. Rectangle and Circle Area
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a base `Shape` class and child classes `Rectangle` and `Circle` that implement `area()`.
#
# **Input format:**
# Dimensions for one rectangle and one circle.
#
# **Output format:**
# Two numeric areas.
#
# **Sample Input:**
# ```text
# Rectangle 4 5 and Circle 3
# ```
#
# **Sample Output:**
# ```text
# 20 and 28.27431
# ```
#
# **Constraints:**
# Use 3.14159 for pi.

# %%
class Shape:
    pass

class Rectangle(Shape):
    pass

class Circle(Shape):
    pass

# %% [markdown]
# ### Q12. Vector Addition
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Vector` class that supports `+` and returns readable string output.
#
# **Input format:**
# Two coordinate pairs.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# (2, 3) and (5, 7)
# ```
#
# **Sample Output:**
# ```text
# Vector(7, 10)
# ```
#
# **Constraints:**
# Coordinates are integers.

# %%
class Vector:
    pass

# %% [markdown]
# ### Q13. Custom Counter
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Counter` class with an `increment()` method that updates internal state.
#
# **Input format:**
# One starting integer.
#
# **Output format:**
# Increasing integers on repeated calls.
#
# **Sample Input:**
# ```text
# 0 then call three times
# ```
#
# **Sample Output:**
# ```text
# 1 2 3
# ```
#
# **Constraints:**
# Starting count is non-negative.

# %%
class Counter:
    pass

# %% [markdown]
# ### Q14. User Role Override
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `User` class with `role()` and an `Admin` child class that overrides it.
#
# **Input format:**
# One string username.
#
# **Output format:**
# One string role.
#
# **Sample Input:**
# ```text
# root_user
# ```
#
# **Sample Output:**
# ```text
# Admin
# ```
#
# **Constraints:**
# Username is a non-empty string.

# %%
class User:
    pass

class Admin(User):
    pass

# %% [markdown]
# ### Q15. Payment Interface
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a base `Payment` class and child classes `CardPayment` and `CashPayment` with `pay(amount)`.
#
# **Input format:**
# One numeric amount.
#
# **Output format:**
# Two strings.
#
# **Sample Input:**
# ```text
# 500
# ```
#
# **Sample Output:**
# ```text
# Paid 500 by card / Paid 500 by cash
# ```
#
# **Constraints:**
# Amount is a positive integer.

# %%
class Payment:
    pass

class CardPayment(Payment):
    pass

class CashPayment(Payment):
    pass

# %% [markdown]
# ### Q16. Validated Percentage Property
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Percentage` class with a property setter that rejects values outside `0` to `100`.
#
# **Input format:**
# One integer percentage.
#
# **Output format:**
# Stored integer or error.
#
# **Sample Input:**
# ```text
# 85
# ```
#
# **Sample Output:**
# ```text
# 85
# ```
#
# **Constraints:**
# Values outside range must be rejected.

# %%
class Percentage:
    pass

# %% [markdown]
# ### Q17. Multiple Inheritance Demo
#
# **Level:** Intermediate
#
# **Problem description:**
# Create `Camera`, `Phone`, and `SmartPhone` classes where `SmartPhone` inherits behavior from both parents.
#
# **Input format:**
# No special runtime input.
#
# **Output format:**
# Two strings from method calls.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Photo captured / Calling...
# ```
#
# **Constraints:**
# Use multiple inheritance once for demonstration.

# %%
class Camera:
    pass

class Phone:
    pass

class SmartPhone(Camera, Phone):
    pass

# %% [markdown]
# ### Q18. Shared Object Counter
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a class that counts how many objects have been created using a class attribute.
#
# **Input format:**
# A sequence of object creations.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# create 3 objects
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# Objects are created normally.

# %%
class Visitor:
    pass

# %% [markdown]
# ### Q19. Statement Account
#
# **Level:** Intermediate
#
# **Problem description:**
# Create an account class that tracks balance and number of transactions.
#
# **Input format:**
# One starting balance and operations.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# 1000 then deposit 100, withdraw 50
# ```
#
# **Sample Output:**
# ```text
# {'balance': 1050, 'count': 2}
# ```
#
# **Constraints:**
# Operations are valid.

# %%
class StatementAccount:
    pass

# %% [markdown]
# ### Q20. Library Book Availability
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `LibraryBook` class with `borrow()` and `return_book()` methods and final availability state.
#
# **Input format:**
# One title and a sequence of actions.
#
# **Output format:**
# A boolean.
#
# **Sample Input:**
# ```text
# Python Book then borrow, return
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# Availability starts as True.

# %%
class LibraryBook:
    pass

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ### Q21. Positive Descriptor
#
# **Level:** Advanced
#
# **Problem description:**
# Create a descriptor that allows only non-negative values and use it in a `Product` class.
#
# **Input format:**
# One integer price.
#
# **Output format:**
# One integer or an error.
#
# **Sample Input:**
# ```text
# 500
# ```
#
# **Sample Output:**
# ```text
# 500
# ```
#
# **Constraints:**
# Negative values should raise an error.

# %%
class PositiveNumber:
    pass

class Product:
    pass

# %% [markdown]
# ### Q22. Sortable Student Objects
#
# **Level:** Advanced
#
# **Problem description:**
# Create `Student` objects and sort them by marks descending using a lambda key.
#
# **Input format:**
# A list of student data.
#
# **Output format:**
# A list of names in sorted order.
#
# **Sample Input:**
# ```text
# [('A', 70), ('B', 90), ('C', 80)]
# ```
#
# **Sample Output:**
# ```text
# ['B', 'C', 'A']
# ```
#
# **Constraints:**
# Marks are between 0 and 100.

# %%
class Student:
    pass

# %% [markdown]
# ### Q23. Transaction String View
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `Transaction` class where `print(object)` returns `Transaction(amount=500, type='deposit')`.
#
# **Input format:**
# One integer amount and one string type.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# 500 deposit
# ```
#
# **Sample Output:**
# ```text
# Transaction(amount=500, type='deposit')
# ```
#
# **Constraints:**
# Type is non-empty.

# %%
class Transaction:
    pass

# %% [markdown]
# ### Q24. Course Registry
#
# **Level:** Advanced
#
# **Problem description:**
# Create a class that stores every created course title in a class-level registry.
#
# **Input format:**
# A sequence of course titles.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# Python, SQL, Statistics
# ```
#
# **Sample Output:**
# ```text
# ['Python', 'SQL', 'Statistics']
# ```
#
# **Constraints:**
# Titles are strings.

# %%
class Course:
    pass

# %% [markdown]
# ### Q25. Inventory Protection
#
# **Level:** Advanced
#
# **Problem description:**
# Create an `InventoryItem` class with `add_stock()` and `remove_stock()` where stock never becomes negative.
#
# **Input format:**
# One starting stock and operations.
#
# **Output format:**
# A final stock value or error text.
#
# **Sample Input:**
# ```text
# 10 then remove 12
# ```
#
# **Sample Output:**
# ```text
# Insufficient stock
# ```
#
# **Constraints:**
# Stock starts non-negative.

# %%
class InventoryItem:
    pass

# %% [markdown]
# ### Q26. Smart Payment Factory
#
# **Level:** Advanced
#
# **Problem description:**
# Create a payment factory class method that returns either `CardPayment` or `CashPayment` objects based on a string.
#
# **Input format:**
# One payment type string and amount.
#
# **Output format:**
# A payment result string.
#
# **Sample Input:**
# ```text
# card and 500
# ```
#
# **Sample Output:**
# ```text
# Paid 500 by card
# ```
#
# **Constraints:**
# Payment type is either `card` or `cash`.

# %%
class Payment:
    pass

class CardPayment(Payment):
    pass

class CashPayment(Payment):
    pass

# %% [markdown]
# ### Q27. Custom Equality for Users
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `UserAccount` class where equality depends on `user_id` only.
#
# **Input format:**
# Two user records.
#
# **Output format:**
# A boolean.
#
# **Sample Input:**
# ```text
# same user_id twice
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# User IDs are integers.

# %%
class UserAccount:
    pass

# %% [markdown]
# ### Q28. Polymorphic Area Sum
#
# **Level:** Advanced
#
# **Problem description:**
# Given mixed `Rectangle` and `Circle` objects, return the sum of all `area()` results.
#
# **Input format:**
# A list of shape objects.
#
# **Output format:**
# One numeric total.
#
# **Sample Input:**
# ```text
# Rectangle(4, 5), Circle(3)
# ```
#
# **Sample Output:**
# ```text
# 48.27431
# ```
#
# **Constraints:**
# Use 3.14159 for pi.

# %%
class Shape:
    pass

# %% [markdown]
# ### Q29. Custom Context Manager Timer
#
# **Level:** Advanced
#
# **Problem description:**
# Create a simple class-based context manager that prints entering and exiting messages for a timed block.
#
# **Input format:**
# No external input required.
#
# **Output format:**
# Two printed status messages.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Entering / Exiting
# ```
#
# **Constraints:**
# Focus on `__enter__` and `__exit__` behavior.

# %%
class TimerLike:
    pass

# %% [markdown]
# ### Q30. Method Resolution Order Awareness
#
# **Level:** Advanced
#
# **Problem description:**
# Create a small multiple inheritance chain and show which method is used when the same method exists in more than one parent.
#
# **Input format:**
# No standard input.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Message from first matching parent in MRO
# ```
#
# **Constraints:**
# Keep the class chain small and clear.

# %%
class A:
    pass

class B:
    pass

class C(A, B):
    pass

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ### Q31. Employee Payroll Object
#
# **Level:** Real-world
#
# **Problem description:**
# Create an `EmployeePayroll` class that stores gross salary and tax percentage and returns net salary.
#
# **Input format:**
# One name, one gross salary, and one tax percentage.
#
# **Output format:**
# One float.
#
# **Sample Input:**
# ```text
# Ravi 50000 10
# ```
#
# **Sample Output:**
# ```text
# 45000.0
# ```
#
# **Constraints:**
# Tax percentage is between 0 and 100.

# %%
class EmployeePayroll:
    pass

# %% [markdown]
# ### Q32. Student Report Object
#
# **Level:** Real-world
#
# **Problem description:**
# Create a `StudentReport` class that returns name, average, and grade as a dictionary.
#
# **Input format:**
# One name and a list of marks.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# Asha and [88, 76, 91, 84]
# ```
#
# **Sample Output:**
# ```text
# {'name': 'Asha', 'average': 84.75, 'grade': 'B'}
# ```
#
# **Constraints:**
# Marks are between 0 and 100.

# %%
class StudentReport:
    pass

# %% [markdown]
# ### Q33. Shopping Cart OOP
#
# **Level:** Real-world
#
# **Problem description:**
# Create a `ShoppingCart` class that stores items and returns the total bill.
#
# **Input format:**
# A sequence of `(name, price, quantity)` values.
#
# **Output format:**
# One integer total.
#
# **Sample Input:**
# ```text
# Book 300 2, Pen 20 5
# ```
#
# **Sample Output:**
# ```text
# 700
# ```
#
# **Constraints:**
# Prices and quantities are non-negative.

# %%
class ShoppingCart:
    pass

# %% [markdown]
# ### Q34. ATM Simulation
#
# **Level:** Real-world
#
# **Problem description:**
# Create an `ATMAccount` class with deposit, withdraw, and mini-statement behavior.
#
# **Input format:**
# One starting balance and operations.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# 1000 then deposit 500, withdraw 200
# ```
#
# **Sample Output:**
# ```text
# {'balance': 1300, 'transactions': 2}
# ```
#
# **Constraints:**
# Operations are valid.

# %%
class ATMAccount:
    pass

# %% [markdown]
# ### Q35. Course Enrollment Tracker
#
# **Level:** Real-world
#
# **Problem description:**
# Create a `CourseEnrollment` class that stores enrolled student names and returns both count and sorted names.
#
# **Input format:**
# One sequence of names.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# Ravi, Asha, Meena
# ```
#
# **Sample Output:**
# ```text
# {'count': 3, 'students': ['Asha', 'Meena', 'Ravi']}
# ```
#
# **Constraints:**
# Names are strings and may arrive unsorted.

# %%
class CourseEnrollment:
    pass
