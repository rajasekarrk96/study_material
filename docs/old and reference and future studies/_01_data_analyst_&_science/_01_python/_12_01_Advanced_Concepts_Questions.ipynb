# %% [markdown]
# # Python Advanced Concepts Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Call Returned Function
#
# **Problem description:** Write a function that returns an inner function which always returns the given message. Then call the returned function and return its result.
#
# **Input format:** `message: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# message = 'Hello'
# ```
#
# **Sample Output:**
# ```python
# 'Hello'
# ```
#
# **Constraints:** The message is a non-empty string.

# %%
def call_returned_function(message: str) -> str:
    pass

# %% [markdown]
# ## Q2. Use Nonlocal Counter
#
# **Problem description:** Create a closure-based counter and return the result after calling it exactly three times.
#
# **Input format:** `start: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# start = 5
# ```
#
# **Sample Output:**
# ```python
# 8
# ```
#
# **Constraints:** The counter should begin from start and increase by 1 on each call.

# %%
def use_nonlocal_counter(start: int) -> int:
    pass

# %% [markdown]
# ## Q3. Apply Function
#
# **Problem description:** Write a function that accepts an integer and another function, applies the function to the integer, and returns the result.
#
# **Input format:** `value: int, operation`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 4, operation = lambda x: x * 2
# ```
#
# **Sample Output:**
# ```python
# 8
# ```
#
# **Constraints:** Assume operation is callable and returns an integer.

# %%
def apply_function(value: int, operation) -> int:
    pass

# %% [markdown]
# ## Q4. Check Identity
#
# **Problem description:** Return True if two variables refer to the same object, otherwise return False.
#
# **Input format:** `a, b`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# a = b = [1, 2]
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Any Python objects may be given.

# %%
def check_identity(a, b) -> bool:
    pass

# %% [markdown]
# ## Q5. Read Property Value
#
# **Problem description:** Given a class with a `@property` named `double`, create an object and return the property value for the given integer.
#
# **Input format:** `value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 7
# ```
#
# **Sample Output:**
# ```python
# 14
# ```
#
# **Constraints:** Use property access, not a separate method call.

# %%
def read_property_value(value: int) -> int:
    pass

# %% [markdown]
# ## Q6. Build Generator List
#
# **Problem description:** Create a generator that yields numbers from 1 to n and return them as a list.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 4
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4]
# ```
#
# **Constraints:** 0 <= n <= 100.

# %%
def build_generator_list(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q7. Context Message
#
# **Problem description:** Use a custom context manager class that returns a string from `__enter__`, then return that string from inside the `with` block.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'resource'
# ```
#
# **Sample Output:**
# ```python
# 'resource'
# ```
#
# **Constraints:** The string may contain spaces.

# %%
def context_message(text: str) -> str:
    pass

# %% [markdown]
# ## Q8. Lambda Sort Scores
#
# **Problem description:** Return a list of student tuples sorted by score in descending order using a lambda expression.
#
# **Input format:** `students: list[tuple[str, int]]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# students = [('A', 70), ('B', 90)]
# ```
#
# **Sample Output:**
# ```python
# [('B', 90), ('A', 70)]
# ```
#
# **Constraints:** The input list may be empty.

# %%
def lambda_sort_scores(students: list[tuple[str, int]]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ## Q9. Mutable Alias Effect
#
# **Problem description:** Given a list, assign it to another variable, append one value using the alias, and return the original list.
#
# **Input format:** `items: list[int], value: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2], value = 3
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3]
# ```
#
# **Constraints:** Mutate the shared list directly.

# %%
def mutable_alias_effect(items: list[int], value: int) -> list[int]:
    pass

# %% [markdown]
# ## Q10. Iterator Next Sum
#
# **Problem description:** Create an iterator from a list of integers, call `next()` twice, and return the sum of the two values.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items = [10, 20, 30]
# ```
#
# **Sample Output:**
# ```python
# 30
# ```
#
# **Constraints:** The list will contain at least two integers.

# %%
def iterator_next_sum(items: list[int]) -> int:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Capture Loop Values Safely
#
# **Problem description:** Return a list of results from closures created inside a loop, where each closure correctly remembers its own loop value.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 3
# ```
#
# **Sample Output:**
# ```python
# [0, 1, 2]
# ```
#
# **Constraints:** 0 <= n <= 20.

# %%
def capture_loop_values_safely(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q12. Decorator Call Counter
#
# **Problem description:** Write a decorator that counts how many times a function is called. Apply it to a function invoked three times and return the final count.
#
# **Input format:** `values: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# values = [2, 4, 6]
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** The decorated function should still return its normal result.

# %%
def decorator_call_counter(values: list[int]) -> int:
    pass

# %% [markdown]
# ## Q13. Generator Filter Evens
#
# **Problem description:** Use a generator expression to lazily filter even numbers from a list and return the final list of even numbers.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4, 5, 6]
# ```
#
# **Sample Output:**
# ```python
# [2, 4, 6]
# ```
#
# **Constraints:** The list may be empty.

# %%
def generator_filter_evens(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q14. Shallow Copy Problem
#
# **Problem description:** Create a shallow copy of a nested list, modify one inner list in the copy, and return both the original and copied structures.
#
# **Input format:** `items: list[list[int]]`
#
# **Output format:** `tuple[list[list[int]], list[list[int]]]`
#
# **Sample Input:**
# ```python
# items = [[1], [2]]
# ```
#
# **Sample Output:**
# ```python
# ([[1, 99], [2]], [[1, 99], [2]])
# ```
#
# **Constraints:** Assume there is at least one inner list.

# %%
def shallow_copy_problem(items: list[list[int]]) -> tuple[list[list[int]], list[list[int]]]:
    pass

# %% [markdown]
# ## Q15. Deep Copy Isolation
#
# **Problem description:** Create a deep copy of a nested list, modify one inner list in the copy, and return both the original and deep-copied structures.
#
# **Input format:** `items: list[list[int]]`
#
# **Output format:** `tuple[list[list[int]], list[list[int]]]`
#
# **Sample Input:**
# ```python
# items = [[1], [2]]
# ```
#
# **Sample Output:**
# ```python
# ([[1], [2]], [[1, 99], [2]])
# ```
#
# **Constraints:** Assume there is at least one inner list.

# %%
def deep_copy_isolation(items: list[list[int]]) -> tuple[list[list[int]], list[list[int]]]:
    pass

# %% [markdown]
# ## Q16. Property Validation
#
# **Problem description:** Create a class with a property setter that rejects negative age values. Return 'Invalid' if assignment fails, otherwise return the stored age.
#
# **Input format:** `age: int`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# age = -1
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** Age may be positive or negative.

# %%
def property_validation(age: int) -> str | int:
    pass

# %% [markdown]
# ## Q17. Descriptor Positive Value
#
# **Problem description:** Use a descriptor to validate that a product price is positive. Return the stored price for valid input, otherwise return 'Invalid'.
#
# **Input format:** `price: int`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# price = 250
# ```
#
# **Sample Output:**
# ```python
# 250
# ```
#
# **Constraints:** Price may be positive, zero, or negative.

# %%
def descriptor_positive_value(price: int) -> str | int:
    pass

# %% [markdown]
# ## Q18. Custom Context Cleanup Flag
#
# **Problem description:** Create a custom context manager that sets a cleanup flag in `__exit__`. Return the cleanup flag value after the `with` block.
#
# **Input format:** `value: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# value = 10
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** No exception handling is required.

# %%
def custom_context_cleanup_flag(value: int) -> bool:
    pass

# %% [markdown]
# ## Q19. Callable Object Multiply
#
# **Problem description:** Create a callable object that multiplies any given input by a stored factor and return the result.
#
# **Input format:** `factor: int, value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# factor = 3, value = 7
# ```
#
# **Sample Output:**
# ```python
# 21
# ```
#
# **Constraints:** Both values are integers.

# %%
def callable_object_multiply(factor: int, value: int) -> int:
    pass

# %% [markdown]
# ## Q20. Yield Running Total
#
# **Problem description:** Write a generator that yields running totals from a list of integers, then return the generated values as a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [2, 3, 5]
# ```
#
# **Sample Output:**
# ```python
# [2, 5, 10]
# ```
#
# **Constraints:** The list may be empty.

# %%
def yield_running_total(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Memoized Fibonacci Closure
#
# **Problem description:** Build a closure-based Fibonacci calculator that caches previous results in a dictionary and return the nth Fibonacci number.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 8
# ```
#
# **Sample Output:**
# ```python
# 21
# ```
#
# **Constraints:** 0 <= n <= 30.

# %%
def memoized_fibonacci_closure(n: int) -> int:
    pass

# %% [markdown]
# ## Q22. Stacked Decorators Order
#
# **Problem description:** Apply two decorators that add text before and after a function result and return the final decorated string.
#
# **Input format:** `name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Asha'
# ```
#
# **Sample Output:**
# ```python
# '[Hello, Asha!]'
# ```
#
# **Constraints:** Use two decorators to show wrapping order.

# %%
def stacked_decorators_order(name: str) -> str:
    pass

# %% [markdown]
# ## Q23. Generator Pipeline Squares
#
# **Problem description:** Use a generator pipeline to square only positive numbers from a list and return their total sum.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items = [-2, -1, 0, 3, 4]
# ```
#
# **Sample Output:**
# ```python
# 25
# ```
#
# **Constraints:** The list may contain negative numbers and zero.

# %%
def generator_pipeline_squares(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q24. Iterator Class Countdown
#
# **Problem description:** Create a custom iterator class that counts down from n to 1 and return the produced values as a list.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 4
# ```
#
# **Sample Output:**
# ```python
# [4, 3, 2, 1]
# ```
#
# **Constraints:** 0 <= n <= 50.

# %%
def iterator_class_countdown(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q25. Context Manager Suppress ValueError
#
# **Problem description:** Create a context manager whose `__exit__` suppresses `ValueError`. Return 'suppressed' when a `ValueError` occurs inside the block.
#
# **Input format:** `number: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# number = -5
# ```
#
# **Sample Output:**
# ```python
# 'suppressed'
# ```
#
# **Constraints:** Raise `ValueError` when the number is negative.

# %%
def context_manager_suppress_valueerror(number: int) -> str:
    pass

# %% [markdown]
# ## Q26. Closure Late Binding Fix
#
# **Problem description:** Create closures inside a loop that each multiply by their captured loop value. Return the list of results when each closure is called with 10.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 4
# ```
#
# **Sample Output:**
# ```python
# [0, 10, 20, 30]
# ```
#
# **Constraints:** 0 <= n <= 10.

# %%
def closure_late_binding_fix(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q27. Dataclass Ranking
#
# **Problem description:** Use a dataclass to store student name and score, then return the name of the student with the highest score.
#
# **Input format:** `records: list[tuple[str, int]]`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# records = [('A', 50), ('B', 90)]
# ```
#
# **Sample Output:**
# ```python
# 'B'
# ```
#
# **Constraints:** Return None for an empty list.

# %%
def dataclass_ranking(records: list[tuple[str, int]]) -> str | None:
    pass

# %% [markdown]
# ## Q28. Descriptor Type and Range Validation
#
# **Problem description:** Create a descriptor that accepts only integers from 1 to 100 inclusive for a score field. Return 'Invalid' when validation fails.
#
# **Input format:** `score: object`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# score = 101
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** The input may be any Python object.

# %%
def descriptor_type_and_range_validation(score: object) -> str | int:
    pass

# %% [markdown]
# ## Q29. Lazy Chunk Reader
#
# **Problem description:** Simulate reading a string in fixed-size chunks using a generator and return the list of chunks.
#
# **Input format:** `text: str, size: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'abcdefgh', size = 3
# ```
#
# **Sample Output:**
# ```python
# ['abc', 'def', 'gh']
# ```
#
# **Constraints:** size will be at least 1.

# %%
def lazy_chunk_reader(text: str, size: int) -> list[str]:
    pass

# %% [markdown]
# ## Q30. Slots Restrict Attributes
#
# **Problem description:** Create a class with `__slots__ = ('x', 'y')`. Return True if assigning a new `z` attribute raises an error, otherwise return False.
#
# **Input format:** `x: int, y: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# x = 1, y = 2
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Use normal attribute assignment.

# %%
def slots_restrict_attributes(x: int, y: int) -> bool:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Audit Log Decorator
#
# **Problem description:** Write a decorator that logs function calls into a list. Apply it to a payment-processing function called twice and return the audit log.
#
# **Input format:** `payments: list[int]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# payments = [100, 200]
# ```
#
# **Sample Output:**
# ```python
# ['process_payment', 'process_payment']
# ```
#
# **Constraints:** The payment list may be empty.

# %%
def audit_log_decorator(payments: list[int]) -> list[str]:
    pass

# %% [markdown]
# ## Q32. Safe File Summary
#
# **Problem description:** Use a context manager to write lines into a file and then read them back. Return the number of lines read.
#
# **Input format:** `lines: list[str]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# lines = ['a', 'b', 'c']
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** Use a local file in the current folder.

# %%
def safe_file_summary(lines: list[str]) -> int:
    pass

# %% [markdown]
# ## Q33. Streaming Sales Total
#
# **Problem description:** Use a generator to process sales amounts lazily and return the total of positive values only.
#
# **Input format:** `sales: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# sales = [10, -5, 20, 0, 15]
# ```
#
# **Sample Output:**
# ```python
# 45
# ```
#
# **Constraints:** Ignore zero and negative values.

# %%
def streaming_sales_total(sales: list[int]) -> int:
    pass

# %% [markdown]
# ## Q34. Validated Employee Record
#
# **Problem description:** Use properties to store an employee name and salary. Reject blank names and negative salaries. Return 'Invalid' on bad input or a formatted summary on success.
#
# **Input format:** `name: str, salary: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Asha', salary = 50000
# ```
#
# **Sample Output:**
# ```python
# 'Asha: 50000'
# ```
#
# **Constraints:** Name may contain extra spaces.

# %%
def validated_employee_record(name: str, salary: int) -> str:
    pass

# %% [markdown]
# ## Q35. Task Queue Iterator
#
# **Problem description:** Create an iterator class over a list of task names and return the tasks in processing order.
#
# **Input format:** `tasks: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# tasks = ['extract', 'clean', 'load']
# ```
#
# **Sample Output:**
# ```python
# ['extract', 'clean', 'load']
# ```
#
# **Constraints:** The list may be empty.

# %%
def task_queue_iterator(tasks: list[str]) -> list[str]:
    pass
