# %% [markdown]
# # Python Decorators Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Simple Logger Decorator
#
# **Problem description:** Write a decorator that prints 'start' before a function call and 'end' after it. Apply it to a function returning a greeting and return the decorated result.
#
# **Input format:** `name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Asha'
# ```
#
# **Sample Output:**
# ```python
# 'Hello, Asha'
# ```
#
# **Constraints:** The input name is a non-empty string.

# %%
def simple_logger_decorator(name: str) -> str:
    pass

# %% [markdown]
# ## Q2. Manual Decoration
#
# **Problem description:** Decorate a function manually without `@` syntax and return the wrapped function result.
#
# **Input format:** `value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 5
# ```
#
# **Sample Output:**
# ```python
# 25
# ```
#
# **Constraints:** Use a decorator that squares the function result.

# %%
def manual_decoration(value: int) -> int:
    pass

# %% [markdown]
# ## Q3. Wrapper With Args
#
# **Problem description:** Create a decorator wrapper using `*args` and `**kwargs` that passes arguments correctly to an addition function.
#
# **Input format:** `a: int, b: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# a = 4, b = 6
# ```
#
# **Sample Output:**
# ```python
# 10
# ```
#
# **Constraints:** Both values are integers.

# %%
def wrapper_with_args(a: int, b: int) -> int:
    pass

# %% [markdown]
# ## Q4. Return Original Result
#
# **Problem description:** Write a decorator that logs a message but still returns the original function result unchanged.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'python'
# ```
#
# **Sample Output:**
# ```python
# 'PYTHON'
# ```
#
# **Constraints:** The decorated function should convert the text to uppercase.

# %%
def return_original_result(text: str) -> str:
    pass

# %% [markdown]
# ## Q5. Metadata With Wraps
#
# **Problem description:** Use `functools.wraps` so a decorated function keeps its original `__name__`. Return that function name.
#
# **Input format:** `value: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# value = 7
# ```
#
# **Sample Output:**
# ```python
# 'double_value'
# ```
#
# **Constraints:** The decorated function should be named `double_value`.

# %%
def metadata_with_wraps(value: int) -> str:
    pass

# %% [markdown]
# ## Q6. Call Counter Once
#
# **Problem description:** Create a decorator that counts function calls and return the call count after one function call.
#
# **Input format:** `number: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# number = 9
# ```
#
# **Sample Output:**
# ```python
# 1
# ```
#
# **Constraints:** The decorated function is called exactly once.

# %%
def call_counter_once(number: int) -> int:
    pass

# %% [markdown]
# ## Q7. Validate Positive
#
# **Problem description:** Write a decorator that raises `ValueError` for non-positive numbers. Return the square root-like result for valid input or 'Invalid' for invalid input.
#
# **Input format:** `number: int`
#
# **Output format:** `str | float`
#
# **Sample Input:**
# ```python
# number = -4
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** Non-positive numbers should be rejected.

# %%
def validate_positive(number: int) -> str | float:
    pass

# %% [markdown]
# ## Q8. Uppercase Result Decorator
#
# **Problem description:** Write a decorator that converts the string result of a function to uppercase and return the final result.
#
# **Input format:** `name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'meera'
# ```
#
# **Sample Output:**
# ```python
# 'MEERA'
# ```
#
# **Constraints:** The function returns the input name as a string.

# %%
def uppercase_result_decorator(name: str) -> str:
    pass

# %% [markdown]
# ## Q9. Repeat Decorator Twice
#
# **Problem description:** Create a parameterized decorator that runs a function twice and return the final result of the second call.
#
# **Input format:** `value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 3
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** The function should add 1 to the input.

# %%
def repeat_decorator_twice(value: int) -> int:
    pass

# %% [markdown]
# ## Q10. Decorator On Method
#
# **Problem description:** Apply a decorator to a class method that doubles a number and return the result.
#
# **Input format:** `value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 8
# ```
#
# **Sample Output:**
# ```python
# 16
# ```
#
# **Constraints:** Use an instance method.

# %%
def decorator_on_method(value: int) -> int:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Execution Time Decorator
#
# **Problem description:** Write a timing decorator that measures a function call and still returns the function result. Return the sum of numbers from 1 to n.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# 15
# ```
#
# **Constraints:** You only need to return the function result, not the time.

# %%
def execution_time_decorator(n: int) -> int:
    pass

# %% [markdown]
# ## Q12. Call Counter Thrice
#
# **Problem description:** Create a decorator that counts calls and return the count after calling a decorated function three times.
#
# **Input format:** `values: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# values = [1, 2, 3]
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** The decorated function should still run normally.

# %%
def call_counter_thrice(values: list[int]) -> int:
    pass

# %% [markdown]
# ## Q13. Access Control Decorator
#
# **Problem description:** Write a decorator that allows access only when the user role is 'admin'. Return either the protected function result or 'Access denied'.
#
# **Input format:** `role: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# role = 'guest'
# ```
#
# **Sample Output:**
# ```python
# 'Access denied'
# ```
#
# **Constraints:** Any non-admin role should be blocked.

# %%
def access_control_decorator(role: str) -> str:
    pass

# %% [markdown]
# ## Q14. Exception Safe Decorator
#
# **Problem description:** Write a decorator that catches exceptions and returns a readable error message instead of crashing.
#
# **Input format:** `a: int, b: int`
#
# **Output format:** `str | float`
#
# **Sample Input:**
# ```python
# a = 10, b = 0
# ```
#
# **Sample Output:**
# ```python
# 'Error: division by zero'
# ```
#
# **Constraints:** Use a division function.

# %%
def exception_safe_decorator(a: int, b: int) -> str | float:
    pass

# %% [markdown]
# ## Q15. Result Cache Decorator
#
# **Problem description:** Create a caching decorator for a square function and return the results of calling it twice with the same input as a tuple.
#
# **Input format:** `number: int`
#
# **Output format:** `tuple[int, int]`
#
# **Sample Input:**
# ```python
# number = 6
# ```
#
# **Sample Output:**
# ```python
# (36, 36)
# ```
#
# **Constraints:** The second call should come from cache.

# %%
def result_cache_decorator(number: int) -> tuple[int, int]:
    pass

# %% [markdown]
# ## Q16. Multiple Decorators Order
#
# **Problem description:** Apply two decorators: one adds brackets around the result and one adds an exclamation mark. Return the final decorated string.
#
# **Input format:** `name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Ravi'
# ```
#
# **Sample Output:**
# ```python
# '[Hello, Ravi!]'
# ```
#
# **Constraints:** Decorator order must match the expected output.

# %%
def multiple_decorators_order(name: str) -> str:
    pass

# %% [markdown]
# ## Q17. Parameterized Prefix Decorator
#
# **Problem description:** Write a parameterized decorator that adds a chosen prefix to the string result of a function.
#
# **Input format:** `prefix: str, name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# prefix = 'User:', name = 'Asha'
# ```
#
# **Sample Output:**
# ```python
# 'User:Asha'
# ```
#
# **Constraints:** The original function should return the plain name.

# %%
def parameterized_prefix_decorator(prefix: str, name: str) -> str:
    pass

# %% [markdown]
# ## Q18. Require Non Empty String
#
# **Problem description:** Write a decorator that rejects blank strings after stripping spaces. Return 'Invalid' when the input is blank.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = '   '
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** Use string stripping before validation.

# %%
def require_non_empty_string(text: str) -> str:
    pass

# %% [markdown]
# ## Q19. Decorated Recursive Fibonacci
#
# **Problem description:** Decorate a recursive Fibonacci function with `lru_cache` and return the nth Fibonacci number.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 10
# ```
#
# **Sample Output:**
# ```python
# 55
# ```
#
# **Constraints:** 0 <= n <= 30.

# %%
def decorated_recursive_fibonacci(n: int) -> int:
    pass

# %% [markdown]
# ## Q20. Decorator With Keyword Args
#
# **Problem description:** Write a decorator that correctly handles keyword arguments for a function building a full name.
#
# **Input format:** `first: str, last: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# first = 'Asha', last = 'Sharma'
# ```
#
# **Sample Output:**
# ```python
# 'Asha Sharma'
# ```
#
# **Constraints:** Use keyword arguments when calling the function.

# %%
def decorator_with_keyword_args(first: str, last: str) -> str:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Decorator Factory Range Check
#
# **Problem description:** Write a parameterized decorator that accepts minimum and maximum values and validates that a number lies inside that inclusive range. Return 'Invalid' on failure.
#
# **Input format:** `number: int`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# number = 150
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** Use a range of 1 to 100.

# %%
def decorator_factory_range_check(number: int) -> str | int:
    pass

# %% [markdown]
# ## Q22. Stateful Average Decorator
#
# **Problem description:** Create a decorator that tracks all numeric results returned by a function and returns the latest result normally. After three calls, also return the running average from decorator state.
#
# **Input format:** `values: list[int]`
#
# **Output format:** `tuple[int, float]`
#
# **Sample Input:**
# ```python
# values = [10, 20, 30]
# ```
#
# **Sample Output:**
# ```python
# (30, 20.0)
# ```
#
# **Constraints:** The wrapped function should return each value unchanged.

# %%
def stateful_average_decorator(values: list[int]) -> tuple[int, float]:
    pass

# %% [markdown]
# ## Q23. Retry Decorator
#
# **Problem description:** Write a decorator that retries a function up to 3 times until it succeeds. Return the successful result.
#
# **Input format:** `target_attempt: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# target_attempt = 3
# ```
#
# **Sample Output:**
# ```python
# 'success'
# ```
#
# **Constraints:** The wrapped function should fail before the target attempt and succeed on it.

# %%
def retry_decorator(target_attempt: int) -> str:
    pass

# %% [markdown]
# ## Q24. Decorator Preserves Docstring
#
# **Problem description:** Use `wraps` to preserve a function docstring and return that docstring from the decorated function object.
#
# **Input format:** `value: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# value = 2
# ```
#
# **Sample Output:**
# ```python
# 'Return doubled value.'
# ```
#
# **Constraints:** The original function should have exactly that docstring.

# %%
def decorator_preserves_docstring(value: int) -> str:
    pass

# %% [markdown]
# ## Q25. Chained Validation Decorators
#
# **Problem description:** Use two decorators together: one checks that a number is positive and another checks that it is even. Return 'Invalid' if any check fails.
#
# **Input format:** `number: int`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# number = 7
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** Return the number itself when valid.

# %%
def chained_validation_decorators(number: int) -> str | int:
    pass

# %% [markdown]
# ## Q26. Decorator For List Result Sort
#
# **Problem description:** Write a decorator that sorts the list returned by a function before returning it.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [3, 1, 2]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3]
# ```
#
# **Constraints:** The original function may return the list unchanged.

# %%
def decorator_for_list_result_sort(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q27. Class Based Decorator
#
# **Problem description:** Implement a class-based decorator using `__call__` that multiplies the result of a function by a chosen factor.
#
# **Input format:** `value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 4
# ```
#
# **Sample Output:**
# ```python
# 12
# ```
#
# **Constraints:** Use a multiplication factor of 3.

# %%
def class_based_decorator(value: int) -> int:
    pass

# %% [markdown]
# ## Q28. Argument Type Check Decorator
#
# **Problem description:** Write a decorator that allows only integers as input for a doubling function. Return 'Invalid' for non-integer input.
#
# **Input format:** `value: object`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# value = '5'
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** The input may be any Python object.

# %%
def argument_type_check_decorator(value: object) -> str | int:
    pass

# %% [markdown]
# ## Q29. Audit Trail Decorator
#
# **Problem description:** Create a decorator that records function names into a shared log list every time the function is called. Return the audit log after two calls.
#
# **Input format:** `values: list[int]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# values = [2, 4]
# ```
#
# **Sample Output:**
# ```python
# ['process', 'process']
# ```
#
# **Constraints:** The decorated function should be named `process`.

# %%
def audit_trail_decorator(values: list[int]) -> list[str]:
    pass

# %% [markdown]
# ## Q30. Decorator On Static Method
#
# **Problem description:** Use a decorator on a static method that adds 5 to the returned result and return the final value.
#
# **Input format:** `value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# value = 10
# ```
#
# **Sample Output:**
# ```python
# 25
# ```
#
# **Constraints:** The original static method should return value + 10.

# %%
def decorator_on_static_method(value: int) -> int:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. API Permission Check
#
# **Problem description:** Write a decorator that blocks API access when a token is empty. Return 'Unauthorized' or the API result.
#
# **Input format:** `token: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# token = ''
# ```
#
# **Sample Output:**
# ```python
# 'Unauthorized'
# ```
#
# **Constraints:** Blank tokens are invalid.

# %%
def api_permission_check(token: str) -> str:
    pass

# %% [markdown]
# ## Q32. Query Logger
#
# **Problem description:** Write a decorator that stores called SQL-like query strings in a log list and return the log after processing all queries.
#
# **Input format:** `queries: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# queries = ['SELECT 1', 'SELECT 2']
# ```
#
# **Sample Output:**
# ```python
# ['SELECT 1', 'SELECT 2']
# ```
#
# **Constraints:** The query list may be empty.

# %%
def query_logger(queries: list[str]) -> list[str]:
    pass

# %% [markdown]
# ## Q33. Salary Validation Decorator
#
# **Problem description:** Write a decorator that rejects negative salaries before saving an employee salary. Return 'Invalid' on bad input or the saved salary otherwise.
#
# **Input format:** `salary: int`
#
# **Output format:** `str | int`
#
# **Sample Input:**
# ```python
# salary = -5000
# ```
#
# **Sample Output:**
# ```python
# 'Invalid'
# ```
#
# **Constraints:** Salary must be zero or greater.

# %%
def salary_validation_decorator(salary: int) -> str | int:
    pass

# %% [markdown]
# ## Q34. File Write Timer
#
# **Problem description:** Use a timing decorator around a function that writes text to a local file and returns the number of written characters.
#
# **Input format:** `text: str`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# text = 'hello'
# ```
#
# **Sample Output:**
# ```python
# 5
# ```
#
# **Constraints:** Use a local file in the current folder.

# %%
def file_write_timer(text: str) -> int:
    pass

# %% [markdown]
# ## Q35. Username Sanitizer Decorators
#
# **Problem description:** Combine decorators to validate a non-empty name and convert the final username result to lowercase. Return 'Invalid' for bad input.
#
# **Input format:** `name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = '  Asha Sharma  '
# ```
#
# **Sample Output:**
# ```python
# 'asha_sharma'
# ```
#
# **Constraints:** Strip outer spaces before building the username.

# %%
def username_sanitizer_decorators(name: str) -> str:
    pass
