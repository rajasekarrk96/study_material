# %% [markdown]
# # Python New Python Features Answers
#
# Each answer includes:
#
# - problem title
# - clean Python solution
# - step-by-step logic
# - dry run
# - test cases
# - time and space complexity notes when useful

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. F String Greeting
#
# **Problem:** Use an f-string to return `Hello, <name>`.
#
# **Step-by-step logic:**
# - Read the required input shape: `name: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The input is a non-empty string.
# - Return the final result in the required format `str`.

# %%
def f_string_greeting(name: str) -> str:
    # Build the greeting using an f-string.
    return f"Hello, {name}"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# name = 'Asha'
# ```
#
# **Expected Output**
# ```python
# 'Hello, Asha'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_name = "Asha"
expected_output = "Hello, Asha"
print(f_string_greeting(input_name))  # should match expected_output
assert f_string_greeting(input_name) == expected_output

# %% [markdown]
# ## Q2. F String Expression
#
# **Problem:** Use an f-string to return the square of a number inside a message string.
#
# **Step-by-step logic:**
# - Read the required input shape: `number: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The number is an integer.
# - Return the final result in the required format `str`.

# %%
def f_string_expression(number: int) -> str:
    # Return a message containing the square expression result.
    return f"Square is {number * number}"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# number = 4
# ```
#
# **Expected Output**
# ```python
# 'Square is 16'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_value = 4
expected_output = "Square is 16"
print(f_string_expression(input_value))  # should match expected_output
assert f_string_expression(input_value) == expected_output

# %% [markdown]
# ## Q3. Numeric Underscore Value
#
# **Problem:** Store a number using underscore separators and return its integer value.
#
# **Step-by-step logic:**
# - Read the required input shape: `unused: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return the numeric value only.
# - Return the final result in the required format `int`.

# %%
def numeric_underscore_value(unused: int) -> int:
    # Store a large number using underscore separators.
    value = 1_000_000

    # Return the numeric value.
    return value

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# unused = 0
# ```
#
# **Expected Output**
# ```python
# 1000000
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = 1000000
print(numeric_underscore_value(0))  # should match expected_output
assert numeric_underscore_value(0) == expected_output

# %% [markdown]
# ## Q4. Extended Unpack Middle
#
# **Problem:** Use extended iterable unpacking to return the middle values of a list.
#
# **Step-by-step logic:**
# - Read the required input shape: `items: list[int]`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The list has at least three items.
# - Return the final result in the required format `list[int]`.

# %%
def extended_unpack_middle(items: list[int]) -> list[int]:
    # Unpack the first and last values away from the middle part.
    first, *middle, last = items

    # Return only the middle values.
    return middle

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# items = [1, 2, 3, 4, 5]
# ```
#
# **Expected Output**
# ```python
# [2, 3, 4]
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_items = [1, 2, 3, 4, 5]
expected_output = [2, 3, 4]
print(extended_unpack_middle(input_items))  # should match expected_output
assert extended_unpack_middle(input_items) == expected_output

# %% [markdown]
# ## Q5. Dictionary Merge
#
# **Problem:** Use the dictionary merge operator `|` to combine two dictionaries and return the result.
#
# **Step-by-step logic:**
# - Read the required input shape: `a: dict, b: dict`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Later keys override earlier ones.
# - Return the final result in the required format `dict`.

# %%
def dictionary_merge(a: dict, b: dict) -> dict:
    # Merge both dictionaries using the modern operator.
    return a | b

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# a = {'x': 1}, b = {'y': 2}
# ```
#
# **Expected Output**
# ```python
# {'x': 1, 'y': 2}
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = {"x": 1, "y": 2}
print(dictionary_merge({"x": 1}, {"y": 2}))  # should match expected_output
assert dictionary_merge({"x": 1}, {"y": 2}) == expected_output

# %% [markdown]
# ## Q6. Walrus Length Check
#
# **Problem:** Use the walrus operator to assign the length of a string and return that length when it is greater than 3, otherwise return 0.
#
# **Step-by-step logic:**
# - Read the required input shape: `text: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The text may be empty.
# - Return the final result in the required format `int`.

# %%
def walrus_length_check(text: str) -> int:
    # Assign and test the text length in one expression.
    if (length := len(text)) > 3:
        return length
    return 0

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# text = 'python'
# ```
#
# **Expected Output**
# ```python
# 6
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_text = "python"
expected_output = 6
print(walrus_length_check(input_text))  # should match expected_output
assert walrus_length_check(input_text) == expected_output
assert walrus_length_check("abc") == 0

# %% [markdown]
# ## Q7. Typed Add Function
#
# **Problem:** Write a function with type hints that adds two integers and returns the result.
#
# **Step-by-step logic:**
# - Read the required input shape: `a: int, b: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Both inputs are integers.
# - Return the final result in the required format `int`.

# %%
def typed_add_function(a: int, b: int) -> int:
    # Return the sum of both typed integer inputs.
    return a + b

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# a = 2, b = 5
# ```
#
# **Expected Output**
# ```python
# 7
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = 7
print(typed_add_function(2, 5))  # should match expected_output
assert typed_add_function(2, 5) == expected_output

# %% [markdown]
# ## Q8. Union Type Describe
#
# **Problem:** Use a function annotated with `int | str` and return `Value: <input>`.
#
# **Step-by-step logic:**
# - Read the required input shape: `value: int | str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The input is either an integer or a string.
# - Return the final result in the required format `str`.

# %%
def union_type_describe(value: int | str) -> str:
    # Return a description string using the provided value.
    return f"Value: {value}"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# value = 'python'
# ```
#
# **Expected Output**
# ```python
# 'Value: python'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_value = "python"
expected_output = "Value: python"
print(union_type_describe(input_value))  # should match expected_output
assert union_type_describe(input_value) == expected_output

# %% [markdown]
# ## Q9. Dataclass Create
#
# **Problem:** Create a dataclass `Student` with `name` and `score`, build one object, and return the score.
#
# **Step-by-step logic:**
# - Read the required input shape: `name: str, score: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return the numeric score field.
# - Return the final result in the required format `int`.

# %%
def dataclass_create(name: str, score: int) -> int:
    # Import the dataclass decorator.
    from dataclasses import dataclass

    # Create a simple data class.
    @dataclass
    class Student:
        # Store the student name.
        name: str

        # Store the student score.
        score: int

    # Build the object and return its score field.
    return Student(name, score).score

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# name = 'Asha', score = 95
# ```
#
# **Expected Output**
# ```python
# 95
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = 95
print(dataclass_create("Asha", 95))  # should match expected_output
assert dataclass_create("Asha", 95) == expected_output

# %% [markdown]
# ## Q10. Pathlib Join
#
# **Problem:** Use `pathlib.Path` to join folder and file parts and return the resulting path string.
#
# **Step-by-step logic:**
# - Read the required input shape: `folder: str, filename: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Use `Path(folder) / filename`.
# - Return the final result in the required format `str`.

# %%
def pathlib_join(folder: str, filename: str) -> str:
    # Import Path from pathlib.
    from pathlib import Path

    # Join the path parts and convert the result to a string.
    return str(Path(folder) / filename)

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# folder = 'reports', filename = 'a.txt'
# ```
#
# **Expected Output**
# ```python
# 'reports\\a.txt' or platform equivalent
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
result = pathlib_join("reports", "a.txt")
print(result)  # should be the joined path
assert result.endswith("reports\\a.txt") or result.endswith("reports/a.txt")

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Dataclass Default Status
#
# **Problem:** Create a dataclass with a default `status='pending'` field and return that status for a new object.
#
# **Step-by-step logic:**
# - Read the required input shape: `title: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Use a default field value.
# - Return the final result in the required format `str`.

# %%
def dataclass_default_status(title: str) -> str:
    # Import the dataclass decorator.
    from dataclasses import dataclass

    # Define a data class with a default status.
    @dataclass
    class Task:
        # Store the title.
        title: str

        # Give every new task a default status.
        status: str = "pending"

    # Return the default status from a new object.
    return Task(title).status

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# title = 'Read notebook'
# ```
#
# **Expected Output**
# ```python
# 'pending'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_title = "Read notebook"
expected_output = "pending"
print(dataclass_default_status(input_title))  # should match expected_output
assert dataclass_default_status(input_title) == expected_output

# %% [markdown]
# ## Q12. Keyword Only Name
#
# **Problem:** Define a function with keyword-only parameters `first` and `last` and return the full name.
#
# **Step-by-step logic:**
# - Read the required input shape: `first: str, last: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Call the function with keyword arguments.
# - Return the final result in the required format `str`.

# %%
def keyword_only_name(first: str, last: str) -> str:
    # Define a function with keyword-only parameters.
    def build_name(*, first: str, last: str) -> str:
        # Return the full name.
        return f"{first} {last}"

    # Call the function with explicit keywords.
    return build_name(first=first, last=last)

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# first = 'Asha', last = 'Sharma'
# ```
#
# **Expected Output**
# ```python
# 'Asha Sharma'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = "Asha Sharma"
print(keyword_only_name("Asha", "Sharma"))  # should match expected_output
assert keyword_only_name("Asha", "Sharma") == expected_output

# %% [markdown]
# ## Q13. Positional Only Divide
#
# **Problem:** Define a function with positional-only parameters and return the division result.
#
# **Step-by-step logic:**
# - Read the required input shape: `a: int, b: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Use `/` in the function signature.
# - Return the final result in the required format `float`.

# %%
def positional_only_divide(a: int, b: int) -> float:
    # Define a function with positional-only parameters.
    def divide(x: int, y: int, /) -> float:
        # Return the division result.
        return x / y

    # Call the function positionally.
    return divide(a, b)

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# a = 10, b = 2
# ```
#
# **Expected Output**
# ```python
# 5.0
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = 5.0
print(positional_only_divide(10, 2))  # should match expected_output
assert positional_only_divide(10, 2) == expected_output

# %% [markdown]
# ## Q14. Match Command
#
# **Problem:** Use structural pattern matching to return `'Starting'` for `'start'`, `'Stopping'` for `'stop'`, and `'Unknown'` otherwise.
#
# **Step-by-step logic:**
# - Read the required input shape: `command: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Handle unmatched commands with `_`.
# - Return the final result in the required format `str`.

# %%
def match_command(command: str) -> str:
    # Match the incoming command against known cases.
    match command:
        case "start":
            return "Starting"
        case "stop":
            return "Stopping"
        case _:
            return "Unknown"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# command = 'start'
# ```
#
# **Expected Output**
# ```python
# 'Starting'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(match_command("start"))  # should match expected_output
assert match_command("start") == "Starting"
assert match_command("pause") == "Unknown"

# %% [markdown]
# ## Q15. Match Tuple Event
#
# **Problem:** Use pattern matching on a tuple like `('move', x, y)` and return `Move to x, y`.
#
# **Step-by-step logic:**
# - Read the required input shape: `event: tuple`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return `'Unknown event'` for other patterns.
# - Return the final result in the required format `str`.

# %%
def match_tuple_event(event: tuple) -> str:
    # Match the tuple shape and extract coordinates when possible.
    match event:
        case ("move", x, y):
            return f"Move to {x}, {y}"
        case _:
            return "Unknown event"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# event = ('move', 10, 20)
# ```
#
# **Expected Output**
# ```python
# 'Move to 10, 20'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_event = ("move", 10, 20)
expected_output = "Move to 10, 20"
print(match_tuple_event(input_event))  # should match expected_output
assert match_tuple_event(input_event) == expected_output
assert match_tuple_event(("stop",)) == "Unknown event"

# %% [markdown]
# ## Q16. Zip Strict Pairs
#
# **Problem:** Use `zip(strict=True)` to pair two equal-length lists and return the list of pairs.
#
# **Step-by-step logic:**
# - Read the required input shape: `names: list[str], scores: list[int]`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Assume equal lengths for this task.
# - Return the final result in the required format `list[tuple[str, int]]`.

# %%
def zip_strict_pairs(names: list[str], scores: list[int]) -> list[tuple[str, int]]:
    # Pair both lists with strict mode enabled.
    return list(zip(names, scores, strict=True))

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# names = ['A', 'B'], scores = [90, 80]
# ```
#
# **Expected Output**
# ```python
# [('A', 90), ('B', 80)]
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = [("A", 90), ("B", 80)]
print(zip_strict_pairs(["A", "B"], [90, 80]))  # should match expected_output
assert zip_strict_pairs(["A", "B"], [90, 80]) == expected_output

# %% [markdown]
# ## Q17. Dataclass Mutable Default Safe
#
# **Problem:** Use `field(default_factory=list)` in a dataclass and return the default empty list from a new object.
#
# **Step-by-step logic:**
# - Read the required input shape: `unused: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Avoid shared mutable defaults.
# - Return the final result in the required format `list[str]`.

# %%
def dataclass_mutable_default_safe(unused: int) -> list[str]:
    # Import dataclass and field.
    from dataclasses import dataclass, field

    # Define a class with a safe list default.
    @dataclass
    class Bag:
        # Create a fresh list for every object.
        items: list[str] = field(default_factory=list)

    # Return the default list from a new object.
    return Bag().items

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# unused = 0
# ```
#
# **Expected Output**
# ```python
# []
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = []
print(dataclass_mutable_default_safe(0))  # should match expected_output
assert dataclass_mutable_default_safe(0) == expected_output

# %% [markdown]
# ## Q18. Pathlib Suffix
#
# **Problem:** Use `Path.suffix` to return the file extension of a path string.
#
# **Step-by-step logic:**
# - Read the required input shape: `path_text: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The path points to a file.
# - Return the final result in the required format `str`.

# %%
def pathlib_suffix(path_text: str) -> str:
    # Import Path from pathlib.
    from pathlib import Path

    # Return the suffix of the path.
    return Path(path_text).suffix

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# path_text = 'notes/report.txt'
# ```
#
# **Expected Output**
# ```python
# '.txt'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_path = "notes/report.txt"
expected_output = ".txt"
print(pathlib_suffix(input_path))  # should match expected_output
assert pathlib_suffix(input_path) == expected_output

# %% [markdown]
# ## Q19. Dictionary Merge Override
#
# **Problem:** Merge two dictionaries with overlapping keys using `|` and return the merged result.
#
# **Step-by-step logic:**
# - Read the required input shape: `a: dict, b: dict`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Keys from the right dictionary override left values.
# - Return the final result in the required format `dict`.

# %%
def dictionary_merge_override(a: dict, b: dict) -> dict:
    # Merge dictionaries so right-side keys override left-side keys.
    return a | b

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# a = {'x': 1}, b = {'x': 5, 'y': 2}
# ```
#
# **Expected Output**
# ```python
# {'x': 5, 'y': 2}
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = {"x": 5, "y": 2}
print(dictionary_merge_override({"x": 1}, {"x": 5, "y": 2}))  # should match expected_output
assert dictionary_merge_override({"x": 1}, {"x": 5, "y": 2}) == expected_output

# %% [markdown]
# ## Q20. Walrus In Loop
#
# **Problem:** Use the walrus operator in a loop-like pattern to collect lengths of non-empty words and return the list of lengths.
#
# **Step-by-step logic:**
# - Read the required input shape: `words: list[str]`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Ignore empty strings.
# - Return the final result in the required format `list[int]`.

# %%
def walrus_in_loop(words: list[str]) -> list[int]:
    # Store lengths of non-empty words here.
    lengths = []

    # Process every word in the list.
    for word in words:
        # Assign the length and check the stripped word at the same time.
        if (size := len(word.strip())) > 0:
            lengths.append(size)

    # Return the collected lengths.
    return lengths

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# words = ['python', '', 'sql']
# ```
#
# **Expected Output**
# ```python
# [6, 3]
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_words = ["python", "", "sql"]
expected_output = [6, 3]
print(walrus_in_loop(input_words))  # should match expected_output
assert walrus_in_loop(input_words) == expected_output

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Dataclass Sort By Score
#
# **Problem:** Use a dataclass to represent students, then return student names sorted by score descending.
#
# **Step-by-step logic:**
# - Read the required input shape: `records: list[tuple[str, int]]`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The list may be empty.
# - Return the final result in the required format `list[str]`.

# %%
def dataclass_sort_by_score(records: list[tuple[str, int]]) -> list[str]:
    # Import the dataclass decorator.
    from dataclasses import dataclass

    # Define a student data class.
    @dataclass
    class Student:
        # Store the student name.
        name: str

        # Store the student score.
        score: int

    # Convert tuples into Student objects.
    students = [Student(name, score) for name, score in records]

    # Sort by score descending and return only names.
    return [student.name for student in sorted(students, key=lambda item: item.score, reverse=True)]

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# records = [('A', 80), ('B', 95), ('C', 88)]
# ```
#
# **Expected Output**
# ```python
# ['B', 'C', 'A']
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_records = [("A", 80), ("B", 95), ("C", 88)]
expected_output = ["B", "C", "A"]
print(dataclass_sort_by_score(input_records))  # should match expected_output
assert dataclass_sort_by_score(input_records) == expected_output

# %% [markdown]
# ## Q22. Pattern Match Point
#
# **Problem:** Use structural pattern matching on a dictionary like `{'type': 'point', 'x': 3, 'y': 4}` and return `Point(3, 4)`.
#
# **Step-by-step logic:**
# - Read the required input shape: `data: dict`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return `'Unknown'` for other structures.
# - Return the final result in the required format `str`.

# %%
def pattern_match_point(data: dict) -> str:
    # Match the dictionary structure against the point pattern.
    match data:
        case {"type": "point", "x": x, "y": y}:
            return f"Point({x}, {y})"
        case _:
            return "Unknown"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# data = {'type': 'point', 'x': 3, 'y': 4}
# ```
#
# **Expected Output**
# ```python
# 'Point(3, 4)'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_data = {"type": "point", "x": 3, "y": 4}
expected_output = "Point(3, 4)"
print(pattern_match_point(input_data))  # should match expected_output
assert pattern_match_point(input_data) == expected_output
assert pattern_match_point({"type": "circle"}) == "Unknown"

# %% [markdown]
# ## Q23. Modern Type Hint Function
#
# **Problem:** Write a function with the return type `list[int]` that returns squares of input integers.
#
# **Step-by-step logic:**
# - Read the required input shape: `items: list[int]`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: The list may be empty.
# - Return the final result in the required format `list[int]`.

# %%
def modern_type_hint_function(items: list[int]) -> list[int]:
    # Return squares of all input integers.
    return [item * item for item in items]

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# items = [1, 2, 3]
# ```
#
# **Expected Output**
# ```python
# [1, 4, 9]
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_items = [1, 2, 3]
expected_output = [1, 4, 9]
print(modern_type_hint_function(input_items))  # should match expected_output
assert modern_type_hint_function(input_items) == expected_output

# %% [markdown]
# ## Q24. Pathlib Read Write
#
# **Problem:** Use `Path.write_text` and `Path.read_text` to save and read text from a local file, then return the read text.
#
# **Step-by-step logic:**
# - Read the required input shape: `text: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Use a local file in the current folder.
# - Return the final result in the required format `str`.

# %%
def pathlib_read_write(text: str) -> str:
    # Import Path from pathlib.
    from pathlib import Path

    # Choose a local file path.
    path = Path("pathlib_read_write_demo.txt")

    # Save the text to the file.
    path.write_text(text, encoding="utf-8")

    # Read the text back and return it.
    return path.read_text(encoding="utf-8")

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# text = 'hello'
# ```
#
# **Expected Output**
# ```python
# 'hello'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_text = "hello"
expected_output = "hello"
print(pathlib_read_write(input_text))  # should match expected_output
assert pathlib_read_write(input_text) == expected_output

# %% [markdown]
# ## Q25. Match Role Access
#
# **Problem:** Use pattern matching on a role string to return `'full'` for `'admin'`, `'limited'` for `'user'`, and `'none'` otherwise.
#
# **Step-by-step logic:**
# - Read the required input shape: `role: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Handle unmatched roles with `_`.
# - Return the final result in the required format `str`.

# %%
def match_role_access(role: str) -> str:
    # Match the role value to a known access level.
    match role:
        case "admin":
            return "full"
        case "user":
            return "limited"
        case _:
            return "none"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# role = 'user'
# ```
#
# **Expected Output**
# ```python
# 'limited'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(match_role_access("user"))  # should match expected_output
assert match_role_access("user") == "limited"
assert match_role_access("guest") == "none"

# %% [markdown]
# ## Q26. Dataclass As Dict Like Access
#
# **Problem:** Create a dataclass with `name` and `age`, then return a normal dictionary using those values.
#
# **Step-by-step logic:**
# - Read the required input shape: `name: str, age: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return a plain dictionary.
# - Return the final result in the required format `dict[str, object]`.

# %%
def dataclass_as_dict_like_access(name: str, age: int) -> dict[str, object]:
    # Import the dataclass decorator.
    from dataclasses import dataclass

    # Define a small person data class.
    @dataclass
    class Person:
        # Store the name.
        name: str

        # Store the age.
        age: int

    # Create the object and return a plain dictionary.
    person = Person(name, age)
    return {"name": person.name, "age": person.age}

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# name = 'Asha', age = 22
# ```
#
# **Expected Output**
# ```python
# {'name': 'Asha', 'age': 22}
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = {"name": "Asha", "age": 22}
print(dataclass_as_dict_like_access("Asha", 22))  # should match expected_output
assert dataclass_as_dict_like_access("Asha", 22) == expected_output

# %% [markdown]
# ## Q27. Union Type Safe Parse
#
# **Problem:** Write a function annotated to return `int | None` that tries to parse a string to int and returns None on failure.
#
# **Step-by-step logic:**
# - Read the required input shape: `text: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return None for invalid integers.
# - Return the final result in the required format `int | None`.

# %%
def union_type_safe_parse(text: str) -> int | None:
    # Try converting the text into an integer.
    try:
        return int(text)
    except ValueError:
        return None

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# text = '42'
# ```
#
# **Expected Output**
# ```python
# 42
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(union_type_safe_parse("42"))  # should match expected_output
assert union_type_safe_parse("42") == 42
assert union_type_safe_parse("abc") is None

# %% [markdown]
# ## Q28. F String Table Row
#
# **Problem:** Use an f-string with width formatting to return a row like `'Asha      | 95'`.
#
# **Step-by-step logic:**
# - Read the required input shape: `name: str, score: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Left-align the name in width 10.
# - Return the final result in the required format `str`.

# %%
def f_string_table_row(name: str, score: int) -> str:
    # Use width formatting inside an f-string.
    return f"{name:<10} | {score}"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# name = 'Asha', score = 95
# ```
#
# **Expected Output**
# ```python
# 'Asha      | 95'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_name = "Asha"
expected_output = "Asha       | 95"
print(f_string_table_row(input_name, 95))  # should match expected_output
assert f_string_table_row(input_name, 95) == expected_output

# %% [markdown]
# ## Q29. Walrus Filter Values
#
# **Problem:** Use the walrus operator to collect only strings whose stripped length is at least 3, and return the cleaned strings.
#
# **Step-by-step logic:**
# - Read the required input shape: `items: list[str]`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Return stripped values only.
# - Return the final result in the required format `list[str]`.

# %%
def walrus_filter_values(items: list[str]) -> list[str]:
    # Store cleaned valid values here.
    cleaned = []

    # Process each input string.
    for item in items:
        # Assign the stripped value and test its length.
        if len(stripped := item.strip()) >= 3:
            cleaned.append(stripped)

    # Return the filtered cleaned values.
    return cleaned

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# items = ['  py ', ' a ', ' sql ']
# ```
#
# **Expected Output**
# ```python
# ['py', 'sql']
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_items = ["  py ", " a ", " sql "]
expected_output = ["py", "sql"]
print(walrus_filter_values(input_items))  # should match expected_output
assert walrus_filter_values(input_items) == expected_output

# %% [markdown]
# ## Q30. Keyword Only Config
#
# **Problem:** Define a function with keyword-only parameters `host` and `port` and return `host:port`.
#
# **Step-by-step logic:**
# - Read the required input shape: `host: str, port: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Call with keyword arguments.
# - Return the final result in the required format `str`.

# %%
def keyword_only_config(host: str, port: int) -> str:
    # Define a function with keyword-only parameters.
    def build_config(*, host: str, port: int) -> str:
        # Return the host and port in one string.
        return f"{host}:{port}"

    # Call the function with explicit keywords.
    return build_config(host=host, port=port)

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# host = 'localhost', port = 8000
# ```
#
# **Expected Output**
# ```python
# 'localhost:8000'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = "localhost:8000"
print(keyword_only_config("localhost", 8000))  # should match expected_output
assert keyword_only_config("localhost", 8000) == expected_output

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. User Summary Dataclass
#
# **Problem:** Create a dataclass for a user with `name` and `city`, then return a formatted summary string using an f-string.
#
# **Step-by-step logic:**
# - Read the required input shape: `name: str, city: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Use a dataclass and an f-string.
# - Return the final result in the required format `str`.

# %%
def user_summary_dataclass(name: str, city: str) -> str:
    # Import the dataclass decorator.
    from dataclasses import dataclass

    # Define a small user data class.
    @dataclass
    class User:
        # Store the user name.
        name: str

        # Store the city name.
        city: str

    # Create the user object.
    user = User(name, city)

    # Return a formatted summary with an f-string.
    return f"{user.name} lives in {user.city}"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# name = 'Asha', city = 'Pune'
# ```
#
# **Expected Output**
# ```python
# 'Asha lives in Pune'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = "Asha lives in Pune"
print(user_summary_dataclass("Asha", "Pune"))  # should match expected_output
assert user_summary_dataclass("Asha", "Pune") == expected_output

# %% [markdown]
# ## Q32. Modern Report Path
#
# **Problem:** Use `pathlib` to build a report path from folder, topic, and extension and return the path string.
#
# **Step-by-step logic:**
# - Read the required input shape: `folder: str, topic: str, extension: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Build the filename from topic + extension.
# - Return the final result in the required format `str`.

# %%
def modern_report_path(folder: str, topic: str, extension: str) -> str:
    # Import Path from pathlib.
    from pathlib import Path

    # Build the file path from parts.
    path = Path(folder) / f"{topic}{extension}"

    # Return the path as a string.
    return str(path)

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# folder = 'reports', topic = 'python', extension = '.txt'
# ```
#
# **Expected Output**
# ```python
# 'reports\\python.txt' or platform equivalent
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
result = modern_report_path("reports", "python", ".txt")
print(result)  # should be the built path
assert result.endswith("reports\\python.txt") or result.endswith("reports/python.txt")

# %% [markdown]
# ## Q33. Pattern Match API Status
#
# **Problem:** Use pattern matching on integer status codes to return `'success'` for 200, `'not found'` for 404, and `'error'` otherwise.
#
# **Step-by-step logic:**
# - Read the required input shape: `status: int`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Handle unmatched values with `_`.
# - Return the final result in the required format `str`.

# %%
def pattern_match_api_status(status: int) -> str:
    # Match known API status codes.
    match status:
        case 200:
            return "success"
        case 404:
            return "not found"
        case _:
            return "error"

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# status = 404
# ```
#
# **Expected Output**
# ```python
# 'not found'
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(pattern_match_api_status(404))  # should match expected_output
assert pattern_match_api_status(404) == "not found"
assert pattern_match_api_status(500) == "error"

# %% [markdown]
# ## Q34. Safe Settings Merge
#
# **Problem:** Merge default settings and user settings with the modern dictionary merge operator and return the result.
#
# **Step-by-step logic:**
# - Read the required input shape: `defaults: dict, user: dict`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: User settings should override defaults.
# - Return the final result in the required format `dict`.

# %%
def safe_settings_merge(defaults: dict, user: dict) -> dict:
    # Merge settings so user values override defaults.
    return defaults | user

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# defaults = {'theme': 'light', 'font': 'medium'}, user = {'font': 'large'}
# ```
#
# **Expected Output**
# ```python
# {'theme': 'light', 'font': 'large'}
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_defaults = {"theme": "light", "font": "medium"}
input_user = {"font": "large"}
expected_output = {"theme": "light", "font": "large"}
print(safe_settings_merge(input_defaults, input_user))  # should match expected_output
assert safe_settings_merge(input_defaults, input_user) == expected_output

# %% [markdown]
# ## Q35. Dataclass Task List
#
# **Problem:** Create a dataclass task model with a safe default tags list, add one tag, and return the tags list.
#
# **Step-by-step logic:**
# - Read the required input shape: `title: str, tag: str`.
# - Choose the modern Python feature that best fits the task.
# - Keep the code clear instead of using new syntax only for style.
# - Handle the constraint carefully: Use `field(default_factory=list)`.
# - Return the final result in the required format `list[str]`.

# %%
def dataclass_task_list(title: str, tag: str) -> list[str]:
    # Import dataclass and field.
    from dataclasses import dataclass, field

    # Define a task model with a safe tags default.
    @dataclass
    class Task:
        # Store the task title.
        title: str

        # Give each task its own tags list.
        tags: list[str] = field(default_factory=list)

    # Create a new task object.
    task = Task(title)

    # Add the provided tag.
    task.tags.append(tag)

    # Return the final tags list.
    return task.tags

# Time Complexity: depends on the number of elements processed or the simple operations used above.
# Space Complexity: depends on extra lists, dataclass objects, merged dictionaries, or path/file work above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# title = 'Study', tag = 'python'
# ```
#
# **Expected Output**
# ```python
# ['python']
# ```
#
# Dry run idea:
# - Start with the given input values.
# - Follow how the modern feature changes formatting, structure, typing, or control flow.
# - Track important intermediate values step by step.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = ["python"]
print(dataclass_task_list("Study", "python"))  # should match expected_output
assert dataclass_task_list("Study", "python") == expected_output
