# %% [markdown]
# # Database SQLite3 Questions
#
# This notebook contains:
# - Section 1: Basic Questions
# - Section 2: Intermediate Questions
# - Section 3: Advanced Questions
# - Section 4: Real-world Problems
#
# No solutions are included here.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ## Q1. Open SQLite Memory DB
#
# **Problem Description**
# Create an in-memory SQLite database and print a success message.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print a success message.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Connected to SQLite memory database`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q2. Create Students Table
#
# **Problem Description**
# Create a students table with id, name, and age.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print `Table created`.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Table created`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q3. Insert One Student
#
# **Problem Description**
# Insert one student row using placeholders.
#
# **Input Format**
# A tuple such as `("Asha", 20)`.
#
# **Output Format**
# Print inserted row count.
#
# **Sample Input**
# `("Asha", 20)`
#
# **Sample Output**
# `1`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q4. Fetch One Row
#
# **Problem Description**
# Fetch one row from a students table.
#
# **Input Format**
# A table with at least one row.
#
# **Output Format**
# Print one row tuple.
#
# **Sample Input**
# `[(1, "Asha")]`
#
# **Sample Output**
# `(1, "Asha")`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q5. Fetch All Names
#
# **Problem Description**
# Read all student names and print them as a list.
#
# **Input Format**
# Existing rows in a table.
#
# **Output Format**
# Print a Python list.
#
# **Sample Input**
# `[(1, "Asha"), (2, "Ravi")]`
#
# **Sample Output**
# `['Asha', 'Ravi']`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q6. Count Rows
#
# **Problem Description**
# Count how many rows are in a table.
#
# **Input Format**
# Existing rows.
#
# **Output Format**
# Print one integer count.
#
# **Sample Input**
# `3 rows`
#
# **Sample Output**
# `3`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q7. Update One Score
#
# **Problem Description**
# Update one student's score using a WHERE clause.
#
# **Input Format**
# Student name and new score.
#
# **Output Format**
# Print updated row count.
#
# **Sample Input**
# `name="Asha", score=95`
#
# **Sample Output**
# `1`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q8. Delete One Row
#
# **Problem Description**
# Delete one row by id.
#
# **Input Format**
# Student id.
#
# **Output Format**
# Print deleted row count.
#
# **Sample Input**
# `id=2`
#
# **Sample Output**
# `1`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q9. Use Default Value
#
# **Problem Description**
# Create a table with a default score and insert only a name.
#
# **Input Format**
# A student name.
#
# **Output Format**
# Print the inserted row with the default value.
#
# **Sample Input**
# `name="Mina"`
#
# **Sample Output**
# `("Mina", 0)`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q10. Close Resources
#
# **Problem Description**
# Show how to close cursor and connection objects safely.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print `Closed successfully`.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Closed successfully`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ## Q11. Batch Insert
#
# **Problem Description**
# Insert multiple rows using `executemany()`.
#
# **Input Format**
# A list of tuples.
#
# **Output Format**
# Print how many rows were inserted.
#
# **Sample Input**
# `[("Asha", 20), ("Ravi", 21)]`
#
# **Sample Output**
# `2`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q12. Use fetchmany
#
# **Problem Description**
# Read rows in batches using `fetchmany(2)`.
#
# **Input Format**
# A table with at least four rows.
#
# **Output Format**
# Print batch results.
#
# **Sample Input**
# `4 rows`
#
# **Sample Output**
# `Two rows per batch`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q13. Duplicate Email Rollback
#
# **Problem Description**
# Roll back a transaction when duplicate email insertion fails.
#
# **Input Format**
# Two inserts with the same email.
#
# **Output Format**
# Print an error and final row count.
#
# **Sample Input**
# `same email twice`
#
# **Sample Output**
# `Integrity error` and final count `1`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q14. Use sqlite3.Row
#
# **Problem Description**
# Access row data by column name.
#
# **Input Format**
# A products table with one row.
#
# **Output Format**
# Print the product name.
#
# **Sample Input**
# `("Notebook", 45.5)`
#
# **Sample Output**
# `Notebook`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q15. Join Students and Marks
#
# **Problem Description**
# Join students and marks tables and print related rows.
#
# **Input Format**
# Students and marks tables.
#
# **Output Format**
# Print name, subject, and score rows.
#
# **Sample Input**
# `sample data`
#
# **Sample Output**
# `[("Asha", "Python", 92)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q16. Average Score Report
#
# **Problem Description**
# Calculate average score per student.
#
# **Input Format**
# A marks table with multiple rows per student.
#
# **Output Format**
# Print student and average score.
#
# **Sample Input**
# `sample marks`
#
# **Sample Output**
# `[("Asha", 90.5)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q17. Safe Search by Name
#
# **Problem Description**
# Search for a student using a parameterized SELECT query.
#
# **Input Format**
# A target name string.
#
# **Output Format**
# Print the row or `None`.
#
# **Sample Input**
# `name="Ravi"`
#
# **Sample Output**
# `("Ravi", 90)` or `None`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q18. Reusable Helper Function
#
# **Problem Description**
# Write a helper that prepares a SQLite database and returns a connection.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print `Database ready`.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Database ready`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q19. Constraint Check Example
#
# **Problem Description**
# Create a table with a CHECK constraint and show a failing insert.
#
# **Input Format**
# An age lower than the allowed minimum.
#
# **Output Format**
# Print a constraint error.
#
# **Sample Input**
# `age=16`
#
# **Sample Output**
# `Constraint prevented insert`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q20. Pagination Query
#
# **Problem Description**
# Fetch page 2 with page size 3 using LIMIT and OFFSET.
#
# **Input Format**
# Page size and page number.
#
# **Output Format**
# Print the selected page rows.
#
# **Sample Input**
# `page_size=3, page_number=2`
#
# **Sample Output**
# `3 rows from page 2`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ## Q21. Context Manager SQLite Helper
#
# **Problem Description**
# Use `with sqlite3.connect(...)` to insert and verify one row.
#
# **Input Format**
# A database path and one student row.
#
# **Output Format**
# Print the saved row.
#
# **Sample Input**
# `("Lina", 94)`
#
# **Sample Output**
# `("Lina", 94)`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q22. SQLite Upsert
#
# **Problem Description**
# Insert a row and update it on conflict.
#
# **Input Format**
# A product name and price.
#
# **Output Format**
# Print the final row.
#
# **Sample Input**
# `name="Pen", price=18`
#
# **Sample Output**
# `("Pen", 18)`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q23. Transfer Transaction
#
# **Problem Description**
# Transfer value between two accounts using a transaction.
#
# **Input Format**
# Sender, receiver, amount.
#
# **Output Format**
# Print final balances.
#
# **Sample Input**
# `Asha, Bharat, 200`
#
# **Sample Output**
# `[("Asha", 800), ("Bharat", 700)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q24. Export Rows as Dictionaries
#
# **Problem Description**
# Convert query results into a list of dictionaries.
#
# **Input Format**
# A table with rows.
#
# **Output Format**
# Print list of dictionaries.
#
# **Sample Input**
# `existing rows`
#
# **Sample Output**
# `[{'name':'Asha','score':92}]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q25. Import Dictionary Data
#
# **Problem Description**
# Load a list of dictionaries into SQLite using `executemany()`.
#
# **Input Format**
# A list of dictionaries.
#
# **Output Format**
# Print inserted row count.
#
# **Sample Input**
# `[{'name':'Asha','score':92}]`
#
# **Sample Output**
# `1`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q26. Report Top Students
#
# **Problem Description**
# Create a reusable function `get_top_students(min_score)`.
#
# **Input Format**
# A minimum score integer.
#
# **Output Format**
# Print all matching rows.
#
# **Sample Input**
# `90`
#
# **Sample Output**
# `[("Asha", 95), ("Mina", 91)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q27. Search with LIKE
#
# **Problem Description**
# Search names using the SQL LIKE operator.
#
# **Input Format**
# A prefix string.
#
# **Output Format**
# Print all matching rows.
#
# **Sample Input**
# `prefix="A%"`
#
# **Sample Output**
# `[("Asha", 92)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q28. Aggregate Summary
#
# **Problem Description**
# Print total students, average score, minimum score, and maximum score.
#
# **Input Format**
# A table with score rows.
#
# **Output Format**
# Print one summary row.
#
# **Sample Input**
# `sample rows`
#
# **Sample Output**
# `(count, avg, min, max)`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q29. Inventory Sales Tracker
#
# **Problem Description**
# Reduce stock after a sale and print before/after stock.
#
# **Input Format**
# Product name, stock, sold quantity.
#
# **Output Format**
# Print stock before and after the sale.
#
# **Sample Input**
# `Notebook, 50, 3`
#
# **Sample Output**
# `Before: 50` and `After: 47`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q30. Attendance Report
#
# **Problem Description**
# Store attendance records and print grouped attendance counts.
#
# **Input Format**
# Attendance rows with name and date.
#
# **Output Format**
# Print grouped counts.
#
# **Sample Input**
# `attendance rows`
#
# **Sample Output**
# `[("Asha", 5), ("Ravi", 3)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ## Q31. User Registration System
#
# **Problem Description**
# Store users with unique emails and reject duplicates cleanly.
#
# **Input Format**
# Name and email for each attempt.
#
# **Output Format**
# Print registration and duplicate messages.
#
# **Sample Input**
# `duplicate email attempts`
#
# **Sample Output**
# `Registered` then `Duplicate email`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q32. Library Borrow Report
#
# **Problem Description**
# Create books and borrow logs and show active borrowings.
#
# **Input Format**
# Books table and borrow log table.
#
# **Output Format**
# Print current borrowed rows.
#
# **Sample Input**
# `sample book and borrow data`
#
# **Sample Output**
# `[("Python 101", "Asha")]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q33. Student Result Dashboard
#
# **Problem Description**
# Store student scores and print the top scoring students.
#
# **Input Format**
# Student rows with scores.
#
# **Output Format**
# Print rows ordered by score descending.
#
# **Sample Input**
# `sample student rows`
#
# **Sample Output**
# `[("Mina", 95), ("Asha", 92)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q34. Local Expense Tracker
#
# **Problem Description**
# Store expense entries with category and amount and print category totals.
#
# **Input Format**
# Expense rows.
#
# **Output Format**
# Print grouped totals per category.
#
# **Sample Input**
# `sample expenses`
#
# **Sample Output**
# `[("Food", 500), ("Travel", 300)]`
#
# **Constraints**
# Use safe parameterized queries where applicable.

# %% [markdown]
# ## Q35. SQLite Prototype Readiness
#
# **Problem Description**
# Write a readiness check that verifies the database file can be created and queried.
#
# **Input Format**
# A local database filename.
#
# **Output Format**
# Print `Ready` or an error message.
#
# **Sample Input**
# `app.db`
#
# **Sample Output**
# `Ready`
#
# **Constraints**
# Use safe parameterized queries where applicable.
