# %% [markdown]
# # Classes and Objects Questions
#
# This notebook contains structured practice questions from beginner to advanced level.
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ### Q1. Create a Student Object
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Student` class with a `name` attribute and return the stored name from an object.
#
# **Input format:**
# One string name.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# Asha
# ```
#
# **Sample Output:**
# ```text
# Asha
# ```
#
# **Constraints:**
# Name is a non-empty string.

# %%
class Student:
    pass

# %% [markdown]
# ### Q2. Store Two Attributes
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Laptop` class that stores `brand` and `ram` and returns both values as a tuple.
#
# **Input format:**
# One string and one integer.
#
# **Output format:**
# A tuple.
#
# **Sample Input:**
# ```text
# Lenovo 16
# ```
#
# **Sample Output:**
# ```text
# ('Lenovo', 16)
# ```
#
# **Constraints:**
# RAM is a positive integer.

# %%
class Laptop:
    pass

# %% [markdown]
# ### Q3. Simple Method Call
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Fan` class with a `speed` attribute and a method that increases speed by one.
#
# **Input format:**
# One integer speed.
#
# **Output format:**
# The updated integer speed.
#
# **Sample Input:**
# ```text
# 2
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# Speed is a non-negative integer.

# %%
class Fan:
    pass

# %% [markdown]
# ### Q4. Bank Balance Read
#
# **Level:** Basic
#
# **Problem description:**
# Create a `BankAccount` class with a `balance` attribute and return the current balance.
#
# **Input format:**
# One integer balance.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# 1000
# ```
#
# **Sample Output:**
# ```text
# 1000
# ```
#
# **Constraints:**
# Balance is non-negative.

# %%
class BankAccount:
    pass

# %% [markdown]
# ### Q5. Product Quantity Default
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Product` class with `name` and optional `quantity` defaulting to `1`.
#
# **Input format:**
# One string name and optional integer quantity.
#
# **Output format:**
# A tuple.
#
# **Sample Input:**
# ```text
# Notebook
# ```
#
# **Sample Output:**
# ```text
# ('Notebook', 1)
# ```
#
# **Constraints:**
# Quantity is a positive integer.

# %%
class Product:
    pass

# %% [markdown]
# ### Q6. Class Attribute Access
#
# **Level:** Basic
#
# **Problem description:**
# Create a `MobilePhone` class with class attribute `category = 'Electronics'` and return that category from an object.
#
# **Input format:**
# One string brand.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# Samsung
# ```
#
# **Sample Output:**
# ```text
# Electronics
# ```
#
# **Constraints:**
# Brand is a non-empty string.

# %%
class MobilePhone:
    pass

# %% [markdown]
# ### Q7. Show Name Method
#
# **Level:** Basic
#
# **Problem description:**
# Create an `Employee` class with a method that returns the employee name.
#
# **Input format:**
# One string name.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# Ravi
# ```
#
# **Sample Output:**
# ```text
# Ravi
# ```
#
# **Constraints:**
# Name is a non-empty string.

# %%
class Employee:
    pass

# %% [markdown]
# ### Q8. Cart Total
#
# **Level:** Basic
#
# **Problem description:**
# Create a `CartItem` class with `name`, `price`, and `quantity`, then return the total cost.
#
# **Input format:**
# One string, one integer price, one integer quantity.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# Keyboard 1500 2
# ```
#
# **Sample Output:**
# ```text
# 3000
# ```
#
# **Constraints:**
# Price and quantity are non-negative integers.

# %%
class CartItem:
    pass

# %% [markdown]
# ### Q9. Course String
#
# **Level:** Basic
#
# **Problem description:**
# Create a `Course` class with `title` and `duration`, then make `print(object)` return a friendly string.
#
# **Input format:**
# One string and one integer.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# Python 40
# ```
#
# **Sample Output:**
# ```text
# Python - 40 hours
# ```
#
# **Constraints:**
# Duration is a positive integer.

# %%
class Course:
    pass

# %% [markdown]
# ### Q10. Valid Marks Check
#
# **Level:** Basic
#
# **Problem description:**
# Create an `ExamResult` class with `marks` and a method that returns `True` only when marks are between 0 and 100.
#
# **Input format:**
# One integer marks.
#
# **Output format:**
# One boolean.
#
# **Sample Input:**
# ```text
# 95
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# Marks may be invalid too.

# %%
class ExamResult:
    pass

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ### Q11. Deposit and Withdraw
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `BankAccount` class with `deposit` and `withdraw` methods and return the final balance.
#
# **Input format:**
# One starting balance and a list of operations.
#
# **Output format:**
# One integer balance.
#
# **Sample Input:**
# ```text
# 1000 then deposit 200, withdraw 150
# ```
#
# **Sample Output:**
# ```text
# 1050
# ```
#
# **Constraints:**
# Withdraw amount will not exceed balance in the sample.

# %%
class BankAccount:
    pass

# %% [markdown]
# ### Q12. Student Grade Method
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `StudentRecord` class with `name`, `marks`, and a `grade()` method.
#
# **Input format:**
# One string name and one integer marks.
#
# **Output format:**
# One string grade.
#
# **Sample Input:**
# ```text
# Anita 84
# ```
#
# **Sample Output:**
# ```text
# B
# ```
#
# **Constraints:**
# Marks are between 0 and 100.

# %%
class StudentRecord:
    pass

# %% [markdown]
# ### Q13. Safe Withdrawal
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `SafeBankAccount` class whose `withdraw` method returns a message when funds are insufficient.
#
# **Input format:**
# One starting balance and one withdrawal amount.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# 500 then withdraw 700
# ```
#
# **Sample Output:**
# ```text
# Insufficient balance
# ```
#
# **Constraints:**
# Balance is non-negative.

# %%
class SafeBankAccount:
    pass

# %% [markdown]
# ### Q14. Override Class Attribute Locally
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `School` class with a class attribute `school_name`, then override it for one object only.
#
# **Input format:**
# One student name and one override value.
#
# **Output format:**
# A tuple of instance and class values.
#
# **Sample Input:**
# ```text
# Meena Riverdale School
# ```
#
# **Sample Output:**
# ```text
# ('Riverdale School', 'Green Valley School')
# ```
#
# **Constraints:**
# Use one object and one class attribute.

# %%
class School:
    pass

# %% [markdown]
# ### Q15. Playlist Length
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Playlist` class that supports `len(object)` using `__len__()`.
#
# **Input format:**
# A list of song strings.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# ['Song A', 'Song B', 'Song C']
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# List may be empty.

# %%
class Playlist:
    pass

# %% [markdown]
# ### Q16. Compare Books by Data
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Book` class where two objects are equal when title and author match.
#
# **Input format:**
# Two title-author pairs.
#
# **Output format:**
# One boolean.
#
# **Sample Input:**
# ```text
# Python Basics Riya and Python Basics Riya
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# Titles and authors are strings.

# %%
class Book:
    pass

# %% [markdown]
# ### Q17. Temperature Property
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Temperature` class with internal Celsius storage and a `fahrenheit` property.
#
# **Input format:**
# One numeric Celsius value.
#
# **Output format:**
# One numeric Fahrenheit value.
#
# **Sample Input:**
# ```text
# 25
# ```
#
# **Sample Output:**
# ```text
# 77.0
# ```
#
# **Constraints:**
# Input can be int or float.

# %%
class Temperature:
    pass

# %% [markdown]
# ### Q18. Validated Positive Price
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Product` class that refuses negative `price` values in the constructor.
#
# **Input format:**
# One integer price.
#
# **Output format:**
# A valid product or an error message.
#
# **Sample Input:**
# ```text
# 500
# ```
#
# **Sample Output:**
# ```text
# 500
# ```
#
# **Constraints:**
# Negative input should not be accepted.

# %%
class Product:
    pass

# %% [markdown]
# ### Q19. Wallet Reader
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a `Wallet` class with an internal amount and a public method that returns it.
#
# **Input format:**
# One integer amount.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# 2500
# ```
#
# **Sample Output:**
# ```text
# 2500
# ```
#
# **Constraints:**
# Amount is non-negative.

# %%
class Wallet:
    pass

# %% [markdown]
# ### Q20. Alternate Constructor
#
# **Level:** Intermediate
#
# **Problem description:**
# Create an `Employee` class with a class method `from_string('Aman-50000')`.
#
# **Input format:**
# One formatted string.
#
# **Output format:**
# A tuple.
#
# **Sample Input:**
# ```text
# Aman-50000
# ```
#
# **Sample Output:**
# ```text
# ('Aman', 50000)
# ```
#
# **Constraints:**
# Input uses one hyphen.

# %%
class Employee:
    pass

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ### Q21. Vector Addition
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `Vector` class that supports `+` using `__add__()` and returns a readable string.
#
# **Input format:**
# Two coordinate pairs.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# (2, 3) and (5, 7)
# ```
#
# **Sample Output:**
# ```text
# Vector(7, 10)
# ```
#
# **Constraints:**
# Coordinates are integers.

# %%
class Vector:
    pass

# %% [markdown]
# ### Q22. Custom Counter Object
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `Counter` class with a method that increments internal state and returns the new count.
#
# **Input format:**
# One starting integer.
#
# **Output format:**
# Increasing integers on repeated calls.
#
# **Sample Input:**
# ```text
# 0 then call three times
# ```
#
# **Sample Output:**
# ```text
# 1 2 3
# ```
#
# **Constraints:**
# Starting count is non-negative.

# %%
class Counter:
    pass

# %% [markdown]
# ### Q23. Shared Class Count
#
# **Level:** Advanced
#
# **Problem description:**
# Create a class that tracks how many objects have been created using a class attribute.
#
# **Input format:**
# A sequence of object creations.
#
# **Output format:**
# One integer object count.
#
# **Sample Input:**
# ```text
# create 3 objects
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# Objects are created normally.

# %%
class Visitor:
    pass

# %% [markdown]
# ### Q24. Sorted Students by Marks
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `Student` class and sort objects by `marks` using a lambda key.
#
# **Input format:**
# A list of student data.
#
# **Output format:**
# A list of names in sorted order.
#
# **Sample Input:**
# ```text
# [('A', 70), ('B', 90), ('C', 80)]
# ```
#
# **Sample Output:**
# ```text
# ['B', 'C', 'A']
# ```
#
# **Constraints:**
# Marks are between 0 and 100.

# %%
class Student:
    pass

# %% [markdown]
# ### Q25. Library Book Status
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `LibraryBook` class with `borrow()` and `return_book()` methods and track whether the book is available.
#
# **Input format:**
# One title and a sequence of actions.
#
# **Output format:**
# A final boolean status.
#
# **Sample Input:**
# ```text
# Python Book then borrow, return
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# Availability starts as True.

# %%
class LibraryBook:
    pass

# %% [markdown]
# ### Q26. Descriptor-Like Validation via Property
#
# **Level:** Advanced
#
# **Problem description:**
# Use a property setter in a `Percentage` class to reject values outside 0 to 100.
#
# **Input format:**
# One integer percentage.
#
# **Output format:**
# A valid percentage or an error message.
#
# **Sample Input:**
# ```text
# 85
# ```
#
# **Sample Output:**
# ```text
# 85
# ```
#
# **Constraints:**
# Values outside range must be rejected.

# %%
class Percentage:
    pass

# %% [markdown]
# ### Q27. Bank Account Statement
#
# **Level:** Advanced
#
# **Problem description:**
# Create a class that stores transactions and returns a final statement dictionary with balance and transaction count.
#
# **Input format:**
# One starting balance and multiple operations.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# 1000 then deposit 100, withdraw 50
# ```
#
# **Sample Output:**
# ```text
# {'balance': 1050, 'count': 2}
# ```
#
# **Constraints:**
# Operations are valid.

# %%
class StatementAccount:
    pass

# %% [markdown]
# ### Q28. Inventory Item Update
#
# **Level:** Advanced
#
# **Problem description:**
# Create an `InventoryItem` class with `add_stock()` and `remove_stock()` methods that never allow negative stock.
#
# **Input format:**
# One starting stock and operations.
#
# **Output format:**
# Final stock or error message.
#
# **Sample Input:**
# ```text
# 10 then remove 12
# ```
#
# **Sample Output:**
# ```text
# Insufficient stock
# ```
#
# **Constraints:**
# Stock is non-negative.

# %%
class InventoryItem:
    pass

# %% [markdown]
# ### Q29. Course Registry
#
# **Level:** Advanced
#
# **Problem description:**
# Create a class that stores course titles in a class-level registry as objects are created.
#
# **Input format:**
# A sequence of course titles.
#
# **Output format:**
# A list of stored titles.
#
# **Sample Input:**
# ```text
# Python, SQL, Statistics
# ```
#
# **Sample Output:**
# ```text
# ['Python', 'SQL', 'Statistics']
# ```
#
# **Constraints:**
# Titles are strings.

# %%
class Course:
    pass

# %% [markdown]
# ### Q30. Transaction String View
#
# **Level:** Advanced
#
# **Problem description:**
# Create a `Transaction` class where `print(object)` returns `Transaction(amount=500, type='deposit')` style text.
#
# **Input format:**
# One integer amount and one string type.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# 500 deposit
# ```
#
# **Sample Output:**
# ```text
# Transaction(amount=500, type='deposit')
# ```
#
# **Constraints:**
# Type is a non-empty string.

# %%
class Transaction:
    pass

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ### Q31. Student Report Card
#
# **Level:** Real-world
#
# **Problem description:**
# Create a `StudentReport` class that stores name and marks and returns a report dictionary with average and grade.
#
# **Input format:**
# One name and a list of marks.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# Asha and [88, 76, 91, 84]
# ```
#
# **Sample Output:**
# ```text
# {'name': 'Asha', 'average': 84.75, 'grade': 'B'}
# ```
#
# **Constraints:**
# Marks are between 0 and 100.

# %%
class StudentReport:
    pass

# %% [markdown]
# ### Q32. Shopping Cart Object
#
# **Level:** Real-world
#
# **Problem description:**
# Create a `ShoppingCart` class that stores items and returns the total bill.
#
# **Input format:**
# A sequence of `(name, price, quantity)` values.
#
# **Output format:**
# One integer total.
#
# **Sample Input:**
# ```text
# Book 300 2, Pen 20 5
# ```
#
# **Sample Output:**
# ```text
# 700
# ```
#
# **Constraints:**
# Prices and quantities are non-negative.

# %%
class ShoppingCart:
    pass

# %% [markdown]
# ### Q33. Simple Attendance Tracker
#
# **Level:** Real-world
#
# **Problem description:**
# Create an `AttendanceTracker` class that records present student names and returns total present count.
#
# **Input format:**
# A sequence of student names.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# Asha, Ravi, Meena
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# Names are strings.

# %%
class AttendanceTracker:
    pass

# %% [markdown]
# ### Q34. ATM Simulation
#
# **Level:** Real-world
#
# **Problem description:**
# Create an `ATMAccount` class with deposit, withdraw, and mini-statement behavior.
#
# **Input format:**
# One starting balance and operations.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# 1000 then deposit 500, withdraw 200
# ```
#
# **Sample Output:**
# ```text
# {'balance': 1300, 'transactions': 2}
# ```
#
# **Constraints:**
# Operations are valid.

# %%
class ATMAccount:
    pass

# %% [markdown]
# ### Q35. Employee Payroll Object
#
# **Level:** Real-world
#
# **Problem description:**
# Create an `EmployeePayroll` class that stores salary details and returns net salary after tax percentage.
#
# **Input format:**
# One name, one gross salary, one tax percentage.
#
# **Output format:**
# One float.
#
# **Sample Input:**
# ```text
# Ravi 50000 10
# ```
#
# **Sample Output:**
# ```text
# 45000.0
# ```
#
# **Constraints:**
# Tax percentage is between 0 and 100.

# %%
class EmployeePayroll:
    pass
