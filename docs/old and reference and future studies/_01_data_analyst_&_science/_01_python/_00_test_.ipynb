# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
for x in range(len(l)):
    print(l[x]+k[x])
# Out:
# 46
# 846
# 846
# 8
# 468
# 468

# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
def go(a,b):
    return a+b
for x in range(len(l)):
    print(go(l[x],k[x]))
# Out:
# 46
# 846
# 846
# 8
# 468
# 468

# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
def go(a,b):
    return a+b
m=map(go,l,k)
print(m)
print(list(m))
# Out:
# ...
# [46, 846, 846, 8, 468, 468]

# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
x=lambda a,b:a+b
m=map(go,l,k)
print(list(m))
# Out:
# ...
# [46, 846, 846, 8, 468, 468]

# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
m=map(lambda a,b:a+b,l,k)
print(list(m))
# Out:
# ...
# [46, 846, 846, 8, 468, 468]

# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
z=zip(l,k)
print(list(z))
# Out:
# [(23, 23), (423, 423), (423, 423), (4, 4), (234, 234), (234, 234)]

# %%
l=[23,423,423,4,234,234]
k=[23,423,423,4,234,234]
def go(a):
    if a>100:return True
    else:return False
x=filter(go,l)
print(list(x))
# Out:
# [423, 423, 234, 234]
