# %% [markdown]
# # Python Web APIs and Requests Answers
#
# Each answer includes:
#
# - problem title
# - clean Python solution
# - step-by-step logic
# - dry run
# - test cases
# - time and space complexity notes when useful

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. HTTP Method Meaning
#
# **Problem:** Return the meaning of the HTTP method `GET` as a short string.
#
# **Step-by-step logic:**
# - Read the required input shape: `unused: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Return a short readable phrase.
# - Return the final answer in the required format `str`.

# %%
def http_method_meaning(unused: int) -> str:
    # Return a short readable meaning for GET.
    return "fetch data"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# unused = 0
# ```
#
# **Expected Output**
# ```python
# 'fetch data'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = "fetch data"
print(http_method_meaning(0))  # should match expected_output
assert http_method_meaning(0) == expected_output

# %% [markdown]
# ## Q2. Status Code Success Check
#
# **Problem:** Return True if a status code is in the 200 range, otherwise False.
#
# **Step-by-step logic:**
# - Read the required input shape: `status_code: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use integer comparisons only.
# - Return the final answer in the required format `bool`.

# %%
def status_code_success_check(status_code: int) -> bool:
    # Return True only for 200-range status codes.
    return 200 <= status_code < 300

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# status_code = 200
# ```
#
# **Expected Output**
# ```python
# True
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(status_code_success_check(200))  # should match expected_output
assert status_code_success_check(200) is True
assert status_code_success_check(404) is False

# %% [markdown]
# ## Q3. Query Parameter Dict
#
# **Problem:** Create and return a query parameter dictionary with `page` and `search` keys.
#
# **Step-by-step logic:**
# - Read the required input shape: `page: int, search: str`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Return a plain dictionary.
# - Return the final answer in the required format `dict[str, object]`.

# %%
def query_parameter_dict(page: int, search: str) -> dict[str, object]:
    # Build a plain query parameter dictionary.
    return {"page": page, "search": search}

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# page = 2, search = 'python'
# ```
#
# **Expected Output**
# ```python
# {'page': 2, 'search': 'python'}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = {"page": 2, "search": "python"}
print(query_parameter_dict(2, "python"))  # should match expected_output
assert query_parameter_dict(2, "python") == expected_output

# %% [markdown]
# ## Q4. Header Accept Json
#
# **Problem:** Return a headers dictionary that requests JSON using the `Accept` header.
#
# **Step-by-step logic:**
# - Read the required input shape: `unused: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Return a plain dictionary.
# - Return the final answer in the required format `dict[str, str]`.

# %%
def header_accept_json(unused: int) -> dict[str, str]:
    # Return a headers dictionary requesting JSON.
    return {"Accept": "application/json"}

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# unused = 0
# ```
#
# **Expected Output**
# ```python
# {'Accept': 'application/json'}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = {"Accept": "application/json"}
print(header_accept_json(0))  # should match expected_output
assert header_accept_json(0) == expected_output

# %% [markdown]
# ## Q5. Extract Status Message
#
# **Problem:** Given a small response dictionary containing `status_code`, return `'Success'` for 200 and `'Failed'` otherwise.
#
# **Step-by-step logic:**
# - Read the required input shape: `response: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: The dictionary contains the `status_code` key.
# - Return the final answer in the required format `str`.

# %%
def extract_status_message(response: dict) -> str:
    # Read the status code and label the response.
    return "Success" if response["status_code"] == 200 else "Failed"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# response = {'status_code': 200}
# ```
#
# **Expected Output**
# ```python
# 'Success'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_response = {"status_code": 200}
expected_output = "Success"
print(extract_status_message(input_response))  # should match expected_output
assert extract_status_message(input_response) == expected_output

# %% [markdown]
# ## Q6. Json Field Read
#
# **Problem:** Given parsed API JSON with a `name` key, return the name value.
#
# **Step-by-step logic:**
# - Read the required input shape: `data: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: The key exists.
# - Return the final answer in the required format `str`.

# %%
def json_field_read(data: dict) -> str:
    # Return the value stored under the name key.
    return data["name"]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# data = {'name': 'Asha'}
# ```
#
# **Expected Output**
# ```python
# 'Asha'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_data = {"name": "Asha"}
expected_output = "Asha"
print(json_field_read(input_data))  # should match expected_output
assert json_field_read(input_data) == expected_output

# %% [markdown]
# ## Q7. List User Names
#
# **Problem:** Given a list of user dictionaries, return a list of their `name` values.
#
# **Step-by-step logic:**
# - Read the required input shape: `users: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Every dictionary has a `name` key.
# - Return the final answer in the required format `list[str]`.

# %%
def list_user_names(users: list[dict]) -> list[str]:
    # Extract every user name from the list.
    return [user["name"] for user in users]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# users = [{'name': 'Asha'}, {'name': 'Ravi'}]
# ```
#
# **Expected Output**
# ```python
# ['Asha', 'Ravi']
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_users = [{"name": "Asha"}, {"name": "Ravi"}]
expected_output = ["Asha", "Ravi"]
print(list_user_names(input_users))  # should match expected_output
assert list_user_names(input_users) == expected_output

# %% [markdown]
# ## Q8. Missing Field Safe Read
#
# **Problem:** Use `dict.get()` to return `city` from a record or `'Unknown'` if missing.
#
# **Step-by-step logic:**
# - Read the required input shape: `record: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use a safe default.
# - Return the final answer in the required format `str`.

# %%
def missing_field_safe_read(record: dict) -> str:
    # Return city safely or Unknown when missing.
    return record.get("city", "Unknown")

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# record = {'name': 'Asha'}
# ```
#
# **Expected Output**
# ```python
# 'Unknown'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_record = {"name": "Asha"}
expected_output = "Unknown"
print(missing_field_safe_read(input_record))  # should match expected_output
assert missing_field_safe_read(input_record) == expected_output

# %% [markdown]
# ## Q9. Payload Build
#
# **Problem:** Return a JSON-style payload dictionary for creating a task with `title` and `completed` keys.
#
# **Step-by-step logic:**
# - Read the required input shape: `title: str`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Set `completed` to False.
# - Return the final answer in the required format `dict[str, object]`.

# %%
def payload_build(title: str) -> dict[str, object]:
    # Build a JSON-style task payload.
    return {"title": title, "completed": False}

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# title = 'Learn APIs'
# ```
#
# **Expected Output**
# ```python
# {'title': 'Learn APIs', 'completed': False}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_title = "Learn APIs"
expected_output = {"title": "Learn APIs", "completed": False}
print(payload_build(input_title))  # should match expected_output
assert payload_build(input_title) == expected_output

# %% [markdown]
# ## Q10. No Content Check
#
# **Problem:** Return True if a status code is `204`, otherwise False.
#
# **Step-by-step logic:**
# - Read the required input shape: `status_code: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use exact status-code comparison.
# - Return the final answer in the required format `bool`.

# %%
def no_content_check(status_code: int) -> bool:
    # Return True only for the 204 No Content status.
    return status_code == 204

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# status_code = 204
# ```
#
# **Expected Output**
# ```python
# True
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(no_content_check(204))  # should match expected_output
assert no_content_check(204) is True
assert no_content_check(200) is False

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Pagination Summary
#
# **Problem:** Given `page`, `per_page`, and `total`, return a pagination dictionary.
#
# **Step-by-step logic:**
# - Read the required input shape: `page: int, per_page: int, total: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Return all three values.
# - Return the final answer in the required format `dict[str, int]`.

# %%
def pagination_summary(page: int, per_page: int, total: int) -> dict[str, int]:
    # Return all pagination values in one dictionary.
    return {"page": page, "per_page": per_page, "total": total}

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# page = 1, per_page = 20, total = 95
# ```
#
# **Expected Output**
# ```python
# {'page': 1, 'per_page': 20, 'total': 95}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
expected_output = {"page": 1, "per_page": 20, "total": 95}
print(pagination_summary(1, 20, 95))  # should match expected_output
assert pagination_summary(1, 20, 95) == expected_output

# %% [markdown]
# ## Q12. Filter Success Responses
#
# **Problem:** Given a list of response dictionaries with `status_code`, return only those in the 200 range.
#
# **Step-by-step logic:**
# - Read the required input shape: `responses: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Preserve original order.
# - Return the final answer in the required format `list[dict]`.

# %%
def filter_success_responses(responses: list[dict]) -> list[dict]:
    # Keep only responses with 200-range status codes.
    return [response for response in responses if 200 <= response["status_code"] < 300]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# responses = [{'status_code': 200}, {'status_code': 404}, {'status_code': 201}]
# ```
#
# **Expected Output**
# ```python
# [{'status_code': 200}, {'status_code': 201}]
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_responses = [{"status_code": 200}, {"status_code": 404}, {"status_code": 201}]
expected_output = [{"status_code": 200}, {"status_code": 201}]
print(filter_success_responses(input_responses))  # should match expected_output
assert filter_success_responses(input_responses) == expected_output

# %% [markdown]
# ## Q13. Extract Nested User Names
#
# **Problem:** Given API JSON like `{'users': [{'name': ...}, ...]}`, return the list of names.
#
# **Step-by-step logic:**
# - Read the required input shape: `data: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Assume the structure exists.
# - Return the final answer in the required format `list[str]`.

# %%
def extract_nested_user_names(data: dict) -> list[str]:
    # Extract names from the nested users list.
    return [user["name"] for user in data["users"]]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# data = {'users': [{'name': 'Asha'}, {'name': 'Ravi'}]}
# ```
#
# **Expected Output**
# ```python
# ['Asha', 'Ravi']
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_data = {"users": [{"name": "Asha"}, {"name": "Ravi"}]}
expected_output = ["Asha", "Ravi"]
print(extract_nested_user_names(input_data))  # should match expected_output
assert extract_nested_user_names(input_data) == expected_output

# %% [markdown]
# ## Q14. Status Code Group Label
#
# **Problem:** Return `'client error'` for 400-range codes, `'server error'` for 500-range codes, and `'other'` otherwise.
#
# **Step-by-step logic:**
# - Read the required input shape: `status_code: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use integer comparisons.
# - Return the final answer in the required format `str`.

# %%
def status_code_group_label(status_code: int) -> str:
    # Label status codes by group.
    if 400 <= status_code < 500:
        return "client error"
    if 500 <= status_code < 600:
        return "server error"
    return "other"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# status_code = 404
# ```
#
# **Expected Output**
# ```python
# 'client error'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(status_code_group_label(404))  # should match expected_output
assert status_code_group_label(404) == "client error"
assert status_code_group_label(500) == "server error"
assert status_code_group_label(200) == "other"

# %% [markdown]
# ## Q15. Build Auth Header
#
# **Problem:** Return an Authorization header dictionary for a bearer token.
#
# **Step-by-step logic:**
# - Read the required input shape: `token: str`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use the Bearer format exactly.
# - Return the final answer in the required format `dict[str, str]`.

# %%
def build_auth_header(token: str) -> dict[str, str]:
    # Return a bearer authorization header.
    return {"Authorization": f"Bearer {token}"}

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# token = 'abc123'
# ```
#
# **Expected Output**
# ```python
# {'Authorization': 'Bearer abc123'}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_token = "abc123"
expected_output = {"Authorization": "Bearer abc123"}
print(build_auth_header(input_token))  # should match expected_output
assert build_auth_header(input_token) == expected_output

# %% [markdown]
# ## Q16. Extract First User City
#
# **Problem:** Given parsed JSON with a `users` list, return the first user's city or `'Unknown'` if missing.
#
# **Step-by-step logic:**
# - Read the required input shape: `data: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use safe reads when possible.
# - Return the final answer in the required format `str`.

# %%
def extract_first_user_city(data: dict) -> str:
    # Read the first user safely and then read city safely.
    first_user = data.get("users", [{}])[0] if data.get("users") else {}
    return first_user.get("city", "Unknown")

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# data = {'users': [{'name': 'Asha', 'city': 'Pune'}]}
# ```
#
# **Expected Output**
# ```python
# 'Pune'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_data = {"users": [{"name": "Asha", "city": "Pune"}]}
expected_output = "Pune"
print(extract_first_user_city(input_data))  # should match expected_output
assert extract_first_user_city(input_data) == expected_output
assert extract_first_user_city({"users": [{"name": "Asha"}]}) == "Unknown"

# %% [markdown]
# ## Q17. Request Config Builder
#
# **Problem:** Return a dictionary containing `url`, `params`, and `headers` for a simple API request.
#
# **Step-by-step logic:**
# - Read the required input shape: `url: str, page: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use Accept JSON header.
# - Return the final answer in the required format `dict[str, object]`.

# %%
def request_config_builder(url: str, page: int) -> dict[str, object]:
    # Build a request configuration dictionary.
    return {
        "url": url,
        "params": {"page": page},
        "headers": {"Accept": "application/json"},
    }

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# url = 'https://api.example.com/users', page = 1
# ```
#
# **Expected Output**
# ```python
# {'url': 'https://api.example.com/users', 'params': {'page': 1}, 'headers': {'Accept': 'application/json'}}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_url = "https://api.example.com/users"
expected_output = {
    "url": "https://api.example.com/users",
    "params": {"page": 1},
    "headers": {"Accept": "application/json"},
}
print(request_config_builder(input_url, 1))  # should match expected_output
assert request_config_builder(input_url, 1) == expected_output

# %% [markdown]
# ## Q18. Count Error Responses
#
# **Problem:** Count how many response dictionaries have status codes 400 or higher.
#
# **Step-by-step logic:**
# - Read the required input shape: `responses: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Every dictionary has a `status_code` key.
# - Return the final answer in the required format `int`.

# %%
def count_error_responses(responses: list[dict]) -> int:
    # Count responses with status codes 400 or higher.
    return sum(1 for response in responses if response["status_code"] >= 400)

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# responses = [{'status_code': 200}, {'status_code': 404}, {'status_code': 500}]
# ```
#
# **Expected Output**
# ```python
# 2
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_responses = [{"status_code": 200}, {"status_code": 404}, {"status_code": 500}]
expected_output = 2
print(count_error_responses(input_responses))  # should match expected_output
assert count_error_responses(input_responses) == expected_output

# %% [markdown]
# ## Q19. Normalize User Records
#
# **Problem:** Convert API user dictionaries into a list of simplified dictionaries containing only `name` and `city`, defaulting city to `'Unknown'`.
#
# **Step-by-step logic:**
# - Read the required input shape: `users: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Preserve original order.
# - Return the final answer in the required format `list[dict[str, str]]`.

# %%
def normalize_user_records(users: list[dict]) -> list[dict[str, str]]:
    # Return only name and city, with a safe city default.
    return [{"name": user["name"], "city": user.get("city", "Unknown")} for user in users]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# users = [{'name': 'Asha'}, {'name': 'Ravi', 'city': 'Delhi'}]
# ```
#
# **Expected Output**
# ```python
# [{'name': 'Asha', 'city': 'Unknown'}, {'name': 'Ravi', 'city': 'Delhi'}]
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_users = [{"name": "Asha"}, {"name": "Ravi", "city": "Delhi"}]
expected_output = [{"name": "Asha", "city": "Unknown"}, {"name": "Ravi", "city": "Delhi"}]
print(normalize_user_records(input_users))  # should match expected_output
assert normalize_user_records(input_users) == expected_output

# %% [markdown]
# ## Q20. Check Retry Worthy
#
# **Problem:** Return True if a status code is one of 429, 500, 502, 503, or 504.
#
# **Step-by-step logic:**
# - Read the required input shape: `status_code: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use a membership check.
# - Return the final answer in the required format `bool`.

# %%
def check_retry_worthy(status_code: int) -> bool:
    # Return True for retry-worthy status codes.
    return status_code in {429, 500, 502, 503, 504}

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# status_code = 503
# ```
#
# **Expected Output**
# ```python
# True
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(check_retry_worthy(503))  # should match expected_output
assert check_retry_worthy(503) is True
assert check_retry_worthy(404) is False

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Response Summary Builder
#
# **Problem:** Given a response dictionary with `status_code` and `data`, return a summary dictionary with keys `ok`, `status_code`, and `item_count`.
#
# **Step-by-step logic:**
# - Read the required input shape: `response: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Treat 200-range codes as ok.
# - Return the final answer in the required format `dict[str, object]`.

# %%
def response_summary_builder(response: dict) -> dict[str, object]:
    # Build a compact response summary dictionary.
    return {
        "ok": 200 <= response["status_code"] < 300,
        "status_code": response["status_code"],
        "item_count": len(response["data"]),
    }

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# response = {'status_code': 200, 'data': [1, 2, 3]}
# ```
#
# **Expected Output**
# ```python
# {'ok': True, 'status_code': 200, 'item_count': 3}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_response = {"status_code": 200, "data": [1, 2, 3]}
expected_output = {"ok": True, "status_code": 200, "item_count": 3}
print(response_summary_builder(input_response))  # should match expected_output
assert response_summary_builder(input_response) == expected_output

# %% [markdown]
# ## Q22. Paginated Name Extractor
#
# **Problem:** Given a list of page dictionaries each containing `users`, return one flat list of all user names.
#
# **Step-by-step logic:**
# - Read the required input shape: `pages: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Preserve page order and user order.
# - Return the final answer in the required format `list[str]`.

# %%
def paginated_name_extractor(pages: list[dict]) -> list[str]:
    # Flatten names from all pages in original order.
    names = []
    for page in pages:
        for user in page["users"]:
            names.append(user["name"])
    return names

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# pages = [{'users': [{'name': 'A'}]}, {'users': [{'name': 'B'}, {'name': 'C'}]}]
# ```
#
# **Expected Output**
# ```python
# ['A', 'B', 'C']
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_pages = [{"users": [{"name": "A"}]}, {"users": [{"name": "B"}, {"name": "C"}]}]
expected_output = ["A", "B", "C"]
print(paginated_name_extractor(input_pages))  # should match expected_output
assert paginated_name_extractor(input_pages) == expected_output

# %% [markdown]
# ## Q23. Error Message Builder
#
# **Problem:** Given a response dictionary with `status_code` and optional `error`, return a formatted error message string like `404: Not Found`.
#
# **Step-by-step logic:**
# - Read the required input shape: `response: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use `'Unknown error'` when `error` is missing.
# - Return the final answer in the required format `str`.

# %%
def error_message_builder(response: dict) -> str:
    # Read the error message safely and format it with the status code.
    return f"{response['status_code']}: {response.get('error', 'Unknown error')}"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# response = {'status_code': 404, 'error': 'Not Found'}
# ```
#
# **Expected Output**
# ```python
# '404: Not Found'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_response = {"status_code": 404, "error": "Not Found"}
expected_output = "404: Not Found"
print(error_message_builder(input_response))  # should match expected_output
assert error_message_builder(input_response) == expected_output
assert error_message_builder({"status_code": 500}) == "500: Unknown error"

# %% [markdown]
# ## Q24. Merge Default And User Headers
#
# **Problem:** Merge default headers and user headers into one dictionary where user headers override defaults.
#
# **Step-by-step logic:**
# - Read the required input shape: `defaults: dict, custom: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use dictionary merging or update logic.
# - Return the final answer in the required format `dict`.

# %%
def merge_default_and_user_headers(defaults: dict, custom: dict) -> dict:
    # Merge user headers so custom values override defaults.
    return defaults | custom

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# defaults = {'Accept': 'application/json'}, custom = {'Authorization': 'Bearer x'}
# ```
#
# **Expected Output**
# ```python
# {'Accept': 'application/json', 'Authorization': 'Bearer x'}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_defaults = {"Accept": "application/json"}
input_custom = {"Authorization": "Bearer x"}
expected_output = {"Accept": "application/json", "Authorization": "Bearer x"}
print(merge_default_and_user_headers(input_defaults, input_custom))  # should match expected_output
assert merge_default_and_user_headers(input_defaults, input_custom) == expected_output

# %% [markdown]
# ## Q25. Extract Unique Cities
#
# **Problem:** Given API user dictionaries, return a sorted list of unique city names, using `'Unknown'` for missing cities.
#
# **Step-by-step logic:**
# - Read the required input shape: `users: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Return sorted unique values.
# - Return the final answer in the required format `list[str]`.

# %%
def extract_unique_cities(users: list[dict]) -> list[str]:
    # Build sorted unique city names with a safe missing-value default.
    return sorted({user.get("city", "Unknown") for user in users})

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# users = [{'name': 'Asha'}, {'name': 'Ravi', 'city': 'Delhi'}, {'name': 'Mia', 'city': 'Delhi'}]
# ```
#
# **Expected Output**
# ```python
# ['Delhi', 'Unknown']
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_users = [{"name": "Asha"}, {"name": "Ravi", "city": "Delhi"}, {"name": "Mia", "city": "Delhi"}]
expected_output = ["Delhi", "Unknown"]
print(extract_unique_cities(input_users))  # should match expected_output
assert extract_unique_cities(input_users) == expected_output

# %% [markdown]
# ## Q26. Validate Api Response Shape
#
# **Problem:** Return True only if a response dictionary has keys `status_code` and `data`.
#
# **Step-by-step logic:**
# - Read the required input shape: `response: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Both keys must exist.
# - Return the final answer in the required format `bool`.

# %%
def validate_api_response_shape(response: dict) -> bool:
    # Check that both required keys are present.
    return "status_code" in response and "data" in response

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# response = {'status_code': 200, 'data': []}
# ```
#
# **Expected Output**
# ```python
# True
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_response = {"status_code": 200, "data": []}
expected_output = True
print(validate_api_response_shape(input_response))  # should match expected_output
assert validate_api_response_shape(input_response) is expected_output
assert validate_api_response_shape({"status_code": 200}) is False

# %% [markdown]
# ## Q27. Build Patch Payload
#
# **Problem:** Given optional `name` and `city` values, build a PATCH payload dictionary containing only non-None fields.
#
# **Step-by-step logic:**
# - Read the required input shape: `name: str | None, city: str | None`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Exclude fields whose value is None.
# - Return the final answer in the required format `dict[str, str]`.

# %%
def build_patch_payload(name: str | None, city: str | None) -> dict[str, str]:
    # Include only non-None fields in the payload.
    payload = {}
    if name is not None:
        payload["name"] = name
    if city is not None:
        payload["city"] = city
    return payload

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# name = 'Asha', city = None
# ```
#
# **Expected Output**
# ```python
# {'name': 'Asha'}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
print(build_patch_payload("Asha", None))  # should match expected_output
assert build_patch_payload("Asha", None) == {"name": "Asha"}
assert build_patch_payload(None, None) == {}

# %% [markdown]
# ## Q28. Rate Limit Message
#
# **Problem:** Given a headers dictionary containing `X-RateLimit-Remaining`, return a formatted string like `Remaining: 5`.
#
# **Step-by-step logic:**
# - Read the required input shape: `headers: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use `'Remaining: Unknown'` if the header is missing.
# - Return the final answer in the required format `str`.

# %%
def rate_limit_message(headers: dict) -> str:
    # Read the remaining-request count safely from headers.
    remaining = headers.get("X-RateLimit-Remaining", "Unknown")
    return f"Remaining: {remaining}"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# headers = {'X-RateLimit-Remaining': '5'}
# ```
#
# **Expected Output**
# ```python
# 'Remaining: 5'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_headers = {"X-RateLimit-Remaining": "5"}
expected_output = "Remaining: 5"
print(rate_limit_message(input_headers))  # should match expected_output
assert rate_limit_message(input_headers) == expected_output
assert rate_limit_message({}) == "Remaining: Unknown"

# %% [markdown]
# ## Q29. Api Result Grouping
#
# **Problem:** Given a list of API result dictionaries with `status_code`, return a dictionary counting `success`, `client_error`, and `server_error` groups.
#
# **Step-by-step logic:**
# - Read the required input shape: `responses: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Ignore other status-code groups.
# - Return the final answer in the required format `dict[str, int]`.

# %%
def api_result_grouping(responses: list[dict]) -> dict[str, int]:
    # Start all counters at zero.
    counts = {"success": 0, "client_error": 0, "server_error": 0}

    # Group each response by its status code range.
    for response in responses:
        status = response["status_code"]
        if 200 <= status < 300:
            counts["success"] += 1
        elif 400 <= status < 500:
            counts["client_error"] += 1
        elif 500 <= status < 600:
            counts["server_error"] += 1
    return counts

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# responses = [{'status_code': 200}, {'status_code': 404}, {'status_code': 500}, {'status_code': 201}]
# ```
#
# **Expected Output**
# ```python
# {'success': 2, 'client_error': 1, 'server_error': 1}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_responses = [{"status_code": 200}, {"status_code": 404}, {"status_code": 500}, {"status_code": 201}]
expected_output = {"success": 2, "client_error": 1, "server_error": 1}
print(api_result_grouping(input_responses))  # should match expected_output
assert api_result_grouping(input_responses) == expected_output

# %% [markdown]
# ## Q30. Transform Todo Records
#
# **Problem:** Given todo dictionaries from an API, return a list of strings like `title [done]` or `title [pending]` based on the boolean `completed` field.
#
# **Step-by-step logic:**
# - Read the required input shape: `todos: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Assume both keys exist.
# - Return the final answer in the required format `list[str]`.

# %%
def transform_todo_records(todos: list[dict]) -> list[str]:
    # Convert each todo into a readable summary string.
    return [f"{todo['title']} [{'done' if todo['completed'] else 'pending'}]" for todo in todos]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# todos = [{'title': 'Learn APIs', 'completed': False}, {'title': 'Practice', 'completed': True}]
# ```
#
# **Expected Output**
# ```python
# ['Learn APIs [pending]', 'Practice [done]']
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_todos = [{"title": "Learn APIs", "completed": False}, {"title": "Practice", "completed": True}]
expected_output = ["Learn APIs [pending]", "Practice [done]"]
print(transform_todo_records(input_todos))  # should match expected_output
assert transform_todo_records(input_todos) == expected_output

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Api User Summary
#
# **Problem:** Given parsed API JSON with a `users` list, return a summary string like `2 users: Asha, Ravi`.
#
# **Step-by-step logic:**
# - Read the required input shape: `data: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Assume every user has a name.
# - Return the final answer in the required format `str`.

# %%
def api_user_summary(data: dict) -> str:
    # Extract the names list from the users payload.
    names = [user["name"] for user in data["users"]]

    # Return a readable summary string.
    return f"{len(names)} users: {', '.join(names)}"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# data = {'users': [{'name': 'Asha'}, {'name': 'Ravi'}]}
# ```
#
# **Expected Output**
# ```python
# '2 users: Asha, Ravi'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_data = {"users": [{"name": "Asha"}, {"name": "Ravi"}]}
expected_output = "2 users: Asha, Ravi"
print(api_user_summary(input_data))  # should match expected_output
assert api_user_summary(input_data) == expected_output

# %% [markdown]
# ## Q32. Search Request Builder
#
# **Problem:** Build a request configuration dictionary for a search API including URL, query parameters, and JSON accept header.
#
# **Step-by-step logic:**
# - Read the required input shape: `base_url: str, query: str, page: int`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use `q` as the query parameter name.
# - Return the final answer in the required format `dict[str, object]`.

# %%
def search_request_builder(base_url: str, query: str, page: int) -> dict[str, object]:
    # Build a search request configuration dictionary.
    return {
        "url": base_url,
        "params": {"q": query, "page": page},
        "headers": {"Accept": "application/json"},
    }

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# base_url = 'https://api.example.com/search', query = 'python', page = 1
# ```
#
# **Expected Output**
# ```python
# {'url': 'https://api.example.com/search', 'params': {'q': 'python', 'page': 1}, 'headers': {'Accept': 'application/json'}}
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_url = "https://api.example.com/search"
expected_output = {
    "url": "https://api.example.com/search",
    "params": {"q": "python", "page": 1},
    "headers": {"Accept": "application/json"},
}
print(search_request_builder(input_url, "python", 1))  # should match expected_output
assert search_request_builder(input_url, "python", 1) == expected_output

# %% [markdown]
# ## Q33. Safe Product Extractor
#
# **Problem:** Given API JSON with optional `products`, return a list of product names safely, or an empty list if the key is missing.
#
# **Step-by-step logic:**
# - Read the required input shape: `data: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Use safe access patterns.
# - Return the final answer in the required format `list[str]`.

# %%
def safe_product_extractor(data: dict) -> list[str]:
    # Read products safely and extract names.
    return [product["name"] for product in data.get("products", [])]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# data = {'products': [{'name': 'Book'}, {'name': 'Pen'}]}
# ```
#
# **Expected Output**
# ```python
# ['Book', 'Pen']
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_data = {"products": [{"name": "Book"}, {"name": "Pen"}]}
expected_output = ["Book", "Pen"]
print(safe_product_extractor(input_data))  # should match expected_output
assert safe_product_extractor(input_data) == expected_output
assert safe_product_extractor({}) == []

# %% [markdown]
# ## Q34. Webhook Event Formatter
#
# **Problem:** Given a webhook event dictionary with `type` and `id`, return a formatted string like `order.created -> 101`.
#
# **Step-by-step logic:**
# - Read the required input shape: `event: dict`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Assume both keys exist.
# - Return the final answer in the required format `str`.

# %%
def webhook_event_formatter(event: dict) -> str:
    # Format the webhook event into a short readable line.
    return f"{event['type']} -> {event['id']}"

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# event = {'type': 'order.created', 'id': 101}
# ```
#
# **Expected Output**
# ```python
# 'order.created -> 101'
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_event = {"type": "order.created", "id": 101}
expected_output = "order.created -> 101"
print(webhook_event_formatter(input_event))  # should match expected_output
assert webhook_event_formatter(input_event) == expected_output

# %% [markdown]
# ## Q35. Simple Retry Queue
#
# **Problem:** Given a list of failed response dictionaries, return the list of `id` values whose status codes are retry-worthy (429, 500, 502, 503, 504).
#
# **Step-by-step logic:**
# - Read the required input shape: `responses: list[dict]`.
# - Choose the correct API or HTTP concept for the task.
# - Keep data extraction and error handling clear.
# - Handle the stated constraint carefully: Preserve original order.
# - Return the final answer in the required format `list[int]`.

# %%
def simple_retry_queue(responses: list[dict]) -> list[int]:
    # Define the retry-worthy status codes.
    retry_statuses = {429, 500, 502, 503, 504}

    # Return the ids of retry-worthy failed responses.
    return [response["id"] for response in responses if response["status_code"] in retry_statuses]

# Time Complexity: depends on the number of records, responses, or fields processed above.
# Space Complexity: depends on extra lists, dictionaries, and summaries created above.

# %% [markdown]
# ### Dry Run
#
# **Sample Input**
# ```python
# responses = [{'id': 1, 'status_code': 404}, {'id': 2, 'status_code': 503}, {'id': 3, 'status_code': 500}]
# ```
#
# **Expected Output**
# ```python
# [2, 3]
# ```
#
# Dry run idea:
# - Start with the request data, response dictionary, or parsed JSON.
# - Follow how fields are checked, grouped, or extracted.
# - Track any safe defaults or status-code logic.
# - Compare the final returned result with the expected output.

# %%
# Test cases
input_responses = [{"id": 1, "status_code": 404}, {"id": 2, "status_code": 503}, {"id": 3, "status_code": 500}]
expected_output = [2, 3]
print(simple_retry_queue(input_responses))  # should match expected_output
assert simple_retry_queue(input_responses) == expected_output
