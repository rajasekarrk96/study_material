# %% [markdown]
# # Python Data Structures Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Create List
#
# **Problem description:** Return a list containing numbers from 1 to n.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 4
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4]
# ```
#
# **Constraints:** n >= 0.

# %%
def create_list(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q2. First and Last
#
# **Problem description:** Return first and last element as a tuple.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `tuple[int, int] | None`
#
# **Sample Input:**
# ```python
# items = [5, 8, 9]
# ```
#
# **Sample Output:**
# ```python
# (5, 9)
# ```
#
# **Constraints:** Return None for empty list.

# %%
def first_and_last(items: list[int]) -> tuple[int, int] | None:
    pass

# %% [markdown]
# ## Q3. Append Value
#
# **Problem description:** Append a value to a list and return the list.
#
# **Input format:** `items: list[int], value: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1,2], value=3
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3]
# ```
#
# **Constraints:** List may be empty.

# %%
def append_value(items: list[int], value: int) -> list[int]:
    pass

# %% [markdown]
# ## Q4. Tuple Unpack Sum
#
# **Problem description:** Given a pair tuple, return the sum of both values.
#
# **Input format:** `pair: tuple[int, int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# pair=(4, 6)
# ```
#
# **Sample Output:**
# ```python
# 10
# ```
#
# **Constraints:** Tuple length is 2.

# %%
def tuple_unpack_sum(pair: tuple[int, int]) -> int:
    pass

# %% [markdown]
# ## Q5. Dictionary Lookup
#
# **Problem description:** Return value for key or 'Not Found'.
#
# **Input format:** `data: dict, key: str`
#
# **Output format:** `object`
#
# **Sample Input:**
# ```python
# data={'a':1}, key='a'
# ```
#
# **Sample Output:**
# ```python
# 1
# ```
#
# **Constraints:** Key may be absent.

# %%
def dictionary_lookup(data: dict, key: str) -> object:
    pass

# %% [markdown]
# ## Q6. Set Unique Count
#
# **Problem description:** Return number of unique values.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items=[1,2,2,3]
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** List may be empty.

# %%
def set_unique_count(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q7. Reverse List
#
# **Problem description:** Return reversed list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1,2,3]
# ```
#
# **Sample Output:**
# ```python
# [3, 2, 1]
# ```
#
# **Constraints:** Do not mutate input.

# %%
def reverse_list(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q8. List Sum
#
# **Problem description:** Return sum of all numbers.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# nums=[1,2,3]
# ```
#
# **Sample Output:**
# ```python
# 6
# ```
#
# **Constraints:** Empty list sum is 0.

# %%
def list_sum(nums: list[int]) -> int:
    pass

# %% [markdown]
# ## Q9. Dictionary Keys
#
# **Problem description:** Return sorted list of dictionary keys.
#
# **Input format:** `data: dict[str, int]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# data={'b':2,'a':1}
# ```
#
# **Sample Output:**
# ```python
# ['a', 'b']
# ```
#
# **Constraints:** Keys are strings.

# %%
def dictionary_keys(data: dict[str, int]) -> list[str]:
    pass

# %% [markdown]
# ## Q10. Check Membership
#
# **Problem description:** Return True if value exists in items.
#
# **Input format:** `items: list[int], value: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# items=[1,2,3], value=2
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** List may be empty.

# %%
def check_membership(items: list[int], value: int) -> bool:
    pass

# %% [markdown]
# # Section 2: Intermediate

# %% [markdown]
# ## Q11. Remove Duplicates Keep Order
#
# **Problem description:** Remove duplicates but keep original order.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[3,1,3,2,1]
# ```
#
# **Sample Output:**
# ```python
# [3, 1, 2]
# ```
#
# **Constraints:** Values are hashable.

# %%
def remove_duplicates_keep_order(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q12. Frequency Dictionary
#
# **Problem description:** Return frequency of each string.
#
# **Input format:** `items: list[str]`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# items=['a','b','a']
# ```
#
# **Sample Output:**
# ```python
# {'a': 2, 'b': 1}
# ```
#
# **Constraints:** List may be empty.

# %%
def frequency_dictionary(items: list[str]) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q13. Merge Dictionaries
#
# **Problem description:** Merge two dictionaries. Values from second override first.
#
# **Input format:** `a: dict, b: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# a={'x':1}, b={'x':2,'y':3}
# ```
#
# **Sample Output:**
# ```python
# {'x': 2, 'y': 3}
# ```
#
# **Constraints:** Keys are hashable.

# %%
def merge_dictionaries(a: dict, b: dict) -> dict:
    pass

# %% [markdown]
# ## Q14. Common Elements
#
# **Problem description:** Return sorted common elements from two lists.
#
# **Input format:** `a: list[int], b: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# a=[1,2,3], b=[2,3,4]
# ```
#
# **Sample Output:**
# ```python
# [2, 3]
# ```
#
# **Constraints:** Duplicates ignored.

# %%
def common_elements(a: list[int], b: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q15. Group By First Letter
#
# **Problem description:** Group words by first character.
#
# **Input format:** `words: list[str]`
#
# **Output format:** `dict[str, list[str]]`
#
# **Sample Input:**
# ```python
# words=['apple','ant','bat']
# ```
#
# **Sample Output:**
# ```python
# {'a':['apple','ant'], 'b':['bat']}
# ```
#
# **Constraints:** Words are non-empty.

# %%
def group_by_first_letter(words: list[str]) -> dict[str, list[str]]:
    pass

# %% [markdown]
# ## Q16. Stack Valid Parentheses
#
# **Problem description:** Check valid brackets containing (), {}, [].
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text='{[]}'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** String may be empty.

# %%
def stack_valid_parentheses(text: str) -> bool:
    pass

# %% [markdown]
# ## Q17. Queue Simulation
#
# **Problem description:** Process queue by removing first k items.
#
# **Input format:** `items: list[str], k: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# items=['a','b','c'], k=2
# ```
#
# **Sample Output:**
# ```python
# ['c']
# ```
#
# **Constraints:** 0 <= k.

# %%
def queue_simulation(items: list[str], k: int) -> list[str]:
    pass

# %% [markdown]
# ## Q18. Top Student
#
# **Problem description:** Return name of student with highest score.
#
# **Input format:** `students: list[dict]`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# students=[{'name':'A','score':80}]
# ```
#
# **Sample Output:**
# ```python
# 'A'
# ```
#
# **Constraints:** Return None for empty.

# %%
def top_student(students: list[dict]) -> str | None:
    pass

# %% [markdown]
# ## Q19. Flatten One Level
#
# **Problem description:** Flatten a one-level nested list.
#
# **Input format:** `items: list[list[int]]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[[1,2],[3]]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3]
# ```
#
# **Constraints:** Nested lists contain integers.

# %%
def flatten_one_level(items: list[list[int]]) -> list[int]:
    pass

# %% [markdown]
# ## Q20. Sort Tuples By Second
#
# **Problem description:** Sort list of tuples by second item descending.
#
# **Input format:** `pairs: list[tuple[str, int]]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# pairs=[('a',2),('b',5)]
# ```
#
# **Sample Output:**
# ```python
# [('b', 5), ('a', 2)]
# ```
#
# **Constraints:** Tuple length is 2.

# %%
def sort_tuples_by_second(pairs: list[tuple[str, int]]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# # Section 3: Advanced

# %% [markdown]
# ## Q21. Two Sum
#
# **Problem description:** Return indices of two numbers adding to target.
#
# **Input format:** `nums: list[int], target: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[2,7,11], target=9
# ```
#
# **Sample Output:**
# ```python
# [0, 1]
# ```
#
# **Constraints:** Return [] if absent.

# %%
def two_sum(nums: list[int], target: int) -> list[int]:
    pass

# %% [markdown]
# ## Q22. Product Except Self
#
# **Problem description:** Return product except current index without division.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[1,2,3,4]
# ```
#
# **Sample Output:**
# ```python
# [24, 12, 8, 6]
# ```
#
# **Constraints:** Length >= 1.

# %%
def product_except_self(nums: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q23. Longest Consecutive
#
# **Problem description:** Return length of longest consecutive sequence.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# nums=[100,4,200,1,3,2]
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** O(n) expected.

# %%
def longest_consecutive(nums: list[int]) -> int:
    pass

# %% [markdown]
# ## Q24. Top K Frequent
#
# **Problem description:** Return k most frequent numbers.
#
# **Input format:** `nums: list[int], k: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[1,1,1,2,2,3], k=2
# ```
#
# **Sample Output:**
# ```python
# [1, 2]
# ```
#
# **Constraints:** k >= 1.

# %%
def top_k_frequent(nums: list[int], k: int) -> list[int]:
    pass

# %% [markdown]
# ## Q25. LRU Cache Simulation
#
# **Problem description:** Return final keys after capacity-limited access sequence.
#
# **Input format:** `capacity: int, operations: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# capacity=2, operations=[1,2,1,3]
# ```
#
# **Sample Output:**
# ```python
# [1, 3]
# ```
#
# **Constraints:** capacity > 0.

# %%
def lru_cache_simulation(capacity: int, operations: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q26. Min Stack Operations
#
# **Problem description:** Process push/pop/min operations and return min outputs.
#
# **Input format:** `operations: list[tuple]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# operations=[('push',3),('push',1),('min',),('pop',),('min',)]
# ```
#
# **Sample Output:**
# ```python
# [1, 3]
# ```
#
# **Constraints:** Valid operations.

# %%
def min_stack_operations(operations: list[tuple]) -> list[int]:
    pass

# %% [markdown]
# ## Q27. Kth Largest
#
# **Problem description:** Return kth largest number.
#
# **Input format:** `nums: list[int], k: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# nums=[3,2,1,5,6,4], k=2
# ```
#
# **Sample Output:**
# ```python
# 5
# ```
#
# **Constraints:** 1 <= k <= len(nums).

# %%
def kth_largest(nums: list[int], k: int) -> int:
    pass

# %% [markdown]
# ## Q28. Deep Flatten
#
# **Problem description:** Flatten arbitrarily nested list of integers.
#
# **Input format:** `items: list`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1,[2,[3]],4]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4]
# ```
#
# **Constraints:** Nested list may be empty.

# %%
def deep_flatten(items: list) -> list[int]:
    pass

# %% [markdown]
# ## Q29. Anagram Groups
#
# **Problem description:** Group words that are anagrams.
#
# **Input format:** `words: list[str]`
#
# **Output format:** `list[list[str]]`
#
# **Sample Input:**
# ```python
# words=['eat','tea','bat']
# ```
#
# **Sample Output:**
# ```python
# [['eat','tea'], ['bat']]
# ```
#
# **Constraints:** Order of groups can vary.

# %%
def anagram_groups(words: list[str]) -> list[list[str]]:
    pass

# %% [markdown]
# ## Q30. Sliding Window Maximum
#
# **Problem description:** Return maximum of every window of size k.
#
# **Input format:** `nums: list[int], k: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[1,3,-1,-3,5], k=3
# ```
#
# **Sample Output:**
# ```python
# [3, 3, 5]
# ```
#
# **Constraints:** 1 <= k <= len(nums).

# %%
def sliding_window_maximum(nums: list[int], k: int) -> list[int]:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Shopping Cart Total
#
# **Problem description:** Return total price from cart rows.
#
# **Input format:** `cart: list[dict]`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# cart=[{'price':10,'qty':2}]
# ```
#
# **Sample Output:**
# ```python
# 20.0
# ```
#
# **Constraints:** Missing qty means 1.

# %%
def shopping_cart_total(cart: list[dict]) -> float:
    pass

# %% [markdown]
# ## Q32. Inventory Update
#
# **Problem description:** Apply sales to inventory and return updated inventory.
#
# **Input format:** `inventory: dict[str, int], sales: dict[str, int]`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# inventory={'pen':10}, sales={'pen':3}
# ```
#
# **Sample Output:**
# ```python
# {'pen': 7}
# ```
#
# **Constraints:** Stock cannot go below 0.

# %%
def inventory_update(inventory: dict[str, int], sales: dict[str, int]) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q33. Log Level Count
#
# **Problem description:** Count log levels from log dictionaries.
#
# **Input format:** `logs: list[dict]`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# logs=[{'level':'ERROR'}, {'level':'INFO'}]
# ```
#
# **Sample Output:**
# ```python
# {'ERROR': 1, 'INFO': 1}
# ```
#
# **Constraints:** Missing level ignored.

# %%
def log_level_count(logs: list[dict]) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q34. Leaderboard
#
# **Problem description:** Return top n players sorted by score.
#
# **Input format:** `players: list[dict], n: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# players=[{'name':'A','score':5}], n=1
# ```
#
# **Sample Output:**
# ```python
# ['A']
# ```
#
# **Constraints:** Higher score first.

# %%
def leaderboard(players: list[dict], n: int) -> list[str]:
    pass

# %% [markdown]
# ## Q35. API Records Index
#
# **Problem description:** Convert list of records into dictionary indexed by id.
#
# **Input format:** `records: list[dict]`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# records=[{'id':1,'name':'A'}]
# ```
#
# **Sample Output:**
# ```python
# {1: {'id': 1, 'name': 'A'}}
# ```
#
# **Constraints:** Every record has id.

# %%
def api_records_index(records: list[dict]) -> dict:
    pass
