# %% [markdown]
# # Database MySQL Connectivity Questions
#
# This notebook contains:
# - Section 1: Basic Questions
# - Section 2: Intermediate Questions
# - Section 3: Advanced Questions
# - Section 4: Real-world Problems
#
# Each question includes:
# - Problem description
# - Input format
# - Output format
# - Sample input
# - Sample output
# - Constraints
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ## Q1. Import MySQL Connector
#
# **Problem Description**
# Write Python code to import `mysql.connector` and print `Connector ready`.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print one success line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Connector ready`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q2. Create a MySQL Config Dictionary
#
# **Problem Description**
# Store `host`, `user`, `password`, `database`, and `port` in a dictionary and print the database name.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print one line containing the database name.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `school_db`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q3. Write a Basic Connection Snippet
#
# **Problem Description**
# Create code that connects to MySQL and prints `Connected` if `is_connected()` is true.
#
# **Input Format**
# `No external input.` Use fixed connection details in the script.
#
# **Output Format**
# Print one status message.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Connected`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q4. Create a Database Query
#
# **Problem Description**
# Write the SQL statement to create a database named `school_db` if it does not already exist and print the query text.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `CREATE DATABASE IF NOT EXISTS school_db`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q5. Create a Table Query
#
# **Problem Description**
# Write the SQL statement to create a `students` table with `id`, `name`, and `email`, then print the query text.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print a multi-line SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `CREATE TABLE IF NOT EXISTS students ...`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q6. Prepare a Safe Insert Query
#
# **Problem Description**
# Create a parameterized `INSERT` query for a `students` table and print the query with its value tuple.
#
# **Input Format**
# `No external input.` Use fixed sample values.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `INSERT INTO students (name, email) VALUES (%s, %s)`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q7. Prepare a Safe Select Query
#
# **Problem Description**
# Write a `SELECT` query that finds students by course using `%s` placeholder and print the query and values tuple.
#
# **Input Format**
# `No external input.` Use a fixed course value.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SELECT name FROM students WHERE course = %s`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q8. Prepare an Update Query
#
# **Problem Description**
# Write a parameterized `UPDATE` query that changes a student's course using email as the identifier.
#
# **Input Format**
# `No external input.` Use fixed values.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `UPDATE students SET course = %s WHERE email = %s`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q9. Prepare a Delete Query
#
# **Problem Description**
# Write a parameterized `DELETE` query that removes a student by email.
#
# **Input Format**
# `No external input.` Use a fixed email.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `DELETE FROM students WHERE email = %s`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# ## Q10. List Fetch Methods
#
# **Problem Description**
# Print the names of the three main cursor fetch methods used after `SELECT` queries.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print three lines.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `fetchone()`
#
# **Constraints**
# Use `mysql.connector` style where relevant. Use safe placeholders `%s` for values.

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ## Q11. Filter Students by Age
#
# **Problem Description**
# Write a query that selects student names where age is greater than or equal to a given value, and print the query plus the parameter tuple.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SELECT name FROM students WHERE age >= %s`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q12. Sort Products by Price
#
# **Problem Description**
# Write a query that selects product name and price, sorts by price descending, and prints the query.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `ORDER BY price DESC`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q13. Use LIMIT in a Query
#
# **Problem Description**
# Write a query that returns only the top 5 student rows ordered by marks descending.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `LIMIT 5`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q14. Prepare a LIKE Search
#
# **Problem Description**
# Write a parameterized query that searches student names starting with `A` and print the query plus the values tuple.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `LIKE %s`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q15. Prepare an Aggregate Count Query
#
# **Problem Description**
# Write a query that counts how many students belong to each course and print the query.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `GROUP BY course`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q16. Prepare an Average Query
#
# **Problem Description**
# Write a query that calculates the average marks for one course and print the query plus parameter tuple.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `AVG(marks)`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q17. Prepare a Bulk Insert Pattern
#
# **Problem Description**
# Create a safe `executemany()` example by printing one insert query and a list of three tuples.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `executemany data ready`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q18. Prepare an Inner Join Query
#
# **Problem Description**
# Write an `INNER JOIN` query that reads student names and batch names from `students` and `enrollments`.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `INNER JOIN enrollments`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q19. Build a Reusable Config Function
#
# **Problem Description**
# Write a function that returns a MySQL config dictionary and print a masked version of it.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'host': 'localhost'`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# ## Q20. Show a Try-Except-Finally Connection Pattern
#
# **Problem Description**
# Write a short code pattern that connects to MySQL, prints a success line, handles errors, and closes the connection in `finally`.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the SQL or status output requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Connection closed`
#
# **Constraints**
# Use proper filtering, ordering, and cursor methods. Keep queries safe and clear.

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ## Q21. Transaction Transfer Pattern
#
# **Problem Description**
# Write code for two parameterized update queries representing money transfer between two accounts and print both queries with their values.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `UPDATE accounts SET balance = balance - %s WHERE account_id = %s`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q22. Rollback Pattern on Error
#
# **Problem Description**
# Write a MySQL code pattern that calls `rollback()` inside `except` and closes the connection in `finally`.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `rollback()`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q23. Unsafe vs Safe Query
#
# **Problem Description**
# Print one unsafe query built with string formatting and one safe parameterized query for user login search.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SELECT * FROM users WHERE email = %s`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q24. Unique Constraint Table Design
#
# **Problem Description**
# Write a `CREATE TABLE` query for `users` where `email` is unique and print the query.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `UNIQUE`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q25. Dictionary Cursor Example
#
# **Problem Description**
# Write connection code that creates a cursor with `dictionary=True` and prints a small success message.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Dictionary cursor ready`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q26. Buffered Cursor Example
#
# **Problem Description**
# Write connection code that creates a buffered cursor and prints a small success message.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Buffered cursor ready`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q27. Metadata Column Name Extraction
#
# **Problem Description**
# Write code that shows how `cursor.description` can be used to collect column names after a query.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `['id', 'name']`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q28. Connection Pooling Config
#
# **Problem Description**
# Write a short example configuration for a MySQL connection pool and print the pool name and size.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `student_pool`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q29. Environment Variable Config Pattern
#
# **Problem Description**
# Write a short example showing config values being read from environment variables and print the host and database only.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `localhost`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# ## Q30. Repository Helper Function
#
# **Problem Description**
# Write a helper function named `run_select_query` that accepts a query and params, and returns fetched rows. Print the function call example.
#
# **Input Format**
# `No external input.` Use fixed values and print the requested pattern.
#
# **Output Format**
# Print the query, code pattern, or status line requested.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `run_select_query`
#
# **Constraints**
# Handle errors carefully. Use transactions or reusable patterns where needed.

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ## Q31. Student Registration Workflow
#
# **Problem Description**
# Write MySQL code that creates a `students` table, inserts three rows, selects Python students, and prints the select query plus sample value tuple.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the requested query text, tuple, or helper result.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `('Python',)`
#
# **Constraints**
# Write the problem as if it belongs to a small production-style app.

# %% [markdown]
# ## Q32. Inventory Low Stock Report
#
# **Problem Description**
# Write a MySQL query that returns item name and quantity where quantity is below a threshold and prints the query plus values tuple.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the requested query text, tuple, or helper result.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `qty < %s`
#
# **Constraints**
# Write the problem as if it belongs to a small production-style app.

# %% [markdown]
# ## Q33. Employee Payroll Summary
#
# **Problem Description**
# Write a MySQL query that returns department-wise total salary using `GROUP BY` and prints the query.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the requested query text, tuple, or helper result.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SUM(salary)`
#
# **Constraints**
# Write the problem as if it belongs to a small production-style app.

# %% [markdown]
# ## Q34. Customer Orders Join
#
# **Problem Description**
# Write a MySQL join query that returns customer name and order amount and prints the query.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the requested query text, tuple, or helper result.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `customers.name, orders.amount`
#
# **Constraints**
# Write the problem as if it belongs to a small production-style app.

# %% [markdown]
# ## Q35. Safe Login Lookup
#
# **Problem Description**
# Write a helper function that returns a parameterized login query and tuple for searching a user by email. Print the returned query and tuple.
#
# **Input Format**
# `No external input.` Use fixed values in the script.
#
# **Output Format**
# Print the requested query text, tuple, or helper result.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `('user@example.com',)`
#
# **Constraints**
# Write the problem as if it belongs to a small production-style app.
