# %% [markdown]
# # Python Iterators and Generators Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. List To Iterator
#
# **Problem description:** Convert a list into an iterator and return the first element using `next()`.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items = [10, 20, 30]
# ```
#
# **Sample Output:**
# ```python
# 10
# ```
#
# **Constraints:** The list will contain at least one element.

# %%
def list_to_iterator(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q2. Iterator Sum Two
#
# **Problem description:** Create an iterator from a list and return the sum of the first two values.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items = [4, 6, 8]
# ```
#
# **Sample Output:**
# ```python
# 10
# ```
#
# **Constraints:** The list will contain at least two integers.

# %%
def iterator_sum_two(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q3. Generate One To N
#
# **Problem description:** Write a generator that yields numbers from 1 to n and return them as a list.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# **Constraints:** 0 <= n <= 100.

# %%
def generate_one_to_n(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q4. Count String Characters
#
# **Problem description:** Iterate over a string using an iterator and return the number of characters.
#
# **Input format:** `text: str`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# text = 'python'
# ```
#
# **Sample Output:**
# ```python
# 6
# ```
#
# **Constraints:** The string may be empty.

# %%
def count_string_characters(text: str) -> int:
    pass

# %% [markdown]
# ## Q5. Safe Next Default
#
# **Problem description:** Use `next(iterator, default)` to return the first item of a list, or -1 if the list is empty.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items = []
# ```
#
# **Sample Output:**
# ```python
# -1
# ```
#
# **Constraints:** The list may be empty.

# %%
def safe_next_default(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q6. Generator Squares
#
# **Problem description:** Create a generator function that yields the square of each number in a list and return the generated values as a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3]
# ```
#
# **Sample Output:**
# ```python
# [1, 4, 9]
# ```
#
# **Constraints:** The list may be empty.

# %%
def generator_squares(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q7. Enumerate Pairs
#
# **Problem description:** Use `enumerate()` starting from 1 and return a list of index-value pairs.
#
# **Input format:** `items: list[str]`
#
# **Output format:** `list[tuple[int, str]]`
#
# **Sample Input:**
# ```python
# items = ['a', 'b']
# ```
#
# **Sample Output:**
# ```python
# [(1, 'a'), (2, 'b')]
# ```
#
# **Constraints:** The list may be empty.

# %%
def enumerate_pairs(items: list[str]) -> list[tuple[int, str]]:
    pass

# %% [markdown]
# ## Q8. Zip Names Scores
#
# **Problem description:** Use `zip()` to combine names and scores and return the paired list.
#
# **Input format:** `names: list[str], scores: list[int]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# names = ['A', 'B'], scores = [90, 80]
# ```
#
# **Sample Output:**
# ```python
# [('A', 90), ('B', 80)]
# ```
#
# **Constraints:** Use the normal zip stopping behavior.

# %%
def zip_names_scores(names: list[str], scores: list[int]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ## Q9. Filter Even Generator
#
# **Problem description:** Use a generator expression to keep only even numbers and return them as a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4, 5, 6]
# ```
#
# **Sample Output:**
# ```python
# [2, 4, 6]
# ```
#
# **Constraints:** The list may be empty.

# %%
def filter_even_generator(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q10. Map Double Values
#
# **Problem description:** Use `map()` to double each value and return the result as a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [2, 4, 6]
# ```
#
# **Sample Output:**
# ```python
# [4, 8, 12]
# ```
#
# **Constraints:** The list may be empty.

# %%
def map_double_values(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Custom Countdown Iterator
#
# **Problem description:** Create a custom iterator class that counts down from n to 1 and return its output as a list.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 4
# ```
#
# **Sample Output:**
# ```python
# [4, 3, 2, 1]
# ```
#
# **Constraints:** 0 <= n <= 50.

# %%
def custom_countdown_iterator(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q12. Running Totals Generator
#
# **Problem description:** Write a generator that yields running totals for a list of integers and return the generated values as a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [3, 5, 2]
# ```
#
# **Sample Output:**
# ```python
# [3, 8, 10]
# ```
#
# **Constraints:** The list may be empty.

# %%
def running_totals_generator(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q13. Batch Items
#
# **Problem description:** Write a generator that yields batches of a list with a given batch size and return the batches as a list.
#
# **Input format:** `items: list[int], size: int`
#
# **Output format:** `list[list[int]]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4, 5], size = 2
# ```
#
# **Sample Output:**
# ```python
# [[1, 2], [3, 4], [5]]
# ```
#
# **Constraints:** size >= 1.

# %%
def batch_items(items: list[int], size: int) -> list[list[int]]:
    pass

# %% [markdown]
# ## Q14. Flatten One Level
#
# **Problem description:** Use `yield from` to flatten a one-level nested list and return the flattened values as a list.
#
# **Input format:** `items: list[list[int]]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [[1, 2], [3], [4, 5]]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# **Constraints:** Inner lists may be empty.

# %%
def flatten_one_level(items: list[list[int]]) -> list[int]:
    pass

# %% [markdown]
# ## Q15. Reverse Iterator Text
#
# **Problem description:** Create a custom reverse iterator for a string and return the reversed string.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'data'
# ```
#
# **Sample Output:**
# ```python
# 'atad'
# ```
#
# **Constraints:** The string may be empty.

# %%
def reverse_iterator_text(text: str) -> str:
    pass

# %% [markdown]
# ## Q16. First N Infinite
#
# **Problem description:** Create an infinite generator of positive integers and return the first n values as a list.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# **Constraints:** 0 <= n <= 50.

# %%
def first_n_infinite(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q17. Generator Exhaustion Demo
#
# **Problem description:** Consume a generator once into a list, then consume it again and return both results.
#
# **Input format:** `n: int`
#
# **Output format:** `tuple[list[int], list[int]]`
#
# **Sample Input:**
# ```python
# n = 3
# ```
#
# **Sample Output:**
# ```python
# ([0, 1, 2], [])
# ```
#
# **Constraints:** 0 <= n <= 20.

# %%
def generator_exhaustion_demo(n: int) -> tuple[list[int], list[int]]:
    pass

# %% [markdown]
# ## Q18. Filter Map Pipeline
#
# **Problem description:** Use lazy filtering and mapping to keep positive numbers, square them, and return the final list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [-2, -1, 0, 3, 4]
# ```
#
# **Sample Output:**
# ```python
# [9, 16]
# ```
#
# **Constraints:** The list may contain negative numbers and zero.

# %%
def filter_map_pipeline(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q19. Iterator Over Dictionary Keys
#
# **Problem description:** Create an iterator over dictionary keys and return the keys as a list in iteration order.
#
# **Input format:** `data: dict[str, int]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# data = {'a': 1, 'b': 2}
# ```
#
# **Sample Output:**
# ```python
# ['a', 'b']
# ```
#
# **Constraints:** Assume normal Python dict ordering.

# %%
def iterator_over_dictionary_keys(data: dict[str, int]) -> list[str]:
    pass

# %% [markdown]
# ## Q20. Skip Every Second
#
# **Problem description:** Write a generator that yields every second element from a list, starting with index 0.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [10, 20, 30, 40, 50]
# ```
#
# **Sample Output:**
# ```python
# [10, 30, 50]
# ```
#
# **Constraints:** The list may be empty.

# %%
def skip_every_second(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Yield From Chain
#
# **Problem description:** Combine three iterables using `yield from` and return the complete result as a list.
#
# **Input format:** `a: list[int], b: tuple[int, ...], c: str`
#
# **Output format:** `list`
#
# **Sample Input:**
# ```python
# a = [1, 2], b = (3, 4), c = 'ab'
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 'a', 'b']
# ```
#
# **Constraints:** Preserve the original order.

# %%
def yield_from_chain(a: list[int], b: tuple[int, ...], c: str) -> list:
    pass

# %% [markdown]
# ## Q22. Manual Next Until Default
#
# **Problem description:** Manually consume an iterator with repeated `next(iterator, default)` calls until a sentinel value appears, then return the consumed values.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [7, 8, 9]
# ```
#
# **Sample Output:**
# ```python
# [7, 8, 9]
# ```
#
# **Constraints:** Use -1 as the sentinel default.

# %%
def manual_next_until_default(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q23. Lazy Chunk Reader
#
# **Problem description:** Write a generator that yields fixed-size chunks from a string and return the chunks as a list.
#
# **Input format:** `text: str, size: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'abcdefgh', size = 3
# ```
#
# **Sample Output:**
# ```python
# ['abc', 'def', 'gh']
# ```
#
# **Constraints:** size >= 1.

# %%
def lazy_chunk_reader(text: str, size: int) -> list[str]:
    pass

# %% [markdown]
# ## Q24. Nested Flatten Recursive
#
# **Problem description:** Write a recursive generator that flattens arbitrarily nested lists of integers and return the flat list.
#
# **Input format:** `items: list`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, [2, [3]], 4]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4]
# ```
#
# **Constraints:** Nested lists may be empty.

# %%
def nested_flatten_recursive(items: list) -> list[int]:
    pass

# %% [markdown]
# ## Q25. Prime Generator
#
# **Problem description:** Write a generator that yields the first n prime numbers and return them as a list.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# [2, 3, 5, 7, 11]
# ```
#
# **Constraints:** 0 <= n <= 20.

# %%
def prime_generator(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q26. Generator Send Echo
#
# **Problem description:** Create a generator that first yields 'ready', then receives a value with `send()` and yields that same value back. Return both yielded values as a tuple.
#
# **Input format:** `message: str`
#
# **Output format:** `tuple[str, str]`
#
# **Sample Input:**
# ```python
# message = 'hello'
# ```
#
# **Sample Output:**
# ```python
# ('ready', 'hello')
# ```
#
# **Constraints:** The message will be a string.

# %%
def generator_send_echo(message: str) -> tuple[str, str]:
    pass

# %% [markdown]
# ## Q27. Sliding Window Generator
#
# **Problem description:** Write a generator that yields each sliding window of size k from a list and return all windows as a list.
#
# **Input format:** `items: list[int], k: int`
#
# **Output format:** `list[list[int]]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4], k = 2
# ```
#
# **Sample Output:**
# ```python
# [[1, 2], [2, 3], [3, 4]]
# ```
#
# **Constraints:** 1 <= k <= len(items) when items is not empty.

# %%
def sliding_window_generator(items: list[int], k: int) -> list[list[int]]:
    pass

# %% [markdown]
# ## Q28. Custom Iterator Step
#
# **Problem description:** Create a custom iterator class that yields numbers from start to end inclusive using a given step and return the output as a list.
#
# **Input format:** `start: int, end: int, step: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# start = 2, end = 8, step = 2
# ```
#
# **Sample Output:**
# ```python
# [2, 4, 6, 8]
# ```
#
# **Constraints:** step > 0 and start <= end.

# %%
def custom_iterator_step(start: int, end: int, step: int) -> list[int]:
    pass

# %% [markdown]
# ## Q29. Duplicate Consecutive Generator
#
# **Problem description:** Write a generator that removes consecutive duplicates from a list and return the result as a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 1, 2, 2, 2, 3, 1, 1]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 1]
# ```
#
# **Constraints:** The list may be empty.

# %%
def duplicate_consecutive_generator(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q30. Merge Sorted Streams
#
# **Problem description:** Given two sorted lists, lazily merge them into one sorted stream and return the merged result as a list.
#
# **Input format:** `a: list[int], b: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# a = [1, 4, 7], b = [2, 3, 8]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 7, 8]
# ```
#
# **Constraints:** Both input lists are already sorted.

# %%
def merge_sorted_streams(a: list[int], b: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Read File Lazily
#
# **Problem description:** Write lines to a local file, then iterate over the file lazily and return the stripped lines as a list.
#
# **Input format:** `lines: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# lines = ['alpha', 'beta']
# ```
#
# **Sample Output:**
# ```python
# ['alpha', 'beta']
# ```
#
# **Constraints:** Use a local file in the current folder.

# %%
def read_file_lazily(lines: list[str]) -> list[str]:
    pass

# %% [markdown]
# ## Q32. Streaming Sales Total
#
# **Problem description:** Use a generator to stream positive sales amounts only and return their total sum.
#
# **Input format:** `sales: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# sales = [10, -5, 20, 0, 15]
# ```
#
# **Sample Output:**
# ```python
# 45
# ```
#
# **Constraints:** Ignore zero and negative values.

# %%
def streaming_sales_total(sales: list[int]) -> int:
    pass

# %% [markdown]
# ## Q33. Paginated Records
#
# **Problem description:** Write a batching generator for records and return the pages as a list of lists.
#
# **Input format:** `records: list[str], page_size: int`
#
# **Output format:** `list[list[str]]`
#
# **Sample Input:**
# ```python
# records = ['r1', 'r2', 'r3', 'r4'], page_size = 3
# ```
#
# **Sample Output:**
# ```python
# [['r1', 'r2', 'r3'], ['r4']]
# ```
#
# **Constraints:** page_size >= 1.

# %%
def paginated_records(records: list[str], page_size: int) -> list[list[str]]:
    pass

# %% [markdown]
# ## Q34. Log Error Filter
#
# **Problem description:** Use a generator expression to return only the log lines that start with 'ERROR'.
#
# **Input format:** `logs: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# logs = ['INFO ok', 'ERROR bad', 'WARNING wait', 'ERROR fail']
# ```
#
# **Sample Output:**
# ```python
# ['ERROR bad', 'ERROR fail']
# ```
#
# **Constraints:** The input list may be empty.

# %%
def log_error_filter(logs: list[str]) -> list[str]:
    pass

# %% [markdown]
# ## Q35. Task Queue Iterator
#
# **Problem description:** Create a custom iterator class over a list of tasks and return the tasks in processing order.
#
# **Input format:** `tasks: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# tasks = ['extract', 'clean', 'load']
# ```
#
# **Sample Output:**
# ```python
# ['extract', 'clean', 'load']
# ```
#
# **Constraints:** The list may be empty.

# %%
def task_queue_iterator(tasks: list[str]) -> list[str]:
    pass
