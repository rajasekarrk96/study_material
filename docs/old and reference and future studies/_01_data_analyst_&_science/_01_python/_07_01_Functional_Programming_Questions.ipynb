# %% [markdown]
# # Functional Programming Questions
#
# This notebook contains structured practice questions from beginner to advanced level.
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ### Q1. Square One Number
#
# **Level:** Basic
#
# **Problem description:**
# Return the square of one integer using a lambda expression stored in a variable.
#
# **Input format:**
# One integer.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# 7
# ```
#
# **Sample Output:**
# ```text
# 49
# ```
#
# **Constraints:**
# Input is between -1000 and 1000.

# %%
square = lambda n: n * n
# Write your solution below

# %% [markdown]
# ### Q2. Double All Numbers
#
# **Level:** Basic
#
# **Problem description:**
# Use `map()` to double every number in a list and return the result as a list.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A list of integers.
#
# **Sample Input:**
# ```text
# [1, 2, 3]
# ```
#
# **Sample Output:**
# ```text
# [2, 4, 6]
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def double_all(numbers: list[int]) -> list[int]:
    pass

# %% [markdown]
# ### Q3. Keep Even Numbers
#
# **Level:** Basic
#
# **Problem description:**
# Use `filter()` to keep only the even numbers from a list.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A list of integers.
#
# **Sample Input:**
# ```text
# [1, 2, 3, 4]
# ```
#
# **Sample Output:**
# ```text
# [2, 4]
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def keep_even(numbers: list[int]) -> list[int]:
    pass

# %% [markdown]
# ### Q4. Sum Numbers
#
# **Level:** Basic
#
# **Problem description:**
# Return the sum of all numbers in a list.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# [5, 10, 15]
# ```
#
# **Sample Output:**
# ```text
# 30
# ```
#
# **Constraints:**
# List may be empty.

# %%
def sum_numbers(numbers: list[int]) -> int:
    pass

# %% [markdown]
# ### Q5. Lowercase Words
#
# **Level:** Basic
#
# **Problem description:**
# Convert all strings in a list to lowercase using a comprehension.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A list of lowercase strings.
#
# **Sample Input:**
# ```text
# ['PyThOn', 'DATA']
# ```
#
# **Sample Output:**
# ```text
# ['python', 'data']
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def lowercase_words(words: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q6. Count Non-Empty Strings
#
# **Level:** Basic
#
# **Problem description:**
# Count how many strings remain after stripping spaces and removing empty strings.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# [' a ', '', 'b', '   ']
# ```
#
# **Sample Output:**
# ```text
# 2
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def count_non_empty(values: list[str]) -> int:
    pass

# %% [markdown]
# ### Q7. Pair Names and Scores
#
# **Level:** Basic
#
# **Problem description:**
# Combine two equal-length lists into a list of tuples using `zip()`.
#
# **Input format:**
# A list of strings and a list of integers.
#
# **Output format:**
# A list of tuples.
#
# **Sample Input:**
# ```text
# ['Asha', 'Ravi'] and [80, 90]
# ```
#
# **Sample Output:**
# ```text
# [('Asha', 80), ('Ravi', 90)]
# ```
#
# **Constraints:**
# Both lists have the same length.

# %%
def pair_names_scores(names: list[str], scores: list[int]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ### Q8. Any Negative
#
# **Level:** Basic
#
# **Problem description:**
# Return `True` if any number in a list is negative.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A boolean value.
#
# **Sample Input:**
# ```text
# [4, -1, 8]
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# List may be empty.

# %%
def any_negative(numbers: list[int]) -> bool:
    pass

# %% [markdown]
# ### Q9. All Positive
#
# **Level:** Basic
#
# **Problem description:**
# Return `True` only if all numbers in a list are positive.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A boolean value.
#
# **Sample Input:**
# ```text
# [2, 5, 9]
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# List may be empty.

# %%
def all_positive(numbers: list[int]) -> bool:
    pass

# %% [markdown]
# ### Q10. Safe Maximum
#
# **Level:** Basic
#
# **Problem description:**
# Return the maximum number in a list or `None` if the list is empty.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# An integer or `None`.
#
# **Sample Input:**
# ```text
# [3, 9, 1]
# ```
#
# **Sample Output:**
# ```text
# 9
# ```
#
# **Constraints:**
# List may be empty.

# %%
def safe_maximum(numbers: list[int]) -> int | None:
    pass

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ### Q11. Frequency Map
#
# **Level:** Intermediate
#
# **Problem description:**
# Return a frequency dictionary for a list of strings.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A dictionary of counts.
#
# **Sample Input:**
# ```text
# ['a', 'b', 'a']
# ```
#
# **Sample Output:**
# ```text
# {'a': 2, 'b': 1}
# ```
#
# **Constraints:**
# List length is between 0 and 5000.

# %%
def frequency_map(items: list[str]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q12. Passed Students
#
# **Level:** Intermediate
#
# **Problem description:**
# Given records with `name` and `score`, return the names whose score is at least the cutoff.
#
# **Input format:**
# A list of dictionaries and one integer cutoff.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# [{'name': 'A', 'score': 80}, {'name': 'B', 'score': 40}] and 50
# ```
#
# **Sample Output:**
# ```text
# ['A']
# ```
#
# **Constraints:**
# Each record contains `name` and `score`.

# %%
def passed_students(records: list[dict], cutoff: int) -> list[str]:
    pass

# %% [markdown]
# ### Q13. Sort by Length
#
# **Level:** Intermediate
#
# **Problem description:**
# Sort a list of strings by length using a lambda key.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A sorted list of strings.
#
# **Sample Input:**
# ```text
# ['python', 'ai', 'data']
# ```
#
# **Sample Output:**
# ```text
# ['ai', 'data', 'python']
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def sort_by_length(words: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q14. Even Squares
#
# **Level:** Intermediate
#
# **Problem description:**
# Return the squares of the even numbers from a list.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A list of integers.
#
# **Sample Input:**
# ```text
# [1, 2, 3, 4]
# ```
#
# **Sample Output:**
# ```text
# [4, 16]
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def even_squares(numbers: list[int]) -> list[int]:
    pass

# %% [markdown]
# ### Q15. Flatten One Level
#
# **Level:** Intermediate
#
# **Problem description:**
# Flatten a list of lists of integers into one list.
#
# **Input format:**
# A list of lists of integers.
#
# **Output format:**
# A flat list of integers.
#
# **Sample Input:**
# ```text
# [[1, 2], [3], [4, 5]]
# ```
#
# **Sample Output:**
# ```text
# [1, 2, 3, 4, 5]
# ```
#
# **Constraints:**
# Nested depth is one level.

# %%
def flatten_once(groups: list[list[int]]) -> list[int]:
    pass

# %% [markdown]
# ### Q16. Extract Names
#
# **Level:** Intermediate
#
# **Problem description:**
# Extract all `name` values from a list of dictionaries.
#
# **Input format:**
# A list of dictionaries.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# [{'name': 'Asha'}, {'name': 'Ravi'}]
# ```
#
# **Sample Output:**
# ```text
# ['Asha', 'Ravi']
# ```
#
# **Constraints:**
# Every dictionary contains `name`.

# %%
def extract_names(records: list[dict]) -> list[str]:
    pass

# %% [markdown]
# ### Q17. Reduce Product
#
# **Level:** Intermediate
#
# **Problem description:**
# Use `reduce()` to calculate the product of a list of integers.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# One integer product.
#
# **Sample Input:**
# ```text
# [2, 3, 4]
# ```
#
# **Sample Output:**
# ```text
# 24
# ```
#
# **Constraints:**
# List contains at least one number.

# %%
def reduce_product(numbers: list[int]) -> int:
    pass

# %% [markdown]
# ### Q18. Normalize Text
#
# **Level:** Intermediate
#
# **Problem description:**
# Strip spaces, lowercase strings, and remove empties from a list.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A list of cleaned strings.
#
# **Sample Input:**
# ```text
# [' Python ', '', ' DATA ']
# ```
#
# **Sample Output:**
# ```text
# ['python', 'data']
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def normalize_text(values: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q19. Group by First Letter
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a dictionary where the key is the first letter and the value is the list of matching words.
#
# **Input format:**
# A list of non-empty strings.
#
# **Output format:**
# A dictionary of lists.
#
# **Sample Input:**
# ```text
# ['apple', 'ant', 'banana']
# ```
#
# **Sample Output:**
# ```text
# {'a': ['apple', 'ant'], 'b': ['banana']}
# ```
#
# **Constraints:**
# Words are non-empty.

# %%
def group_by_first_letter(words: list[str]) -> dict[str, list[str]]:
    pass

# %% [markdown]
# ### Q20. Top Scores
#
# **Level:** Intermediate
#
# **Problem description:**
# Return the scores greater than or equal to 75, preserving order.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A list of integers.
#
# **Sample Input:**
# ```text
# [65, 75, 90, 50]
# ```
#
# **Sample Output:**
# ```text
# [75, 90]
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def top_scores(scores: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ### Q21. Top K Frequent Words
#
# **Level:** Advanced
#
# **Problem description:**
# Return the `k` most frequent words. Break ties alphabetically.
#
# **Input format:**
# A list of strings and one integer `k`.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# ['b', 'a', 'b', 'c', 'a', 'a'] and 2
# ```
#
# **Sample Output:**
# ```text
# ['a', 'b']
# ```
#
# **Constraints:**
# 0 <= k <= number of unique words.

# %%
def top_k_frequent(words: list[str], k: int) -> list[str]:
    pass

# %% [markdown]
# ### Q22. Compose Two Functions
#
# **Level:** Advanced
#
# **Problem description:**
# Write a function that composes two single-argument functions and returns a new function.
#
# **Input format:**
# Two functions.
#
# **Output format:**
# A new function.
#
# **Sample Input:**
# ```text
# double and square
# ```
#
# **Sample Output:**
# ```text
# A function that applies both
# ```
#
# **Constraints:**
# Each input function accepts one value.

# %%
def compose(f, g):
    pass

# %% [markdown]
# ### Q23. Closure Counter
#
# **Level:** Advanced
#
# **Problem description:**
# Create a closure-based counter that returns increasing integers on each call.
#
# **Input format:**
# No standard input.
#
# **Output format:**
# Increasing integer outputs.
#
# **Sample Input:**
# ```text
# call, call, call
# ```
#
# **Sample Output:**
# ```text
# 1 2 3
# ```
#
# **Constraints:**
# Use `nonlocal`.

# %%
def make_counter():
    pass

# %% [markdown]
# ### Q24. Manual Reduce
#
# **Level:** Advanced
#
# **Problem description:**
# Implement a simplified reduce for a list of integers and a combine function.
#
# **Input format:**
# A combine function and a list of integers.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# addition with [1, 2, 3, 4]
# ```
#
# **Sample Output:**
# ```text
# 10
# ```
#
# **Constraints:**
# List contains at least one integer.

# %%
def manual_reduce(combine, values: list[int]) -> int:
    pass

# %% [markdown]
# ### Q25. Unique Stable Filter
#
# **Level:** Advanced
#
# **Problem description:**
# Return unique strings while preserving their first appearance order.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# ['a', 'b', 'a', 'c', 'b']
# ```
#
# **Sample Output:**
# ```text
# ['a', 'b', 'c']
# ```
#
# **Constraints:**
# List length is between 0 and 5000.

# %%
def unique_stable(items: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q26. Score Pipeline
#
# **Level:** Advanced
#
# **Problem description:**
# Return names of students with scores between 60 and 90 inclusive, sorted by score descending.
#
# **Input format:**
# A list of dictionaries.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# [{'name': 'A', 'score': 95}, {'name': 'B', 'score': 88}, {'name': 'C', 'score': 60}]
# ```
#
# **Sample Output:**
# ```text
# ['B', 'C']
# ```
#
# **Constraints:**
# Each record has `name` and `score`.

# %%
def score_pipeline(records: list[dict]) -> list[str]:
    pass

# %% [markdown]
# ### Q27. Partition Even and Odd
#
# **Level:** Advanced
#
# **Problem description:**
# Split numbers into one even list and one odd list.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A tuple of two lists.
#
# **Sample Input:**
# ```text
# [1, 2, 3, 4]
# ```
#
# **Sample Output:**
# ```text
# ([2, 4], [1, 3])
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def partition_even_odd(numbers: list[int]) -> tuple[list[int], list[int]]:
    pass

# %% [markdown]
# ### Q28. Longest Clean Word
#
# **Level:** Advanced
#
# **Problem description:**
# Strip and lowercase words, remove empties, and return the longest cleaned word or `None`.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A string or `None`.
#
# **Sample Input:**
# ```text
# ['  Python ', '', ' ai ']
# ```
#
# **Sample Output:**
# ```text
# python
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def longest_clean_word(words: list[str]) -> str | None:
    pass

# %% [markdown]
# ### Q29. Memoized Fibonacci
#
# **Level:** Advanced
#
# **Problem description:**
# Return the nth Fibonacci number using memoization.
#
# **Input format:**
# One integer `n`.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# 10
# ```
#
# **Sample Output:**
# ```text
# 55
# ```
#
# **Constraints:**
# 0 <= n <= 100

# %%
def memoized_fibonacci(n: int) -> int:
    pass

# %% [markdown]
# ### Q30. Aggregate Sales
#
# **Level:** Advanced
#
# **Problem description:**
# Given `(name, amount)` tuples, return total amount per name.
#
# **Input format:**
# A list of `(str, int)` tuples.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# [('A', 10), ('B', 5), ('A', 7)]
# ```
#
# **Sample Output:**
# ```text
# {'A': 17, 'B': 5}
# ```
#
# **Constraints:**
# Amounts are integers.

# %%
def aggregate_sales(entries: list[tuple[str, int]]) -> dict[str, int]:
    pass

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ### Q31. Clean Survey Responses
#
# **Level:** Real-world
#
# **Problem description:**
# Strip spaces, lowercase responses, remove blank values, and return the cleaned responses.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# [' Yes ', '', 'NO', ' maybe ']
# ```
#
# **Sample Output:**
# ```text
# ['yes', 'no', 'maybe']
# ```
#
# **Constraints:**
# List length is between 0 and 5000.

# %%
def clean_survey_responses(values: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q32. Sales Summary
#
# **Level:** Real-world
#
# **Problem description:**
# Return total sales, average sales, and how many amounts are above average.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A tuple `(total, average, count)`.
#
# **Sample Input:**
# ```text
# [100, 150, 250]
# ```
#
# **Sample Output:**
# ```text
# (500, 166.66666666666666, 1)
# ```
#
# **Constraints:**
# List contains at least one integer.

# %%
def sales_summary(amounts: list[int]) -> tuple[int, float, int]:
    pass

# %% [markdown]
# ### Q33. Tag Articles
#
# **Level:** Real-world
#
# **Problem description:**
# Return dictionaries with article title and title length.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A list of dictionaries.
#
# **Sample Input:**
# ```text
# ['Python Basics', 'Data Science']
# ```
#
# **Sample Output:**
# ```text
# [{'title': 'Python Basics', 'length': 13}, {'title': 'Data Science', 'length': 12}]
# ```
#
# **Constraints:**
# Titles are non-empty strings.

# %%
def tag_articles(titles: list[str]) -> list[dict]:
    pass

# %% [markdown]
# ### Q34. Filter Valid Emails
#
# **Level:** Real-world
#
# **Problem description:**
# Return only strings that contain both `@` and `.` and do not contain spaces.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# ['a@example.com', 'bad email', 'b@test.org']
# ```
#
# **Sample Output:**
# ```text
# ['a@example.com', 'b@test.org']
# ```
#
# **Constraints:**
# List length is between 0 and 5000.

# %%
def filter_valid_emails(values: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q35. Department Payroll Totals
#
# **Level:** Real-world
#
# **Problem description:**
# Given `(department, salary)` tuples, return total salary per department.
#
# **Input format:**
# A list of tuples.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# [('HR', 1000), ('IT', 2000), ('HR', 500)]
# ```
#
# **Sample Output:**
# ```text
# {'HR': 1500, 'IT': 2000}
# ```
#
# **Constraints:**
# Salary values are non-negative integers.

# %%
def payroll_totals(records: list[tuple[str, int]]) -> dict[str, int]:
    pass
