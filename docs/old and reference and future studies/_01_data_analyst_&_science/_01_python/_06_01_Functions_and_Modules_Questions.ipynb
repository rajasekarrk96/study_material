# %% [markdown]
# # Functions and Modules Questions
#
# This notebook is divided into four sections:
# - Section 1: Basic Questions
# - Section 2: Intermediate Questions
# - Section 3: Advanced Questions
# - Section 4: Real-world Problems
#
# No solutions are included in this notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ### Q1. Print Greeting
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that receives a name and returns the string `Hello, <name>!`.
#
# **Input format:**
# A single string representing a name.
#
# **Output format:**
# A greeting string.
#
# **Sample Input:**
# ```text
# Priya
# ```
#
# **Sample Output:**
# ```text
# Hello, Priya!
# ```
#
# **Constraints:**
# Name length is between 1 and 50 characters.

# %%
def greet(name):
    pass

# %% [markdown]
# ### Q2. Add Two Numbers
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that accepts two integers and returns their sum.
#
# **Input format:**
# Two integers.
#
# **Output format:**
# An integer sum.
#
# **Sample Input:**
# ```text
# 12 8
# ```
#
# **Sample Output:**
# ```text
# 20
# ```
#
# **Constraints:**
# Values are between -10^6 and 10^6.

# %%
def add_two_numbers(a, b):
    pass

# %% [markdown]
# ### Q3. Check Even Number
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that returns `True` if a number is even, otherwise `False`.
#
# **Input format:**
# One integer.
#
# **Output format:**
# Boolean result.
#
# **Sample Input:**
# ```text
# 14
# ```
#
# **Sample Output:**
# ```text
# True
# ```
#
# **Constraints:**
# Input is an integer.

# %%
def is_even(number):
    pass

# %% [markdown]
# ### Q4. Square a Number
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that returns the square of a given number.
#
# **Input format:**
# One integer.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# 9
# ```
#
# **Sample Output:**
# ```text
# 81
# ```
#
# **Constraints:**
# Input is between -10^4 and 10^4.

# %%
def square_number(number):
    pass

# %% [markdown]
# ### Q5. Find Maximum
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that accepts three numbers and returns the largest one.
#
# **Input format:**
# Three integers separated by space.
#
# **Output format:**
# Largest integer.
#
# **Sample Input:**
# ```text
# 4 17 9
# ```
#
# **Sample Output:**
# ```text
# 17
# ```
#
# **Constraints:**
# Numbers fit in standard Python int.

# %%
def find_maximum(a, b, c):
    pass

# %% [markdown]
# ### Q6. Default Greeting
#
# **Level:** Basic
#
# **Problem description:**
# Write a function `welcome(name, greeting='Hello')` and return a formatted greeting.
#
# **Input format:**
# A name and optionally a greeting.
#
# **Output format:**
# A string.
#
# **Sample Input:**
# ```text
# Aman
# ```
#
# **Sample Output:**
# ```text
# Hello, Aman!
# ```
#
# **Constraints:**
# Greeting may be omitted.

# %%
def welcome(name, greeting="Hello"):
    pass

# %% [markdown]
# ### Q7. Count Characters
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that returns the number of characters in a string.
#
# **Input format:**
# One string.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# python
# ```
#
# **Sample Output:**
# ```text
# 6
# ```
#
# **Constraints:**
# String may contain spaces.

# %%
def count_characters(text):
    pass

# %% [markdown]
# ### Q8. Return None Demo
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that prints a message but does not return anything. Then observe what gets stored when its output is assigned.
#
# **Input format:**
# One string message.
#
# **Output format:**
# Printed message and implicit return behavior.
#
# **Sample Input:**
# ```text
# Learning Python
# ```
#
# **Sample Output:**
# ```text
# Learning Python
# ```
#
# **Constraints:**
# Focus on understanding returned value.

# %%
def show_message(message):
    pass

# %% [markdown]
# ### Q9. Use Keyword Arguments
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that takes `name` and `age` and returns a formatted sentence. Call it using keyword arguments.
#
# **Input format:**
# A string name and an integer age.
#
# **Output format:**
# A string sentence.
#
# **Sample Input:**
# ```text
# name='Riya', age=21
# ```
#
# **Sample Output:**
# ```text
# Riya is 21 years old.
# ```
#
# **Constraints:**
# Age is between 0 and 120.

# %%
def introduce(name, age):
    pass

# %% [markdown]
# ### Q10. Simple Module Import
#
# **Level:** Basic
#
# **Problem description:**
# Import the built-in `math` module and return the square root of a number.
#
# **Input format:**
# One non-negative integer.
#
# **Output format:**
# A floating-point number.
#
# **Sample Input:**
# ```text
# 49
# ```
#
# **Sample Output:**
# ```text
# 7.0
# ```
#
# **Constraints:**
# Number is between 0 and 10^8.

# %%
def find_square_root(number):
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ### Q11. Sum Using *args
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a function that accepts any number of integers and returns their total using `*args`.
#
# **Input format:**
# A variable number of integers.
#
# **Output format:**
# One integer sum.
#
# **Sample Input:**
# ```text
# 1 2 3 4 5
# ```
#
# **Sample Output:**
# ```text
# 15
# ```
#
# **Constraints:**
# At least one integer is provided.

# %%
def sum_using_args(*numbers):
    pass

# %% [markdown]
# ### Q12. Profile Builder with **kwargs
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a function that accepts keyword arguments and returns them as a dictionary.
#
# **Input format:**
# Any number of keyword arguments.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# name='Kiran', city='Delhi'
# ```
#
# **Sample Output:**
# ```text
# {'name': 'Kiran', 'city': 'Delhi'}
# ```
#
# **Constraints:**
# Keys are strings.

# %%
def profile_builder(**details):
    pass

# %% [markdown]
# ### Q13. Factorial Recursion
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a recursive function to calculate factorial of a non-negative integer.
#
# **Input format:**
# One integer `n`.
#
# **Output format:**
# Factorial of `n`.
#
# **Sample Input:**
# ```text
# 5
# ```
#
# **Sample Output:**
# ```text
# 120
# ```
#
# **Constraints:**
# 0 <= n <= 12

# %%
def factorial_recursive(n):
    pass

# %% [markdown]
# ### Q14. Fibonacci Recursion
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a recursive function that returns the nth Fibonacci number.
#
# **Input format:**
# One integer `n`.
#
# **Output format:**
# Nth Fibonacci number.
#
# **Sample Input:**
# ```text
# 7
# ```
#
# **Sample Output:**
# ```text
# 13
# ```
#
# **Constraints:**
# 0 <= n <= 20

# %%
def fibonacci_recursive(n):
    pass

# %% [markdown]
# ### Q15. Safe Average
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a function that returns the average of a list of numbers. Return 0 for an empty list.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# A float or integer average.
#
# **Sample Input:**
# ```text
# 10 20 30
# ```
#
# **Sample Output:**
# ```text
# 20.0
# ```
#
# **Constraints:**
# List length can be 0 to 10^5.

# %%
def safe_average(values):
    pass

# %% [markdown]
# ### Q16. Lambda Sorting
#
# **Level:** Intermediate
#
# **Problem description:**
# Given a list of tuples `(name, marks)`, sort it by marks in descending order using a lambda function.
#
# **Input format:**
# A list of tuples.
#
# **Output format:**
# Sorted list of tuples.
#
# **Sample Input:**
# ```text
# [('A', 80), ('B', 95), ('C', 88)]
# ```
#
# **Sample Output:**
# ```text
# [('B', 95), ('C', 88), ('A', 80)]
# ```
#
# **Constraints:**
# Marks are integers.

# %%
def sort_by_marks(records):
    pass

# %% [markdown]
# ### Q17. Local vs Global
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a global variable and a function that reads it. Also create a local variable inside the function and print both.
#
# **Input format:**
# No external input required.
#
# **Output format:**
# Printed values showing scope behavior.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Displays global and local values
# ```
#
# **Constraints:**
# Focus on scope rules.

# %%
def show_scope():
    pass

# %% [markdown]
# ### Q18. Discount Calculator
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a function with type hints that returns the discounted price after subtracting a percentage.
#
# **Input format:**
# Two floats: price and percentage.
#
# **Output format:**
# Discounted price as float.
#
# **Sample Input:**
# ```text
# 1000 10
# ```
#
# **Sample Output:**
# ```text
# 900.0
# ```
#
# **Constraints:**
# 0 <= percentage <= 100

# %%
def discount_price(price: float, percent: float) -> float:
    pass

# %% [markdown]
# ### Q19. Selective Import
#
# **Level:** Intermediate
#
# **Problem description:**
# Use `from math import factorial` and return factorial of a number.
#
# **Input format:**
# One integer.
#
# **Output format:**
# One integer factorial.
#
# **Sample Input:**
# ```text
# 6
# ```
#
# **Sample Output:**
# ```text
# 720
# ```
#
# **Constraints:**
# 0 <= n <= 12

# %%
def factorial_value(number):
    pass

# %% [markdown]
# ### Q20. Main Guard Purpose
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a small script structure that prints one line when run directly and another line when imported.
#
# **Input format:**
# No runtime input.
#
# **Output format:**
# Demonstration of main guard behavior.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Direct run message or imported message
# ```
#
# **Constraints:**
# Conceptual implementation question.

# %%
def main_guard_demo(is_direct):
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ### Q21. Memoized Fibonacci
#
# **Level:** Advanced
#
# **Problem description:**
# Write a function that computes Fibonacci numbers efficiently using caching inside a helper function or dictionary.
#
# **Input format:**
# One integer `n`.
#
# **Output format:**
# Nth Fibonacci number.
#
# **Sample Input:**
# ```text
# 10
# ```
#
# **Sample Output:**
# ```text
# 55
# ```
#
# **Constraints:**
# 0 <= n <= 100

# %%
def memoized_fibonacci(n):
    pass

# %% [markdown]
# ### Q22. Function Returning Function
#
# **Level:** Advanced
#
# **Problem description:**
# Write a function `make_multiplier(n)` that returns another function which multiplies its input by `n`.
#
# **Input format:**
# One integer multiplier and later one integer input.
#
# **Output format:**
# Computed product.
#
# **Sample Input:**
# ```text
# 3 then 7
# ```
#
# **Sample Output:**
# ```text
# 21
# ```
#
# **Constraints:**
# Inputs are integers.

# %%
def make_multiplier(n):
    pass

# %% [markdown]
# ### Q23. Closure Counter
#
# **Level:** Advanced
#
# **Problem description:**
# Create a closure-based counter function that remembers its state between calls.
#
# **Input format:**
# No fixed input.
#
# **Output format:**
# Increasing integers on repeated calls.
#
# **Sample Input:**
# ```text
# call, call, call
# ```
#
# **Sample Output:**
# ```text
# 1 2 3
# ```
#
# **Constraints:**
# Use inner function behavior.

# %%
def make_counter():
    pass

# %% [markdown]
# ### Q24. Decorator Logger
#
# **Level:** Advanced
#
# **Problem description:**
# Write a decorator that prints the function name before running the wrapped function.
#
# **Input format:**
# A function as input.
#
# **Output format:**
# Wrapped function output plus log line.
#
# **Sample Input:**
# ```text
# say_hello('Neha')
# ```
#
# **Sample Output:**
# ```text
# Running say_hello\nHello Neha
# ```
#
# **Constraints:**
# Keep the decorator simple.

# %%
def logger_decorator(func):
    pass

# %% [markdown]
# ### Q25. Shadowing Built-ins
#
# **Level:** Advanced
#
# **Problem description:**
# Show why naming a variable `sum` is risky and then fix the problem in a clean solution.
#
# **Input format:**
# A list of integers.
#
# **Output format:**
# Correct numeric total.
#
# **Sample Input:**
# ```text
# 1 2 3
# ```
#
# **Sample Output:**
# ```text
# 6
# ```
#
# **Constraints:**
# Explain the namespace issue.

# %%
def total_numbers(values):
    pass

# %% [markdown]
# ### Q26. Recursive Directory Planner
#
# **Level:** Advanced
#
# **Problem description:**
# Without touching the file system, write a recursive function that counts nested items in a dictionary-based folder structure.
#
# **Input format:**
# A nested dictionary/list structure.
#
# **Output format:**
# An integer count.
#
# **Sample Input:**
# ```text
# {'root': ['a', {'sub': ['b', 'c']} ]}
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# Only count file names as leaf strings.

# %%
def count_files(structure):
    pass

# %% [markdown]
# ### Q27. Import Alias Use
#
# **Level:** Advanced
#
# **Problem description:**
# Import `math` as `m` and use the alias to compute area of a circle.
#
# **Input format:**
# One float radius.
#
# **Output format:**
# Area as float.
#
# **Sample Input:**
# ```text
# 2
# ```
#
# **Sample Output:**
# ```text
# 12.566370614359172
# ```
#
# **Constraints:**
# Radius is non-negative.

# %%
def circle_area(radius):
    pass

# %% [markdown]
# ### Q28. Package Import Design
#
# **Level:** Advanced
#
# **Problem description:**
# Design import statements for a package with modules `cleaning`, `charts`, and `reports`, then show how each function would be called.
#
# **Input format:**
# Conceptual package structure.
#
# **Output format:**
# Valid example import and call statements.
#
# **Sample Input:**
# ```text
# N/A
# ```
#
# **Sample Output:**
# ```text
# Sample import lines
# ```
#
# **Constraints:**
# No actual files required.

# %%
def package_import_examples():
    pass

# %% [markdown]
# ### Q29. Argument Unpacking
#
# **Level:** Advanced
#
# **Problem description:**
# Write a function that accepts three parameters and call it by unpacking a list and a dictionary.
#
# **Input format:**
# A list of three values and a dictionary of three keys.
#
# **Output format:**
# Two formatted output lines.
#
# **Sample Input:**
# ```text
# [1, 2, 3] and {'a': 4, 'b': 5, 'c': 6}
# ```
#
# **Sample Output:**
# ```text
# 1-2-3 and 4-5-6
# ```
#
# **Constraints:**
# Use `*` and `**` unpacking.

# %%
def show_values(a, b, c):
    pass

# %% [markdown]
# ### Q30. Custom Utility Module Plan
#
# **Level:** Advanced
#
# **Problem description:**
# Describe and code a small utility module layout for text processing functions: clean text, count words, and title-case text.
#
# **Input format:**
# A sample sentence string.
#
# **Output format:**
# Processed outputs from three helpers.
#
# **Sample Input:**
# ```text
#   hello python world
# ```
#
# **Sample Output:**
# ```text
# hello python world / 3 / Hello Python World
# ```
#
# **Constraints:**
# Use separate helper functions.

# %%
def clean_text(text):
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ### Q31. Payroll Calculator
#
# **Level:** Real-world
#
# **Problem description:**
# Write a function that calculates net salary after tax deduction. Place tax logic in a separate helper function.
#
# **Input format:**
# Gross salary and tax percentage.
#
# **Output format:**
# Net salary.
#
# **Sample Input:**
# ```text
# 50000 10
# ```
#
# **Sample Output:**
# ```text
# 45000.0
# ```
#
# **Constraints:**
# 0 <= tax <= 100

# %%
def calculate_tax(gross_salary, tax_percent):
    pass

# %% [markdown]
# ### Q32. Student Report Module
#
# **Level:** Real-world
#
# **Problem description:**
# Design functions to calculate total marks, percentage, and grade for a student. Organize them as if they belong to one module.
#
# **Input format:**
# A list of marks.
#
# **Output format:**
# Total, percentage, and grade.
#
# **Sample Input:**
# ```text
# 88 76 91 84
# ```
#
# **Sample Output:**
# ```text
# 339, 84.75, A
# ```
#
# **Constraints:**
# Each mark is between 0 and 100.

# %%
def total_marks(marks):
    pass

# %% [markdown]
# ### Q33. Temperature Converter Toolkit
#
# **Level:** Real-world
#
# **Problem description:**
# Create a mini toolkit with functions for Celsius to Fahrenheit, Fahrenheit to Celsius, and Kelvin conversion validation.
#
# **Input format:**
# One numeric temperature and conversion choice.
#
# **Output format:**
# Converted temperature or validation message.
#
# **Sample Input:**
# ```text
# 25 C_TO_F
# ```
#
# **Sample Output:**
# ```text
# 77.0
# ```
#
# **Constraints:**
# Kelvin cannot be negative.

# %%
def celsius_to_fahrenheit(celsius):
    pass

# %% [markdown]
# ### Q34. Invoice Generator
#
# **Level:** Real-world
#
# **Problem description:**
# Write reusable functions to compute subtotal, tax, and final bill from a list of item prices.
#
# **Input format:**
# A list of prices and a tax percentage.
#
# **Output format:**
# Subtotal, tax amount, final total.
#
# **Sample Input:**
# ```text
# 100 250 150 with tax 18
# ```
#
# **Sample Output:**
# ```text
# 500, 90, 590
# ```
#
# **Constraints:**
# Prices are non-negative.

# %%
def subtotal(prices):
    pass

# %% [markdown]
# ### Q35. Text Analytics Helper
#
# **Level:** Real-world
#
# **Problem description:**
# Create module-style functions to clean text, count words, and find the most frequent word in a sentence.
#
# **Input format:**
# One sentence string.
#
# **Output format:**
# Cleaned text, word count, and most frequent word.
#
# **Sample Input:**
# ```text
# Python is great, and Python is easy
# ```
#
# **Sample Output:**
# ```text
# python is great and python is easy / 7 / python
# ```
#
# **Constraints:**
# Ignore punctuation and case.

# %%
def clean_sentence(text):
    pass
