# %% [markdown]
# # Database SQL Server Connectivity Questions
#
# This notebook contains:
# - Section 1: Basic Questions
# - Section 2: Intermediate Questions
# - Section 3: Advanced Questions
# - Section 4: Real-world Problems
#
# Each question includes:
# - Problem description
# - Input format
# - Output format
# - Sample input
# - Sample output
# - Constraints
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ## Q1. Import pyodbc
#
# **Problem Description**
# Write Python code to import `pyodbc` and print `pyodbc ready`.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print one success line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `pyodbc ready`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q2. Create a SQL Server Connection String
#
# **Problem Description**
# Build a SQL Server authentication connection string and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the connection string.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `DRIVER={ODBC Driver 17 for SQL Server};...`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q3. Create a Trusted Connection String
#
# **Problem Description**
# Build a Windows trusted SQL Server connection string and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the connection string.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Trusted_Connection=yes;`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q4. Write a Basic Connection Snippet
#
# **Problem Description**
# Write code that connects to SQL Server using `pyodbc.connect()` and prints `Connected` on success.
#
# **Input Format**
# `No external input.` Use fixed connection details.
#
# **Output Format**
# Print one status message.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Connected`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q5. Create a Database Script
#
# **Problem Description**
# Write a SQL Server script that creates `school_db` only if it does not already exist and print the script.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL script.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `IF DB_ID('school_db') IS NULL`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q6. Create a Students Table Script
#
# **Problem Description**
# Write a SQL Server `CREATE TABLE` script for `students` with `IDENTITY(1,1)` and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL script.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `IDENTITY(1,1)`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q7. Prepare a Safe Insert Query
#
# **Problem Description**
# Create a parameterized insert query for `students` and print the query and tuple of values.
#
# **Input Format**
# `No external input.` Use fixed values.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `INSERT INTO students (name, email, age, course) VALUES (?, ?, ?, ?)`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q8. Prepare a Safe Select Query
#
# **Problem Description**
# Write a SQL Server select query that filters students by course and print the query plus values tuple.
#
# **Input Format**
# `No external input.` Use a fixed course.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SELECT name FROM students WHERE course = ?`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q9. Prepare an Update Query
#
# **Problem Description**
# Write a parameterized update query that changes course using email as the identifier.
#
# **Input Format**
# `No external input.` Use fixed values.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `UPDATE students SET course = ? WHERE email = ?`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# ## Q10. List Fetch Methods
#
# **Problem Description**
# Print the names of the three main fetch methods used with a cursor after `SELECT` queries.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print three lines.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `fetchone()`
#
# **Constraints**
# Use SQL Server or `pyodbc` style where relevant. Use safe `?` placeholders.

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ## Q11. Prepare a Delete Query
#
# **Problem Description**
# Write a parameterized delete query that removes a student by email and print the query with values.
#
# **Input Format**
# `No external input.` Use a fixed email.
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `DELETE FROM students WHERE email = ?`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q12. Use TOP in a Query
#
# **Problem Description**
# Write a query that returns the top 5 students ordered by marks descending and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SELECT TOP 5`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q13. Prepare a LIKE Query
#
# **Problem Description**
# Write a parameterized query that finds student names starting with `A` and print the query and values tuple.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `LIKE ?`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q14. Prepare a Count Grouping Query
#
# **Problem Description**
# Write a query that counts students per course using `GROUP BY` and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `GROUP BY course`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q15. Prepare an Average Query
#
# **Problem Description**
# Write a query that finds average marks for one course and print the query with values tuple.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `AVG(marks)`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q16. Prepare a Bulk Insert Pattern
#
# **Problem Description**
# Print one SQL Server insert query and a list of three tuples suitable for `executemany()`.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the query and all tuples.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `executemany data ready`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q17. Prepare an Inner Join Query
#
# **Problem Description**
# Write a SQL Server inner join query that returns student names and batch names.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `INNER JOIN enrollments`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q18. Prepare a Stored Procedure Call
#
# **Problem Description**
# Write a parameterized stored procedure call that gets top students above a given score and print the call plus values.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the procedure call and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `EXEC GetTopStudents ?`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q19. Build a Reusable Connection String Function
#
# **Problem Description**
# Write a helper function that returns a SQL Server connection string and print the returned string.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the connection string.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SERVER=localhost;`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# ## Q20. Show Try-Except-Finally Connection Pattern
#
# **Problem Description**
# Write a short `pyodbc` connection pattern that prints success, handles errors, and closes the connection.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print a status line and a final closing line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Connection closed`
#
# **Constraints**
# Keep SQL clear, use SQL Server syntax, and print the requested pattern or output.

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ## Q21. Transaction Transfer Pattern
#
# **Problem Description**
# Write two parameterized update queries that represent a money transfer between two accounts and print both queries with their tuples.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print both queries and both tuples.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `UPDATE accounts SET balance = balance - ? WHERE account_id = ?`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q22. Rollback Pattern on Error
#
# **Problem Description**
# Write a code pattern that rolls back a transaction inside `except pyodbc.Error` and closes resources in `finally`.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print `rollback()` when the error branch runs.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `rollback()`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q23. Unsafe vs Safe Query
#
# **Problem Description**
# Print one unsafe SQL Server login query and one safe parameterized version.
#
# **Input Format**
# `No external input.` Use a fixed risky email string.
#
# **Output Format**
# Print two query lines.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SELECT * FROM users WHERE email = ?`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q24. Unique Constraint Table Design
#
# **Problem Description**
# Write a SQL Server create table script for `users` where `email` is unique and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL script.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `UNIQUE`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q25. Metadata Column Extraction
#
# **Problem Description**
# Show how to collect column names from `cursor.description` and print the final Python list.
#
# **Input Format**
# `No external input.` Use a fixed sample `description` object.
#
# **Output Format**
# Print a list of column names.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `['id', 'name']`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q26. Environment Variable Config Pattern
#
# **Problem Description**
# Write a short example that reads SQL Server host and database from environment variables and prints them.
#
# **Input Format**
# `No external input.` Set fixed env values in the script.
#
# **Output Format**
# Print two lines.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `localhost`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q27. Trusted Connection Config Helper
#
# **Problem Description**
# Write a helper function that returns a trusted SQL Server connection string and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the connection string.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Trusted_Connection=yes;`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q28. Table Existence Check Script
#
# **Problem Description**
# Write a SQL Server script that checks whether a table exists before creating it and print the script.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL script.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `IF OBJECT_ID('students', 'U') IS NULL`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q29. Repository Helper Function
#
# **Problem Description**
# Write a helper function named `run_select_query` that accepts a query and params and prints a sample call result string.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print one line showing the sample call.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `run_select_query`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# ## Q30. ODBC Driver Readiness Message
#
# **Problem Description**
# Write a small script that prints a friendly message about verifying the SQL Server ODBC driver before connecting.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print one line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Verify ODBC Driver 17 for SQL Server is installed`
#
# **Constraints**
# Handle transactions, errors, or advanced SQL Server patterns carefully.

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ## Q31. Student Registration Workflow
#
# **Problem Description**
# Write SQL Server code patterns for creating a students table, inserting rows, and selecting Python learners. Print the select query and tuple used for filtering.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the select query and its parameter tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `('Python',)`
#
# **Constraints**
# Frame the solution like a small real application task using SQL Server connectivity.

# %% [markdown]
# ## Q32. Inventory Low Stock Report
#
# **Problem Description**
# Write a SQL Server query that returns item name and quantity where stock is below a threshold and print the query with values tuple.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `qty < ?`
#
# **Constraints**
# Frame the solution like a small real application task using SQL Server connectivity.

# %% [markdown]
# ## Q33. Employee Payroll Summary
#
# **Problem Description**
# Write a SQL Server query that returns department-wise total salary and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `SUM(salary)`
#
# **Constraints**
# Frame the solution like a small real application task using SQL Server connectivity.

# %% [markdown]
# ## Q34. Customer Orders Join
#
# **Problem Description**
# Write a SQL Server join query that returns customer name and order amount and print it.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the SQL query.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `customers.name, orders.amount`
#
# **Constraints**
# Frame the solution like a small real application task using SQL Server connectivity.

# %% [markdown]
# ## Q35. Safe Login Lookup Helper
#
# **Problem Description**
# Write a helper function that returns a parameterized SQL Server login query and values tuple for searching a user by email, then print both.
#
# **Input Format**
# `No external input.`
#
# **Output Format**
# Print the query and tuple.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `('user@example.com',)`
#
# **Constraints**
# Frame the solution like a small real application task using SQL Server connectivity.
