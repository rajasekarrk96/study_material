# %% [markdown]
# # Python Modules and Standard Library Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Import Math Sqrt
#
# **Problem description:** Import the `math` module and return the square root of a given integer using `math.sqrt`.
#
# **Input format:** `number: int`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# number = 49
# ```
#
# **Sample Output:**
# ```python
# 7.0
# ```
#
# **Constraints:** The number will be non-negative.

# %%
def import_math_sqrt(number: int) -> float:
    pass

# %% [markdown]
# ## Q2. Selective Import Power
#
# **Problem description:** Use `from math import pow` and return `pow(a, b)`.
#
# **Input format:** `a: int, b: int`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# a = 2, b = 3
# ```
#
# **Sample Output:**
# ```python
# 8.0
# ```
#
# **Constraints:** Both inputs are integers.

# %%
def selective_import_power(a: int, b: int) -> float:
    pass

# %% [markdown]
# ## Q3. Random Choice
#
# **Problem description:** Use `random.choice` to return one item from a non-empty list.
#
# **Input format:** `items: list[str]`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# items = ['python', 'sql', 'excel']
# ```
#
# **Sample Output:**
# ```python
# 'python' or another list item
# ```
#
# **Constraints:** The list will contain at least one value.

# %%
def random_choice(items: list[str]) -> str:
    pass

# %% [markdown]
# ## Q4. Path Filename
#
# **Problem description:** Use `pathlib.Path` and return only the file name part from a given path string.
#
# **Input format:** `path_text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# path_text = 'reports/output.txt'
# ```
#
# **Sample Output:**
# ```python
# 'output.txt'
# ```
#
# **Constraints:** The string represents a file path.

# %%
def path_filename(path_text: str) -> str:
    pass

# %% [markdown]
# ## Q5. Current Date String
#
# **Problem description:** Use `date.today()` from `datetime` and return the date as a string in `YYYY-MM-DD` format.
#
# **Input format:** `unused: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# '2026-04-27' like date string
# ```
#
# **Constraints:** Return today's date string.

# %%
def current_date_string(unused: int) -> str:
    pass

# %% [markdown]
# ## Q6. Json Dumps Dict
#
# **Problem description:** Convert a dictionary to a JSON string using `json.dumps` and return it.
#
# **Input format:** `data: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# data = {'name': 'Asha'}
# ```
#
# **Sample Output:**
# ```python
# '{"name": "Asha"}'
# ```
#
# **Constraints:** The dictionary will be JSON serializable.

# %%
def json_dumps_dict(data: dict) -> str:
    pass

# %% [markdown]
# ## Q7. Counter Most Common
#
# **Problem description:** Use `collections.Counter` to return the most common item from a list of strings.
#
# **Input format:** `items: list[str]`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# items = ['a', 'b', 'a']
# ```
#
# **Sample Output:**
# ```python
# 'a'
# ```
#
# **Constraints:** The list will be non-empty.

# %%
def counter_most_common(items: list[str]) -> str:
    pass

# %% [markdown]
# ## Q8. Deque Left Pop
#
# **Problem description:** Use `collections.deque` and return the first item removed with `popleft`.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items = [10, 20, 30]
# ```
#
# **Sample Output:**
# ```python
# 10
# ```
#
# **Constraints:** The list will be non-empty.

# %%
def deque_left_pop(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q9. Statistics Mean
#
# **Problem description:** Use `statistics.mean` to return the average of a list of numbers.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# items = [10, 20, 30]
# ```
#
# **Sample Output:**
# ```python
# 20
# ```
#
# **Constraints:** The list will be non-empty.

# %%
def statistics_mean(items: list[int]) -> float:
    pass

# %% [markdown]
# ## Q10. Chain Lists
#
# **Problem description:** Use `itertools.chain` to combine two lists and return the result as a list.
#
# **Input format:** `a: list[int], b: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# a = [1, 2], b = [3, 4]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4]
# ```
#
# **Constraints:** The lists may be empty.

# %%
def chain_lists(a: list[int], b: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Defaultdict Group
#
# **Problem description:** Use `defaultdict(list)` to group words by their first letter and return the grouped dictionary.
#
# **Input format:** `words: list[str]`
#
# **Output format:** `dict[str, list[str]]`
#
# **Sample Input:**
# ```python
# words = ['apple', 'ant', 'bat']
# ```
#
# **Sample Output:**
# ```python
# {'a': ['apple', 'ant'], 'b': ['bat']}
# ```
#
# **Constraints:** Words are non-empty strings.

# %%
def defaultdict_group(words: list[str]) -> dict[str, list[str]]:
    pass

# %% [markdown]
# ## Q12. Date Add Days
#
# **Problem description:** Use `timedelta` to add a given number of days to a date string in `YYYY-MM-DD` format and return the new date string.
#
# **Input format:** `date_text: str, days: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# date_text = '2026-04-27', days = 5
# ```
#
# **Sample Output:**
# ```python
# '2026-05-02'
# ```
#
# **Constraints:** The input date string is valid.

# %%
def date_add_days(date_text: str, days: int) -> str:
    pass

# %% [markdown]
# ## Q13. Json Loads Name
#
# **Problem description:** Use `json.loads` to parse a JSON string and return the value of the `name` key.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = '{"name": "Asha", "score": 90}'
# ```
#
# **Sample Output:**
# ```python
# 'Asha'
# ```
#
# **Constraints:** The JSON text contains the `name` key.

# %%
def json_loads_name(text: str) -> str:
    pass

# %% [markdown]
# ## Q14. Path Exists Check
#
# **Problem description:** Use `pathlib.Path.exists()` to check if a local file exists and return the boolean result.
#
# **Input format:** `filename: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# filename = 'sample.txt'
# ```
#
# **Sample Output:**
# ```python
# True or False
# ```
#
# **Constraints:** Use the current folder.

# %%
def path_exists_check(filename: str) -> bool:
    pass

# %% [markdown]
# ## Q15. Combinations Of Two
#
# **Problem description:** Use `itertools.combinations` to return all size-2 combinations from a list as a list of tuples.
#
# **Input format:** `items: list[str]`
#
# **Output format:** `list[tuple[str, str]]`
#
# **Sample Input:**
# ```python
# items = ['a', 'b', 'c']
# ```
#
# **Sample Output:**
# ```python
# [('a', 'b'), ('a', 'c'), ('b', 'c')]
# ```
#
# **Constraints:** The list length is at least 2.

# %%
def combinations_of_two(items: list[str]) -> list[tuple[str, str]]:
    pass

# %% [markdown]
# ## Q16. System Version Major
#
# **Problem description:** Use `sys.version_info` to return the Python major version number.
#
# **Input format:** `unused: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** Return the running interpreter major version.

# %%
def system_version_major(unused: int) -> int:
    pass

# %% [markdown]
# ## Q17. Csv Read Names
#
# **Problem description:** Use `csv.DictReader` to read CSV text and return the list of names from the `name` column.
#
# **Input format:** `csv_text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# csv_text = 'name,score\nAsha,95\nRavi,88\n'
# ```
#
# **Sample Output:**
# ```python
# ['Asha', 'Ravi']
# ```
#
# **Constraints:** The CSV text has a `name` column.

# %%
def csv_read_names(csv_text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q18. Regex Find Digits
#
# **Problem description:** Use `re.findall` to return all digit groups in a string.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'Room 12, Floor 5'
# ```
#
# **Sample Output:**
# ```python
# ['12', '5']
# ```
#
# **Constraints:** The text may contain zero or more digit groups.

# %%
def regex_find_digits(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q19. Namedtuple Point
#
# **Problem description:** Use `namedtuple` to create a Point with x and y fields and return the sum of x and y.
#
# **Input format:** `x: int, y: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# x = 3, y = 4
# ```
#
# **Sample Output:**
# ```python
# 7
# ```
#
# **Constraints:** Both inputs are integers.

# %%
def namedtuple_point(x: int, y: int) -> int:
    pass

# %% [markdown]
# ## Q20. Os Getcwd Name
#
# **Problem description:** Use `os.getcwd()` and return only the final folder name from the current working directory.
#
# **Input format:** `unused: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# '_01_python' like folder name
# ```
#
# **Constraints:** Return the current folder name only.

# %%
def os_getcwd_name(unused: int) -> str:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Counter Sorted Frequencies
#
# **Problem description:** Use `Counter` to count word frequencies and return a list of `(word, count)` pairs sorted by descending count and then alphabetically.
#
# **Input format:** `words: list[str]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# words = ['b', 'a', 'b', 'c', 'a', 'a']
# ```
#
# **Sample Output:**
# ```python
# [('a', 3), ('b', 2), ('c', 1)]
# ```
#
# **Constraints:** The list may be empty.

# %%
def counter_sorted_frequencies(words: list[str]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ## Q22. Json Report To File
#
# **Problem description:** Use `json.dumps` and `pathlib.Path.write_text` to save a dictionary as JSON to a local file, then read it back and return the parsed dictionary.
#
# **Input format:** `data: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# data = {'topic': 'python'}
# ```
#
# **Sample Output:**
# ```python
# {'topic': 'python'}
# ```
#
# **Constraints:** The dictionary is JSON serializable.

# %%
def json_report_to_file(data: dict) -> dict:
    pass

# %% [markdown]
# ## Q23. Datetime Parse Format
#
# **Problem description:** Use `datetime.strptime` to parse a date-time string and `strftime` to format it as `DD/MM/YYYY HH:MM`.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = '2026-04-27 15:45'
# ```
#
# **Sample Output:**
# ```python
# '27/04/2026 15:45'
# ```
#
# **Constraints:** The input format is `%Y-%m-%d %H:%M`.

# %%
def datetime_parse_format(text: str) -> str:
    pass

# %% [markdown]
# ## Q24. Itertools Product Pairs
#
# **Problem description:** Use `itertools.product` to return all ordered pairs from two input lists.
#
# **Input format:** `a: list[str], b: list[int]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# a = ['x', 'y'], b = [1, 2]
# ```
#
# **Sample Output:**
# ```python
# [('x', 1), ('x', 2), ('y', 1), ('y', 2)]
# ```
#
# **Constraints:** The lists may be empty.

# %%
def itertools_product_pairs(a: list[str], b: list[int]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ## Q25. Statistics Median Safe
#
# **Problem description:** Use `statistics.median` to return the median of a list, or `'Empty'` when the list is empty.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `str | float | int`
#
# **Sample Input:**
# ```python
# items = []
# ```
#
# **Sample Output:**
# ```python
# 'Empty'
# ```
#
# **Constraints:** The list may be empty.

# %%
def statistics_median_safe(items: list[int]) -> str | float | int:
    pass

# %% [markdown]
# ## Q26. Deque Rotation
#
# **Problem description:** Use `deque.rotate` to rotate a list right by k positions and return the rotated list.
#
# **Input format:** `items: list[int], k: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4], k = 1
# ```
#
# **Sample Output:**
# ```python
# [4, 1, 2, 3]
# ```
#
# **Constraints:** The list may be empty.

# %%
def deque_rotation(items: list[int], k: int) -> list[int]:
    pass

# %% [markdown]
# ## Q27. Pathlib Suffix Filter
#
# **Problem description:** Use `Path.suffix` logic to return only file names ending with `.txt` from a list of path strings.
#
# **Input format:** `paths: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# paths = ['a.txt', 'b.csv', 'notes.txt']
# ```
#
# **Sample Output:**
# ```python
# ['a.txt', 'notes.txt']
# ```
#
# **Constraints:** The list may be empty.

# %%
def pathlib_suffix_filter(paths: list[str]) -> list[str]:
    pass

# %% [markdown]
# ## Q28. Main Guard Simulation
#
# **Problem description:** Write a function that simulates `if __name__ == '__main__'` behavior by returning `'run'` only when the given module name equals `'__main__'`.
#
# **Input format:** `module_name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# module_name = '__main__'
# ```
#
# **Sample Output:**
# ```python
# 'run'
# ```
#
# **Constraints:** Return `'skip'` otherwise.

# %%
def main_guard_simulation(module_name: str) -> str:
    pass

# %% [markdown]
# ## Q29. Chain Counter Pipeline
#
# **Problem description:** Use `itertools.chain` and `Counter` together to combine multiple lists of tags and return the frequency dictionary.
#
# **Input format:** `groups: list[list[str]]`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# groups = [['python', 'sql'], ['python'], ['excel']]
# ```
#
# **Sample Output:**
# ```python
# {'python': 2, 'sql': 1, 'excel': 1}
# ```
#
# **Constraints:** Inner lists may be empty.

# %%
def chain_counter_pipeline(groups: list[list[str]]) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q30. Random Sample Unique
#
# **Problem description:** Use `random.sample` to return `k` unique items from a list.
#
# **Input format:** `items: list[int], k: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4], k = 2
# ```
#
# **Sample Output:**
# ```python
# Any 2 unique values from the list
# ```
#
# **Constraints:** Assume `0 <= k <= len(items)`.

# %%
def random_sample_unique(items: list[int], k: int) -> list[int]:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Config Json Reader
#
# **Problem description:** Write a JSON config dictionary to a local file and then read it back using `json.loads`. Return the restored dictionary.
#
# **Input format:** `config: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# config = {'mode': 'test'}
# ```
#
# **Sample Output:**
# ```python
# {'mode': 'test'}
# ```
#
# **Constraints:** The config dictionary is JSON serializable.

# %%
def config_json_reader(config: dict) -> dict:
    pass

# %% [markdown]
# ## Q32. Sales Report Mean And Date
#
# **Problem description:** Return a dictionary containing today's date string and the mean sales amount using `date.today()` and `statistics.mean`.
#
# **Input format:** `sales: list[int]`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# sales = [100, 150, 200]
# ```
#
# **Sample Output:**
# ```python
# {'date': '...', 'mean': 150}
# ```
#
# **Constraints:** The list will be non-empty.

# %%
def sales_report_mean_and_date(sales: list[int]) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q33. Log Parser Regex
#
# **Problem description:** Use `re.findall` to extract all error codes like `E101` or `E502` from log text.
#
# **Input format:** `text: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# text = 'ERROR E101 then ERROR E502'
# ```
#
# **Sample Output:**
# ```python
# ['E101', 'E502']
# ```
#
# **Constraints:** Error codes match `E` followed by digits.

# %%
def log_parser_regex(text: str) -> list[str]:
    pass

# %% [markdown]
# ## Q34. File Extension Summary
#
# **Problem description:** Use `pathlib.Path` and `Counter` to count file extensions from a list of file path strings and return the frequency dictionary.
#
# **Input format:** `paths: list[str]`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# paths = ['a.txt', 'b.csv', 'c.txt']
# ```
#
# **Sample Output:**
# ```python
# {'.txt': 2, '.csv': 1}
# ```
#
# **Constraints:** Ignore files with no suffix only if none are present.

# %%
def file_extension_summary(paths: list[str]) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q35. Queue Processing With Deque
#
# **Problem description:** Use `deque` to process tasks from left to right and return the order in which tasks were processed.
#
# **Input format:** `tasks: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# tasks = ['extract', 'clean', 'load']
# ```
#
# **Sample Output:**
# ```python
# ['extract', 'clean', 'load']
# ```
#
# **Constraints:** The list may be empty.

# %%
def queue_processing_with_deque(tasks: list[str]) -> list[str]:
    pass
