# %% [markdown]
# # Sets and Dictionaries Questions
#
# This notebook contains structured practice questions from basic to advanced level.
#
# No solutions are given in this notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Remove Duplicate Numbers
# **Problem Description:** Given a list of integers, print only the unique values using a set.
#
# **Input Format:** A list of integers
#
# **Output Format:** A set of unique integers
#
# **Sample Input:** `[1, 2, 2, 3, 4, 4]`
#
# **Sample Output:** `{1, 2, 3, 4}`
#
# **Constraints:** The list can be empty.

# %%
def unique_numbers(numbers):
    pass

# %% [markdown]
# ## Q2. Count Unique Words
# **Problem Description:** Given a list of words, count how many unique words are present.
#
# **Input Format:** A list of strings
#
# **Output Format:** One integer
#
# **Sample Input:** `['cat', 'dog', 'cat', 'bird']`
#
# **Sample Output:** `3`
#
# **Constraints:** Words are case-sensitive unless you normalize them yourself.

# %%
def count_unique_words(words):
    pass

# %% [markdown]
# ## Q3. Create a Student Dictionary
# **Problem Description:** Create a dictionary with keys `name`, `age`, and `course`, then print the value of `course`.
#
# **Input Format:** Three input values: name, age, and course
#
# **Output Format:** The course value
#
# **Sample Input:** `Riya, 20, Python`
#
# **Sample Output:** `Python`
#
# **Constraints:** Age is a positive integer.

# %%
def get_course(name, age, course):
    pass

# %% [markdown]
# ## Q4. Check Membership in a Set
# **Problem Description:** Check whether a given number exists in a set.
#
# **Input Format:** A set and one integer
#
# **Output Format:** `True` or `False`
#
# **Sample Input:** `set = {10, 20, 30}, number = 20`
#
# **Sample Output:** `True`
#
# **Constraints:** None

# %%
def exists_in_set(values, target):
    pass

# %% [markdown]
# ## Q5. Add an Item to a Set
# **Problem Description:** Add a new city to an existing set of cities.
#
# **Input Format:** A set of strings and one string
#
# **Output Format:** The updated set
#
# **Sample Input:** `{'Delhi', 'Pune'}, 'Mumbai'`
#
# **Sample Output:** `{'Delhi', 'Pune', 'Mumbai'}`
#
# **Constraints:** The city name is non-empty.

# %%
def add_city(cities, city):
    pass

# %% [markdown]
# ## Q6. Access a Dictionary Value Safely
# **Problem Description:** Given a dictionary and a key, return the value. If the key is missing, return `'Not Found'`.
#
# **Input Format:** A dictionary and one key
#
# **Output Format:** The value or `'Not Found'`
#
# **Sample Input:** `{'a': 1, 'b': 2}, 'c'`
#
# **Sample Output:** `Not Found`
#
# **Constraints:** None

# %%
def safe_get(data, key):
    pass

# %% [markdown]
# ## Q7. Print All Dictionary Keys
# **Problem Description:** Print all keys from a given dictionary as a list.
#
# **Input Format:** A dictionary
#
# **Output Format:** A list of keys
#
# **Sample Input:** `{'name': 'Aman', 'age': 22}`
#
# **Sample Output:** `['name', 'age']`
#
# **Constraints:** None

# %%
def get_keys(data):
    pass

# %% [markdown]
# ## Q8. Update a Dictionary Value
# **Problem Description:** Update the salary of an employee in a dictionary.
#
# **Input Format:** A dictionary and a new salary value
#
# **Output Format:** The updated dictionary
#
# **Sample Input:** `{'name': 'Raj', 'salary': 30000}, 35000`
#
# **Sample Output:** `{'name': 'Raj', 'salary': 35000}`
#
# **Constraints:** Salary is a non-negative integer.

# %%
def update_salary(employee, new_salary):
    pass

# %% [markdown]
# ## Q9. Convert a String to a Set of Characters
# **Problem Description:** Convert a given string into a set of unique characters.
#
# **Input Format:** A string
#
# **Output Format:** A set of characters
#
# **Sample Input:** `'banana'`
#
# **Sample Output:** `{'b', 'a', 'n'}`
#
# **Constraints:** The string may be empty.

# %%
def unique_characters(text):
    pass

# %% [markdown]
# ## Q10. Count Dictionary Items
# **Problem Description:** Count how many key-value pairs are present in a dictionary.
#
# **Input Format:** A dictionary
#
# **Output Format:** One integer
#
# **Sample Input:** `{'x': 10, 'y': 20, 'z': 30}`
#
# **Sample Output:** `3`
#
# **Constraints:** None

# %%
def count_items(data):
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Find Common Subjects
# **Problem Description:** Given two sets of subjects chosen by two students, print the common subjects.
#
# **Input Format:** Two sets of strings
#
# **Output Format:** A set of common subjects
#
# **Sample Input:** `{'Math', 'Science', 'English'}` and `{'Science', 'History', 'Math'}`
#
# **Sample Output:** `{'Math', 'Science'}`
#
# **Constraints:** None

# %%
def common_subjects(set_a, set_b):
    pass

# %% [markdown]
# ## Q12. Find Students Present in Either Class
# **Problem Description:** Given two sets of student names, print the union of both sets.
#
# **Input Format:** Two sets of strings
#
# **Output Format:** A set of all unique names
#
# **Sample Input:** `{'A', 'B'}` and `{'B', 'C'}`
#
# **Sample Output:** `{'A', 'B', 'C'}`
#
# **Constraints:** None

# %%
def all_students(class_a, class_b):
    pass

# %% [markdown]
# ## Q13. Word Frequency Counter
# **Problem Description:** Count the frequency of each word in a sentence using a dictionary.
#
# **Input Format:** A sentence as a string
#
# **Output Format:** A dictionary mapping words to counts
#
# **Sample Input:** `'red blue red green red'`
#
# **Sample Output:** `{'red': 3, 'blue': 1, 'green': 1}`
#
# **Constraints:** Split words using spaces.

# %%
def word_frequency(sentence):
    pass

# %% [markdown]
# ## Q14. Merge Two Dictionaries
# **Problem Description:** Merge two dictionaries into one. If a key appears in both, keep the value from the second dictionary.
#
# **Input Format:** Two dictionaries
#
# **Output Format:** One merged dictionary
#
# **Sample Input:** `{'a': 1, 'b': 2}` and `{'b': 5, 'c': 3}`
#
# **Sample Output:** `{'a': 1, 'b': 5, 'c': 3}`
#
# **Constraints:** Keys are hashable.

# %%
def merge_dicts(dict_a, dict_b):
    pass

# %% [markdown]
# ## Q15. Find Missing Items
# **Problem Description:** Given a required set and an available set, find which required items are missing.
#
# **Input Format:** Two sets of strings
#
# **Output Format:** A set of missing items
#
# **Sample Input:** `{'pen', 'book', 'bag'}` and `{'pen', 'bag'}`
#
# **Sample Output:** `{'book'}`
#
# **Constraints:** None

# %%
def missing_items(required, available):
    pass

# %% [markdown]
# ## Q16. Group Numbers by Even and Odd
# **Problem Description:** Given a list of integers, store even numbers and odd numbers in separate dictionary entries.
#
# **Input Format:** A list of integers
#
# **Output Format:** A dictionary like `{'even': [...], 'odd': [...]}`
#
# **Sample Input:** `[1, 2, 3, 4, 5]`
#
# **Sample Output:** `{'even': [2, 4], 'odd': [1, 3, 5]}`
#
# **Constraints:** None

# %%
def group_even_odd(numbers):
    pass

# %% [markdown]
# ## Q17. Build a Dictionary of Squares
# **Problem Description:** Create a dictionary where keys are numbers from 1 to `n` and values are their squares.
#
# **Input Format:** One integer `n`
#
# **Output Format:** A dictionary
#
# **Sample Input:** `4`
#
# **Sample Output:** `{1: 1, 2: 4, 3: 9, 4: 16}`
#
# **Constraints:** `n >= 1`

# %%
def square_dictionary(n):
    pass

# %% [markdown]
# ## Q18. Check Subset Relationship
# **Problem Description:** Check whether set A is a subset of set B.
#
# **Input Format:** Two sets
#
# **Output Format:** `True` or `False`
#
# **Sample Input:** `{1, 2}` and `{1, 2, 3, 4}`
#
# **Sample Output:** `True`
#
# **Constraints:** None

# %%
def is_subset(set_a, set_b):
    pass

# %% [markdown]
# ## Q19. Invert a Dictionary
# **Problem Description:** Swap keys and values in a dictionary where all values are unique.
#
# **Input Format:** One dictionary
#
# **Output Format:** An inverted dictionary
#
# **Sample Input:** `{'a': 1, 'b': 2}`
#
# **Sample Output:** `{1: 'a', 2: 'b'}`
#
# **Constraints:** Dictionary values must be unique and hashable.

# %%
def invert_dictionary(data):
    pass

# %% [markdown]
# ## Q20. Count Character Frequency
# **Problem Description:** Count the frequency of each character in a string while ignoring spaces.
#
# **Input Format:** A string
#
# **Output Format:** A dictionary of character counts
#
# **Sample Input:** `'data science'`
#
# **Sample Output:** `{'d': 1, 'a': 2, 't': 1, 's': 1, 'c': 2, 'i': 1, 'e': 2, 'n': 1}`
#
# **Constraints:** Ignore spaces only.

# %%
def character_frequency(text):
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Find the First Repeating Element
# **Problem Description:** Given a list of integers, find the first element that repeats while traversing from left to right.
#
# **Input Format:** A list of integers
#
# **Output Format:** The first repeating element or `None`
#
# **Sample Input:** `[5, 3, 4, 3, 5, 6]`
#
# **Sample Output:** `3`
#
# **Constraints:** Return the first repeated element based on traversal order.

# %%
def first_repeating(numbers):
    pass

# %% [markdown]
# ## Q22. Find Duplicate Elements
# **Problem Description:** Given a list, return a set of all elements that appear more than once.
#
# **Input Format:** A list of integers
#
# **Output Format:** A set of duplicate elements
#
# **Sample Input:** `[1, 2, 3, 2, 4, 1, 5]`
#
# **Sample Output:** `{1, 2}`
#
# **Constraints:** None

# %%
def find_duplicates(numbers):
    pass

# %% [markdown]
# ## Q23. Determine Whether Dictionary Values Are Unique
# **Problem Description:** Check whether all values in a dictionary are unique.
#
# **Input Format:** One dictionary
#
# **Output Format:** `True` or `False`
#
# **Sample Input:** `{'a': 1, 'b': 2, 'c': 1}`
#
# **Sample Output:** `False`
#
# **Constraints:** Values must support equality comparison.

# %%
def has_unique_values(data):
    pass

# %% [markdown]
# ## Q24. Create a Nested Marks Report
# **Problem Description:** Given a nested dictionary of students and subject marks, compute the total marks for each student.
#
# **Input Format:** A dictionary where each value is another dictionary of subject-mark pairs
#
# **Output Format:** A dictionary of student totals
#
# **Sample Input:** `{'A': {'math': 80, 'science': 90}, 'B': {'math': 70, 'science': 60}}`
#
# **Sample Output:** `{'A': 170, 'B': 130}`
#
# **Constraints:** Marks are non-negative integers.

# %%
def total_marks(report):
    pass

# %% [markdown]
# ## Q25. Check Disjoint Sets
# **Problem Description:** Check whether two sets have no common elements.
#
# **Input Format:** Two sets
#
# **Output Format:** `True` or `False`
#
# **Sample Input:** `{1, 2}` and `{3, 4}`
#
# **Sample Output:** `True`
#
# **Constraints:** None

# %%
def are_disjoint(set_a, set_b):
    pass

# %% [markdown]
# ## Q26. Build a Reverse Index
# **Problem Description:** Given a dictionary mapping students to courses, build a dictionary mapping each course to a set of students enrolled in it.
#
# **Input Format:** A dictionary where keys are student names and values are course names
#
# **Output Format:** A dictionary where values are sets of student names
#
# **Sample Input:** `{'Amit': 'Python', 'Neha': 'SQL', 'Riya': 'Python'}`
#
# **Sample Output:** `{'Python': {'Amit', 'Riya'}, 'SQL': {'Neha'}}`
#
# **Constraints:** Student names are unique keys.

# %%
def reverse_index(student_courses):
    pass

# %% [markdown]
# ## Q27. Symmetric Difference of Two Lists
# **Problem Description:** Given two lists, find elements that are present in exactly one of the lists.
#
# **Input Format:** Two lists of integers
#
# **Output Format:** A set
#
# **Sample Input:** `[1, 2, 3, 4]` and `[3, 4, 5, 6]`
#
# **Sample Output:** `{1, 2, 5, 6}`
#
# **Constraints:** None

# %%
def symmetric_difference_lists(list_a, list_b):
    pass

# %% [markdown]
# ## Q28. Most Frequent Word
# **Problem Description:** Find the most frequent word in a sentence. If there is a tie, returning any one highest-frequency word is acceptable.
#
# **Input Format:** A sentence as a string
#
# **Output Format:** One string
#
# **Sample Input:** `'a b a c b a'`
#
# **Sample Output:** `a`
#
# **Constraints:** The sentence contains at least one word.

# %%
def most_frequent_word(sentence):
    pass

# %% [markdown]
# ## Q29. Dictionary Difference by Keys
# **Problem Description:** Given two dictionaries, return the keys that appear in the first dictionary but not in the second.
#
# **Input Format:** Two dictionaries
#
# **Output Format:** A set of keys
#
# **Sample Input:** `{'a': 1, 'b': 2, 'c': 3}` and `{'b': 20, 'd': 4}`
#
# **Sample Output:** `{'a', 'c'}`
#
# **Constraints:** Keys are hashable.

# %%
def dictionary_key_difference(dict_a, dict_b):
    pass

# %% [markdown]
# ## Q30. Build a Dictionary from Two Lists
# **Problem Description:** Given one list of keys and one list of values, create a dictionary.
#
# **Input Format:** Two lists of equal length
#
# **Output Format:** One dictionary
#
# **Sample Input:** `['name', 'age']` and `['Asha', 22]`
#
# **Sample Output:** `{'name': 'Asha', 'age': 22}`
#
# **Constraints:** Both lists must have equal length.

# %%
def build_dictionary(keys, values):
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Unique Website Visitors
# **Problem Description:** A website log contains visitor IDs with repeats. Find the number of unique visitors.
#
# **Input Format:** A list of visitor IDs
#
# **Output Format:** One integer
#
# **Sample Input:** `['u1', 'u2', 'u1', 'u3', 'u2']`
#
# **Sample Output:** `3`
#
# **Constraints:** Visitor IDs are strings.

# %%
def unique_visitor_count(visitor_ids):
    pass

# %% [markdown]
# ## Q32. Inventory Stock Summary
# **Problem Description:** Given a list of sold products, count how many times each product was sold.
#
# **Input Format:** A list of product names
#
# **Output Format:** A dictionary of product counts
#
# **Sample Input:** `['pen', 'book', 'pen', 'bag', 'pen']`
#
# **Sample Output:** `{'pen': 3, 'book': 1, 'bag': 1}`
#
# **Constraints:** Product names are strings.

# %%
def sales_summary(products):
    pass

# %% [markdown]
# ## Q33. Course Enrollment System
# **Problem Description:** Given a dictionary mapping students to sets of courses, find students enrolled in a specific course.
#
# **Input Format:** A dictionary and one course name
#
# **Output Format:** A set of student names
#
# **Sample Input:** `{'A': {'Python', 'SQL'}, 'B': {'Excel'}, 'C': {'Python'}}`, `'Python'`
#
# **Sample Output:** `{'A', 'C'}`
#
# **Constraints:** Course names are strings.

# %%
def students_in_course(enrollment, target_course):
    pass

# %% [markdown]
# ## Q34. Common Skills in Job Profiles
# **Problem Description:** Given two sets of professional skills, find the common skills between them.
#
# **Input Format:** Two sets of skill names
#
# **Output Format:** A set of common skills
#
# **Sample Input:** `{'python', 'sql', 'excel'}` and `{'sql', 'powerbi', 'python'}`
#
# **Sample Output:** `{'python', 'sql'}`
#
# **Constraints:** Skill names are strings.

# %%
def common_skills(skills_a, skills_b):
    pass

# %% [markdown]
# ## Q35. Login Tracking Dashboard
# **Problem Description:** Given a list of login events, create both a set of unique users and a dictionary of login counts.
#
# **Input Format:** A list of usernames
#
# **Output Format:** A tuple containing `(set_of_users, login_count_dictionary)`
#
# **Sample Input:** `['raj', 'neha', 'raj', 'aman', 'raj']`
#
# **Sample Output:** `({'raj', 'neha', 'aman'}, {'raj': 3, 'neha': 1, 'aman': 1})`
#
# **Constraints:** Usernames are strings.

# %%
def login_dashboard(logins):
    pass
