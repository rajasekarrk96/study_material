# %% [markdown]
# # Python Lists and Tuples Questions
#
# Solve these before opening the answer notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Create Number List
#
# **Problem description:** Return list from 1 to n.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n=5
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# **Constraints:** n >= 0.

# %%
def create_number_list(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q2. Get First Item
#
# **Problem description:** Return first item or None.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int | None`
#
# **Sample Input:**
# ```python
# items=[4,5]
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** List may be empty.

# %%
def get_first_item(items: list[int]) -> int | None:
    pass

# %% [markdown]
# ## Q3. Get Last Item
#
# **Problem description:** Return last item or None.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int | None`
#
# **Sample Input:**
# ```python
# items=[4,5]
# ```
#
# **Sample Output:**
# ```python
# 5
# ```
#
# **Constraints:** List may be empty.

# %%
def get_last_item(items: list[int]) -> int | None:
    pass

# %% [markdown]
# ## Q4. Append Item
#
# **Problem description:** Return a new list after appending value.
#
# **Input format:** `items: list[int], value: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1], value=2
# ```
#
# **Sample Output:**
# ```python
# [1, 2]
# ```
#
# **Constraints:** Do not mutate input.

# %%
def append_item(items: list[int], value: int) -> list[int]:
    pass

# %% [markdown]
# ## Q5. Tuple Sum
#
# **Problem description:** Return sum of a pair tuple.
#
# **Input format:** `pair: tuple[int, int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# pair=(3,7)
# ```
#
# **Sample Output:**
# ```python
# 10
# ```
#
# **Constraints:** Pair has two ints.

# %%
def tuple_sum(pair: tuple[int, int]) -> int:
    pass

# %% [markdown]
# ## Q6. Reverse Items
#
# **Problem description:** Return reversed copy.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1,2,3]
# ```
#
# **Sample Output:**
# ```python
# [3, 2, 1]
# ```
#
# **Constraints:** List may be empty.

# %%
def reverse_items(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q7. List Length
#
# **Problem description:** Return list length without using len.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items=[1,2,3]
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** List may be empty.

# %%
def list_length(items: list[int]) -> int:
    pass

# %% [markdown]
# ## Q8. Count Value
#
# **Problem description:** Count occurrences of value.
#
# **Input format:** `items: list[int], value: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# items=[1,2,1], value=1
# ```
#
# **Sample Output:**
# ```python
# 2
# ```
#
# **Constraints:** List may be empty.

# %%
def count_value(items: list[int], value: int) -> int:
    pass

# %% [markdown]
# ## Q9. Check Sorted
#
# **Problem description:** Return True if list is non-decreasing.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# items=[1,2,2]
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** List may be empty.

# %%
def check_sorted(items: list[int]) -> bool:
    pass

# %% [markdown]
# ## Q10. Swap Pair
#
# **Problem description:** Given tuple pair, return swapped tuple.
#
# **Input format:** `pair: tuple[int, int]`
#
# **Output format:** `tuple[int, int]`
#
# **Sample Input:**
# ```python
# pair=(1,2)
# ```
#
# **Sample Output:**
# ```python
# (2, 1)
# ```
#
# **Constraints:** Pair has two ints.

# %%
def swap_pair(pair: tuple[int, int]) -> tuple[int, int]:
    pass

# %% [markdown]
# # Section 2: Intermediate

# %% [markdown]
# ## Q11. Remove Duplicates
#
# **Problem description:** Remove duplicates while preserving order.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[2,1,2,3]
# ```
#
# **Sample Output:**
# ```python
# [2, 1, 3]
# ```
#
# **Constraints:** Values are hashable.

# %%
def remove_duplicates(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q12. Second Largest
#
# **Problem description:** Return second largest distinct value.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `int | None`
#
# **Sample Input:**
# ```python
# items=[4,1,7,7]
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** Return None if absent.

# %%
def second_largest(items: list[int]) -> int | None:
    pass

# %% [markdown]
# ## Q13. Rotate Left
#
# **Problem description:** Rotate list left by k positions.
#
# **Input format:** `items: list[int], k: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1,2,3,4], k=1
# ```
#
# **Sample Output:**
# ```python
# [2, 3, 4, 1]
# ```
#
# **Constraints:** List may be empty.

# %%
def rotate_left(items: list[int], k: int) -> list[int]:
    pass

# %% [markdown]
# ## Q14. Chunk List
#
# **Problem description:** Split list into chunks of size k.
#
# **Input format:** `items: list[int], k: int`
#
# **Output format:** `list[list[int]]`
#
# **Sample Input:**
# ```python
# items=[1,2,3,4,5], k=2
# ```
#
# **Sample Output:**
# ```python
# [[1, 2], [3, 4], [5]]
# ```
#
# **Constraints:** k > 0.

# %%
def chunk_list(items: list[int], k: int) -> list[list[int]]:
    pass

# %% [markdown]
# ## Q15. Flatten One Level
#
# **Problem description:** Flatten one-level nested list.
#
# **Input format:** `items: list[list[int]]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[[1,2],[3]]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3]
# ```
#
# **Constraints:** Nested lists contain ints.

# %%
def flatten_one_level(items: list[list[int]]) -> list[int]:
    pass

# %% [markdown]
# ## Q16. Pair Lists
#
# **Problem description:** Pair names and scores into tuples.
#
# **Input format:** `names: list[str], scores: list[int]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# names=['A'], scores=[90]
# ```
#
# **Sample Output:**
# ```python
# [('A', 90)]
# ```
#
# **Constraints:** Use shortest length.

# %%
def pair_lists(names: list[str], scores: list[int]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ## Q17. Filter Passing
#
# **Problem description:** Return scores >= 40.
#
# **Input format:** `scores: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# scores=[20,40,80]
# ```
#
# **Sample Output:**
# ```python
# [40, 80]
# ```
#
# **Constraints:** Scores are ints.

# %%
def filter_passing(scores: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q18. Matrix Row Sum
#
# **Problem description:** Return sum of each row.
#
# **Input format:** `matrix: list[list[int]]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# matrix=[[1,2],[3]]
# ```
#
# **Sample Output:**
# ```python
# [3, 3]
# ```
#
# **Constraints:** Rows may be empty.

# %%
def matrix_row_sum(matrix: list[list[int]]) -> list[int]:
    pass

# %% [markdown]
# ## Q19. Tuple Records To Names
#
# **Problem description:** Return names from tuple records.
#
# **Input format:** `records: list[tuple[str, int]]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# records=[('A',90)]
# ```
#
# **Sample Output:**
# ```python
# ['A']
# ```
#
# **Constraints:** Records are name-score.

# %%
def tuple_records_to_names(records: list[tuple[str, int]]) -> list[str]:
    pass

# %% [markdown]
# ## Q20. Sort By Tuple Score
#
# **Problem description:** Sort tuple records by score descending.
#
# **Input format:** `records: list[tuple[str, int]]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# records=[('A',80),('B',90)]
# ```
#
# **Sample Output:**
# ```python
# [('B', 90), ('A', 80)]
# ```
#
# **Constraints:** Records are valid.

# %%
def sort_by_tuple_score(records: list[tuple[str, int]]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# # Section 3: Advanced

# %% [markdown]
# ## Q21. Two Sum Indices
#
# **Problem description:** Return indices of two numbers adding to target.
#
# **Input format:** `nums: list[int], target: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[2,7,11], target=9
# ```
#
# **Sample Output:**
# ```python
# [0, 1]
# ```
#
# **Constraints:** Return [] if absent.

# %%
def two_sum_indices(nums: list[int], target: int) -> list[int]:
    pass

# %% [markdown]
# ## Q22. Maximum Subarray
#
# **Problem description:** Return maximum contiguous subarray sum.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# nums=[-2,1,-3,4,-1,2,1]
# ```
#
# **Sample Output:**
# ```python
# 6
# ```
#
# **Constraints:** List not empty.

# %%
def maximum_subarray(nums: list[int]) -> int:
    pass

# %% [markdown]
# ## Q23. Product Except Self
#
# **Problem description:** Return product except self without division.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[1,2,3,4]
# ```
#
# **Sample Output:**
# ```python
# [24, 12, 8, 6]
# ```
#
# **Constraints:** List not empty.

# %%
def product_except_self(nums: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q24. Merge Sorted Lists
#
# **Problem description:** Merge two sorted lists.
#
# **Input format:** `a: list[int], b: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# a=[1,3], b=[2,4]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4]
# ```
#
# **Constraints:** Inputs sorted.

# %%
def merge_sorted_lists(a: list[int], b: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q25. Find Missing Positive
#
# **Problem description:** Return smallest missing positive integer.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# nums=[3,4,-1,1]
# ```
#
# **Sample Output:**
# ```python
# 2
# ```
#
# **Constraints:** Interview style.

# %%
def find_missing_positive(nums: list[int]) -> int:
    pass

# %% [markdown]
# ## Q26. Deep Flatten
#
# **Problem description:** Flatten arbitrarily nested lists.
#
# **Input format:** `items: list`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items=[1,[2,[3]]]
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3]
# ```
#
# **Constraints:** Items are ints/lists.

# %%
def deep_flatten(items: list) -> list[int]:
    pass

# %% [markdown]
# ## Q27. Generate Pairs
#
# **Problem description:** Return all unique pairs from list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[tuple[int, int]]`
#
# **Sample Input:**
# ```python
# items=[1,2,3]
# ```
#
# **Sample Output:**
# ```python
# [(1, 2), (1, 3), (2, 3)]
# ```
#
# **Constraints:** Order by indexes.

# %%
def generate_pairs(items: list[int]) -> list[tuple[int, int]]:
    pass

# %% [markdown]
# ## Q28. Transpose Matrix
#
# **Problem description:** Transpose matrix rows to columns.
#
# **Input format:** `matrix: list[list[int]]`
#
# **Output format:** `list[list[int]]`
#
# **Sample Input:**
# ```python
# matrix=[[1,2],[3,4]]
# ```
#
# **Sample Output:**
# ```python
# [[1, 3], [2, 4]]
# ```
#
# **Constraints:** Rectangular matrix.

# %%
def transpose_matrix(matrix: list[list[int]]) -> list[list[int]]:
    pass

# %% [markdown]
# ## Q29. Sliding Window Sum
#
# **Problem description:** Return sums of each window of size k.
#
# **Input format:** `nums: list[int], k: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[1,2,3,4], k=2
# ```
#
# **Sample Output:**
# ```python
# [3, 5, 7]
# ```
#
# **Constraints:** 1 <= k <= len(nums).

# %%
def sliding_window_sum(nums: list[int], k: int) -> list[int]:
    pass

# %% [markdown]
# ## Q30. Next Greater Elements
#
# **Problem description:** Return next greater element for each item or -1.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# nums=[2,1,3]
# ```
#
# **Sample Output:**
# ```python
# [3, 3, -1]
# ```
#
# **Constraints:** Use stack pattern.

# %%
def next_greater_elements(nums: list[int]) -> list[int]:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Average Marks
#
# **Problem description:** Return average from marks list.
#
# **Input format:** `marks: list[int]`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# marks=[80,90]
# ```
#
# **Sample Output:**
# ```python
# 85.0
# ```
#
# **Constraints:** Return 0.0 for empty.

# %%
def average_marks(marks: list[int]) -> float:
    pass

# %% [markdown]
# ## Q32. Top N Products
#
# **Problem description:** Return top n product names by sales.
#
# **Input format:** `products: list[tuple[str, int]], n: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# products=[('A',5),('B',8)], n=1
# ```
#
# **Sample Output:**
# ```python
# ['B']
# ```
#
# **Constraints:** Higher sales first.

# %%
def top_n_products(products: list[tuple[str, int]], n: int) -> list[str]:
    pass

# %% [markdown]
# ## Q33. Remove Cancelled Tasks
#
# **Problem description:** Return tasks excluding cancelled status.
#
# **Input format:** `tasks: list[tuple[str, str]]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# tasks=[('t1','done'),('t2','cancelled')]
# ```
#
# **Sample Output:**
# ```python
# ['t1']
# ```
#
# **Constraints:** Tuple is name-status.

# %%
def remove_cancelled_tasks(tasks: list[tuple[str, str]]) -> list[str]:
    pass

# %% [markdown]
# ## Q34. Seat Booking
#
# **Problem description:** Mark selected seat as booked.
#
# **Input format:** `seats: list[str], seat: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# seats=['A1','A2'], seat='A2'
# ```
#
# **Sample Output:**
# ```python
# ['A1', 'BOOKED']
# ```
#
# **Constraints:** If missing, unchanged.

# %%
def seat_booking(seats: list[str], seat: str) -> list[str]:
    pass

# %% [markdown]
# ## Q35. Sales Trend
#
# **Problem description:** Return Increase, Decrease, or Same comparing first and last sales.
#
# **Input format:** `sales: list[int]`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# sales=[100,150]
# ```
#
# **Sample Output:**
# ```python
# Increase
# ```
#
# **Constraints:** Need at least two values.

# %%
def sales_trend(sales: list[int]) -> str:
    pass
