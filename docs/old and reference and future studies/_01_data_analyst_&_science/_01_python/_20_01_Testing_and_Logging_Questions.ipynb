# %% [markdown]
# # Interview Questions: Python Testing and Logging
#
# Solve each question in order without looking at solutions first.
#
# - Section 1 contains beginner-friendly warm-up problems.
# - Section 2 adds more data handling and validation logic.
# - Section 3 includes trickier interview-style problems.
# - Section 4 applies testing and logging ideas to real-world scenarios.

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ### Q1. Check Addition Result
#
# **Problem description:** Write a function that receives two integers, adds them, and returns `True` only if the result matches an expected value.
#
# **Input format:** Three integers: `a`, `b`, and `expected_total`.
#
# **Output format:** A boolean value: `True` if `a + b` equals `expected_total`, otherwise `False`.
#
# **Sample Input:** `a = 2, b = 3, expected_total = 5`
#
# **Sample Output:** `True`
#
# **Constraints:** Inputs are integers.

# %%
def check_addition_result(a: int, b: int, expected_total: int) -> bool:
    pass

# %% [markdown]
# ### Q2. Build Assertion Message
#
# **Problem description:** Return a readable assertion-style message showing expected and actual values.
#
# **Input format:** Two values: `expected` and `actual` as strings.
#
# **Output format:** A formatted string.
#
# **Sample Input:** `expected = 'PASS', actual = 'FAIL'`
#
# **Sample Output:** `'Expected PASS, but got FAIL'`
#
# **Constraints:** Treat both values as strings.

# %%
def build_assertion_message(expected: str, actual: str) -> str:
    pass

# %% [markdown]
# ### Q3. Is Empty List Safe
#
# **Problem description:** Return `True` if the given list is empty, otherwise return `False`.
#
# **Input format:** One list of integers named `items`.
#
# **Output format:** A boolean value.
#
# **Sample Input:** `items = []`
#
# **Sample Output:** `True`
#
# **Constraints:** The list may contain any number of integers.

# %%
def is_empty_list_safe(items: list[int]) -> bool:
    pass

# %% [markdown]
# ### Q4. Count Passed Tests
#
# **Problem description:** Given a list of booleans, count how many test results are `True`.
#
# **Input format:** A list of boolean values called `results`.
#
# **Output format:** An integer count.
#
# **Sample Input:** `results = [True, False, True, True]`
#
# **Sample Output:** `3`
#
# **Constraints:** The list may be empty.

# %%
def count_passed_tests(results: list[bool]) -> int:
    pass

# %% [markdown]
# ### Q5. Normalize Log Level
#
# **Problem description:** Convert a log level string to uppercase and remove outer spaces.
#
# **Input format:** One string named `level`.
#
# **Output format:** A cleaned uppercase string.
#
# **Sample Input:** `level = '  info '`
#
# **Sample Output:** `'INFO'`
#
# **Constraints:** The input is a string.

# %%
def normalize_log_level(level: str) -> str:
    pass

# %% [markdown]
# ### Q6. Has Warning Level
#
# **Problem description:** Return `True` if the log level is `WARNING` after normalization, else `False`.
#
# **Input format:** One string named `level`.
#
# **Output format:** A boolean value.
#
# **Sample Input:** `level = 'warning'`
#
# **Sample Output:** `True`
#
# **Constraints:** Ignore surrounding spaces and case.

# %%
def has_warning_level(level: str) -> bool:
    pass

# %% [markdown]
# ### Q7. Get First Failure
#
# **Problem description:** Return the first string equal to `FAIL` from a list of status values, or `None` if it does not exist.
#
# **Input format:** A list of strings named `statuses`.
#
# **Output format:** A string or `None`.
#
# **Sample Input:** `statuses = ['PASS', 'FAIL', 'PASS']`
#
# **Sample Output:** `'FAIL'`
#
# **Constraints:** Comparison is case-sensitive in this problem.

# %%
def get_first_failure(statuses: list[str]) -> str | None:
    pass

# %% [markdown]
# ### Q8. Create Log Prefix
#
# **Problem description:** Combine a log level and module name into the format `LEVEL:module`.
#
# **Input format:** Two strings: `level` and `module_name`.
#
# **Output format:** A formatted string.
#
# **Sample Input:** `level = 'INFO', module_name = 'auth'`
#
# **Sample Output:** `'INFO:auth'`
#
# **Constraints:** Use the given values directly.

# %%
def create_log_prefix(level: str, module_name: str) -> str:
    pass

# %% [markdown]
# ### Q9. Compare Usernames
#
# **Problem description:** Return `True` if two usernames are equal after lowercasing both strings.
#
# **Input format:** Two strings: `left` and `right`.
#
# **Output format:** A boolean value.
#
# **Sample Input:** `left = 'Asha', right = 'asha'`
#
# **Sample Output:** `True`
#
# **Constraints:** Case-insensitive comparison only.

# %%
def compare_usernames(left: str, right: str) -> bool:
    pass

# %% [markdown]
# ### Q10. Safe Division Check
#
# **Problem description:** Return `None` if the divisor is zero; otherwise return the division result.
#
# **Input format:** Two numbers: `a` and `b`.
#
# **Output format:** A float or `None`.
#
# **Sample Input:** `a = 10, b = 2`
#
# **Sample Output:** `5.0`
#
# **Constraints:** The divisor may be zero.

# %%
def safe_division_check(a: float, b: float) -> float | None:
    pass

# %% [markdown]
# ## Intermediate Questions

# %% [markdown]
# ### Q11. Count Log Levels
#
# **Problem description:** Given a list of log level strings, return a dictionary counting each normalized level.
#
# **Input format:** A list of strings called `levels`.
#
# **Output format:** A dictionary mapping level strings to counts.
#
# **Sample Input:** `levels = ['info', 'ERROR', ' info ']`
#
# **Sample Output:** `{'INFO': 2, 'ERROR': 1}`
#
# **Constraints:** Ignore surrounding spaces and case.

# %%
def count_log_levels(levels: list[str]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q12. Filter Error Logs
#
# **Problem description:** Return only the log dictionaries whose `level` field is `ERROR`.
#
# **Input format:** A list of dictionaries, each possibly containing a `level` key.
#
# **Output format:** A list of filtered dictionaries.
#
# **Sample Input:** `logs = [{'level': 'INFO'}, {'level': 'ERROR'}]`
#
# **Sample Output:** `[{'level': 'ERROR'}]`
#
# **Constraints:** Keep the original order.

# %%
def filter_error_logs(logs: list[dict]) -> list[dict]:
    pass

# %% [markdown]
# ### Q13. Validate Score Range
#
# **Problem description:** Return `True` only if every score in the list is between 0 and 100 inclusive.
#
# **Input format:** A list of integers named `scores`.
#
# **Output format:** A boolean value.
#
# **Sample Input:** `scores = [0, 45, 100]`
#
# **Sample Output:** `True`
#
# **Constraints:** The list may be empty.

# %%
def validate_score_range(scores: list[int]) -> bool:
    pass

# %% [markdown]
# ### Q14. Summarize Test Results
#
# **Problem description:** Return a dictionary with counts for `passed` and `failed` based on a list of booleans.
#
# **Input format:** A list of booleans called `results`.
#
# **Output format:** A dictionary like `{'passed': x, 'failed': y}`.
#
# **Sample Input:** `results = [True, False, True]`
#
# **Sample Output:** `{'passed': 2, 'failed': 1}`
#
# **Constraints:** The list may be empty.

# %%
def summarize_test_results(results: list[bool]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q15. Find Missing Required Keys
#
# **Problem description:** Given one record and a list of required keys, return the keys that are missing.
#
# **Input format:** A dictionary `record` and a list of strings `required_keys`.
#
# **Output format:** A list of missing keys.
#
# **Sample Input:** `record = {'id': 1}, required_keys = ['id', 'name']`
#
# **Sample Output:** `['name']`
#
# **Constraints:** Keep required key order in the result.

# %%
def find_missing_required_keys(record: dict, required_keys: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q16. Merge Test Reports
#
# **Problem description:** Merge two dictionaries of test counts by adding values for matching keys.
#
# **Input format:** Two dictionaries with string keys and integer counts.
#
# **Output format:** One merged dictionary.
#
# **Sample Input:** `report_a = {'passed': 2}, report_b = {'passed': 1, 'failed': 3}`
#
# **Sample Output:** `{'passed': 3, 'failed': 3}`
#
# **Constraints:** All values are non-negative integers.

# %%
def merge_test_reports(report_a: dict[str, int], report_b: dict[str, int]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q17. Detect Duplicate Test Names
#
# **Problem description:** Return a sorted list of test names that appear more than once.
#
# **Input format:** A list of strings called `names`.
#
# **Output format:** A sorted list of duplicate names.
#
# **Sample Input:** `names = ['test_a', 'test_b', 'test_a']`
#
# **Sample Output:** `['test_a']`
#
# **Constraints:** Comparison is case-sensitive.

# %%
def detect_duplicate_test_names(names: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q18. Build Logger Names
#
# **Problem description:** Given a base name and feature names, return logger names in the format `base.feature`.
#
# **Input format:** One string `base_name` and one list of strings `features`.
#
# **Output format:** A list of logger name strings.
#
# **Sample Input:** `base_name = 'app', features = ['auth', 'billing']`
#
# **Sample Output:** `['app.auth', 'app.billing']`
#
# **Constraints:** Keep the input order.

# %%
def build_logger_names(base_name: str, features: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q19. Extract Failed Case IDs
#
# **Problem description:** From a list of dictionaries, return the `id` values for records whose `status` is `FAIL`.
#
# **Input format:** A list of dictionaries containing `id` and `status` fields.
#
# **Output format:** A list of IDs.
#
# **Sample Input:** `cases = [{'id': 1, 'status': 'PASS'}, {'id': 2, 'status': 'FAIL'}]`
#
# **Sample Output:** `[2]`
#
# **Constraints:** Keep the original order.

# %%
def extract_failed_case_ids(cases: list[dict]) -> list[int]:
    pass

# %% [markdown]
# ### Q20. Simulate Assert Raises
#
# **Problem description:** Return `True` if a value is negative and would therefore fail a non-negative assertion, else `False`.
#
# **Input format:** One integer named `value`.
#
# **Output format:** A boolean value.
#
# **Sample Input:** `value = -2`
#
# **Sample Output:** `True`
#
# **Constraints:** The input is an integer.

# %%
def simulate_assert_raises(value: int) -> bool:
    pass

# %% [markdown]
# ## Advanced Questions

# %% [markdown]
# ### Q21. Group Logs By Level
#
# **Problem description:** Group log messages by normalized log level and return a dictionary where each value is a list of messages.
#
# **Input format:** A list of dictionaries with keys `level` and `message`.
#
# **Output format:** A dictionary mapping level strings to lists of messages.
#
# **Sample Input:** `logs = [{'level': 'info', 'message': 'start'}, {'level': 'ERROR', 'message': 'fail'}]`
#
# **Sample Output:** `{'INFO': ['start'], 'ERROR': ['fail']}`
#
# **Constraints:** Keep message order inside each group.

# %%
def group_logs_by_level(logs: list[dict]) -> dict[str, list[str]]:
    pass

# %% [markdown]
# ### Q22. Find Longest Failure Streak
#
# **Problem description:** Given a list of booleans where `False` means failure, return the longest consecutive failure streak.
#
# **Input format:** A list of booleans called `results`.
#
# **Output format:** An integer streak length.
#
# **Sample Input:** `results = [True, False, False, True, False]`
#
# **Sample Output:** `2`
#
# **Constraints:** The list may be empty.

# %%
def find_longest_failure_streak(results: list[bool]) -> int:
    pass

# %% [markdown]
# ### Q23. Retry Until Success
#
# **Problem description:** Given a list of boolean attempt results, return the 1-based attempt number where success first occurs, or `-1` if it never succeeds.
#
# **Input format:** A list of booleans called `attempts`.
#
# **Output format:** An integer attempt index or `-1`.
#
# **Sample Input:** `attempts = [False, False, True]`
#
# **Sample Output:** `3`
#
# **Constraints:** The list may be empty.

# %%
def retry_until_success(attempts: list[bool]) -> int:
    pass

# %% [markdown]
# ### Q24. Compare Expected And Actual Rows
#
# **Problem description:** Return the row indices where the expected and actual lists differ.
#
# **Input format:** Two lists of strings: `expected_rows` and `actual_rows`.
#
# **Output format:** A list of zero-based integer indices.
#
# **Sample Input:** `expected_rows = ['a', 'b'], actual_rows = ['a', 'x']`
#
# **Sample Output:** `[1]`
#
# **Constraints:** Assume both lists have the same length.

# %%
def compare_expected_and_actual_rows(expected_rows: list[str], actual_rows: list[str]) -> list[int]:
    pass

# %% [markdown]
# ### Q25. Rank Modules By Error Count
#
# **Problem description:** Return module names sorted by descending error count, then alphabetically for ties.
#
# **Input format:** A dictionary mapping module names to integer error counts.
#
# **Output format:** A list of module names.
#
# **Sample Input:** `errors = {'auth': 3, 'billing': 5, 'api': 5}`
#
# **Sample Output:** `['api', 'billing', 'auth']`
#
# **Constraints:** Counts are non-negative integers.

# %%
def rank_modules_by_error_count(errors: dict[str, int]) -> list[str]:
    pass

# %% [markdown]
# ### Q26. Collapse Duplicate Consecutive Logs
#
# **Problem description:** Return a new list where repeated consecutive identical log messages appear only once.
#
# **Input format:** A list of strings named `messages`.
#
# **Output format:** A list of strings.
#
# **Sample Input:** `messages = ['A', 'A', 'B', 'B', 'C']`
#
# **Sample Output:** `['A', 'B', 'C']`
#
# **Constraints:** Keep the original order of first appearances in each run.

# %%
def collapse_duplicate_consecutive_logs(messages: list[str]) -> list[str]:
    pass

# %% [markdown]
# ### Q27. Validate Monotonic Timestamps
#
# **Problem description:** Return `True` if the integer timestamps never decrease from left to right.
#
# **Input format:** A list of integers named `timestamps`.
#
# **Output format:** A boolean value.
#
# **Sample Input:** `timestamps = [10, 10, 12, 15]`
#
# **Sample Output:** `True`
#
# **Constraints:** The list may be empty.

# %%
def validate_monotonic_timestamps(timestamps: list[int]) -> bool:
    pass

# %% [markdown]
# ### Q28. Mock Call Summary
#
# **Problem description:** Given a list of argument tuples representing mock calls, return a list of strings in the format `arg1|arg2|...` for each call.
#
# **Input format:** A list of tuples named `calls`.
#
# **Output format:** A list of strings.
#
# **Sample Input:** `calls = [('user1', 'ok'), ('user2', 'fail')]`
#
# **Sample Output:** `['user1|ok', 'user2|fail']`
#
# **Constraints:** Tuple values can be converted to strings.

# %%
def mock_call_summary(calls: list[tuple]) -> list[str]:
    pass

# %% [markdown]
# ### Q29. Collect Exception Types
#
# **Problem description:** Given a list of exception name strings, return a dictionary counting each type.
#
# **Input format:** A list of strings named `exception_names`.
#
# **Output format:** A dictionary mapping names to counts.
#
# **Sample Input:** `exception_names = ['ValueError', 'TypeError', 'ValueError']`
#
# **Sample Output:** `{'ValueError': 2, 'TypeError': 1}`
#
# **Constraints:** Comparison is case-sensitive.

# %%
def collect_exception_types(exception_names: list[str]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q30. Build Failure Matrix
#
# **Problem description:** Given a list of lists of booleans, convert it into a matrix of `1` for failure and `0` for pass where `False` means failure.
#
# **Input format:** A list of boolean lists called `batches`.
#
# **Output format:** A list of integer lists.
#
# **Sample Input:** `batches = [[True, False], [False, False]]`
#
# **Sample Output:** `[[0, 1], [1, 1]]`
#
# **Constraints:** Keep the original shape.

# %%
def build_failure_matrix(batches: list[list[bool]]) -> list[list[int]]:
    pass

# %% [markdown]
# ## Real-world Problems

# %% [markdown]
# ### Q31. API Health Summary
#
# **Problem description:** Given API response status codes, return a dictionary counting `success`, `client_error`, and `server_error` responses.
#
# **Input format:** A list of integers named `status_codes`.
#
# **Output format:** A dictionary with keys `success`, `client_error`, and `server_error`.
#
# **Sample Input:** `status_codes = [200, 201, 404, 500]`
#
# **Sample Output:** `{'success': 2, 'client_error': 1, 'server_error': 1}`
#
# **Constraints:** Assume codes are valid HTTP status integers.

# %%
def api_health_summary(status_codes: list[int]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q32. Login Audit Report
#
# **Problem description:** Given login event dictionaries, count successful and failed logins.
#
# **Input format:** A list of dictionaries with a boolean key `success`.
#
# **Output format:** A dictionary like `{'success': x, 'failed': y}`.
#
# **Sample Input:** `events = [{'success': True}, {'success': False}]`
#
# **Sample Output:** `{'success': 1, 'failed': 1}`
#
# **Constraints:** Every event contains the `success` key.

# %%
def login_audit_report(events: list[dict]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q33. ETL Validation Errors
#
# **Problem description:** From a list of row dictionaries, return the IDs of rows missing either `id` or `name`.
#
# **Input format:** A list of dictionaries named `rows`.
#
# **Output format:** A list of row positions as integers.
#
# **Sample Input:** `rows = [{'id': 1, 'name': 'A'}, {'id': 2}]`
#
# **Sample Output:** `[1]`
#
# **Constraints:** Return zero-based row indices.

# %%
def etl_validation_errors(rows: list[dict]) -> list[int]:
    pass

# %% [markdown]
# ### Q34. Payment Retry Analysis
#
# **Problem description:** Given groups of boolean payment attempts for many transactions, return how many transactions eventually succeeded.
#
# **Input format:** A list of boolean lists named `transactions`.
#
# **Output format:** An integer count.
#
# **Sample Input:** `transactions = [[False, True], [False, False], [True]]`
#
# **Sample Output:** `2`
#
# **Constraints:** Each inner list represents attempts for one transaction.

# %%
def payment_retry_analysis(transactions: list[list[bool]]) -> int:
    pass

# %% [markdown]
# ### Q35. Production Error Dashboard
#
# **Problem description:** Given log dictionaries with `module` and `level`, return error counts per module for rows whose level is `ERROR`.
#
# **Input format:** A list of dictionaries with keys `module` and `level`.
#
# **Output format:** A dictionary mapping module names to error counts.
#
# **Sample Input:** `logs = [{'module': 'auth', 'level': 'ERROR'}, {'module': 'auth', 'level': 'INFO'}]`
#
# **Sample Output:** `{'auth': 1}`
#
# **Constraints:** Normalize log levels before comparison.

# %%
def production_error_dashboard(logs: list[dict]) -> dict[str, int]:
    pass
