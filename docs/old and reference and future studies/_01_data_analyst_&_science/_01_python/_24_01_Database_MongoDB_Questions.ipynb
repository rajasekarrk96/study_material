# %% [markdown]
# # Database MongoDB Connectivity Questions
#
# This notebook contains:
# - Section 1: Basic Questions
# - Section 2: Intermediate Questions
# - Section 3: Advanced Questions
# - Section 4: Real-world Problems
#
# Each question includes:
# - Problem description
# - Input format
# - Output format
# - Sample input
# - Sample output
# - Constraints
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ## Q1. Import MongoClient
#
# **Problem Description**
# Write Python code to import `MongoClient` from `pymongo` and print `MongoClient ready`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `MongoClient ready`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q2. Create a Local MongoDB URI
#
# **Problem Description**
# Store the local MongoDB URI in a variable and print it.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `mongodb://localhost:27017/`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q3. Create a MongoDB Client
#
# **Problem Description**
# Write code that creates a `MongoClient` for the local URI and prints `Client created`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Client created`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q4. Select a Database and Collection
#
# **Problem Description**
# Write code that selects `school_db` and `students` from a MongoDB client and prints both names.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `school_db`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q5. Build One Student Document
#
# **Problem Description**
# Create one student document with `name`, `course`, and `marks`, then print it.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'name': 'Aman', 'course': 'Python', 'marks': 88}`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q6. Prepare an `insert_one` Document
#
# **Problem Description**
# Create one document that could be passed to `insert_one()` and print it.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'name': 'Aman', 'email': 'aman@example.com'}`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q7. Prepare an `insert_many` List
#
# **Problem Description**
# Create a list of three MongoDB documents and print each one.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'name': 'Aman', 'course': 'Python'}`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q8. Prepare a `find_one` Filter
#
# **Problem Description**
# Build a filter dictionary that finds one student by email and print it.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'email': 'aman@example.com'}`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q9. Prepare a `find` Filter
#
# **Problem Description**
# Build a filter dictionary that finds all students in the `Python` course and print it.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'course': 'Python'}`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# ## Q10. Show the `_id` Field
#
# **Problem Description**
# Create and print a MongoDB document that includes a custom `_id` field.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'_id': 1, 'name': 'Aman'}`
#
# **Constraints**
# Use MongoDB and `pymongo` style where relevant. Use valid dictionary-based filters and updates.

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ## Q11. Use a `$gt` Filter
#
# **Problem Description**
# Create and print a filter dictionary that matches documents where `marks` is greater than 80.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'marks': {'$gt': 80}}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q12. Use an `$in` Filter
#
# **Problem Description**
# Create and print a filter dictionary that matches `course` in `['Python', 'MongoDB']`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'course': {'$in': ['Python', 'MongoDB']}}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q13. Build a Projection
#
# **Problem Description**
# Create and print a projection that includes `name` and `course` but excludes `_id`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'name': 1, 'course': 1, '_id': 0}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q14. Show Sorting and Limit Values
#
# **Problem Description**
# Store a descending sort on `marks` and a limit of `5`, then print both values.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `-1`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q15. Prepare a `$set` Update
#
# **Problem Description**
# Build and print a filter and `$set` update for changing a student's course.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$set': {'course': 'Advanced Python'}}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q16. Prepare a `$inc` Update
#
# **Problem Description**
# Build and print a filter and `$inc` update that adds `5` to marks.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$inc': {'marks': 5}}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q17. Prepare a `$push` Update
#
# **Problem Description**
# Build and print a `$push` operation that adds `MongoDB` to a `skills` array.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$push': {'skills': 'MongoDB'}}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q18. Prepare a `$addToSet` Update
#
# **Problem Description**
# Build and print a `$addToSet` operation that adds `MongoDB` only if it is not already present.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$addToSet': {'skills': 'MongoDB'}}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q19. Prepare a Delete Filter
#
# **Problem Description**
# Create and print a filter that deletes one student by email.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'email': 'aman@example.com'}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# ## Q20. Prepare a Replacement Document
#
# **Problem Description**
# Create and print a filter plus a full replacement document for `_id = 1`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'_id': 1}`
#
# **Constraints**
# Use clear MongoDB operators, projections, or cursor patterns. Keep examples safe and readable.

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ## Q21. Build a `$match` Stage
#
# **Problem Description**
# Create and print an aggregation `$match` stage for `marks >= 80`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$match': {'marks': {'$gte': 80}}}`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q22. Build a `$group` Stage
#
# **Problem Description**
# Create and print a `$group` stage that calculates average marks by course.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$group': {'_id': '$course', 'average_marks': {'$avg': '$marks'}}}`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q23. Build a `$sort` Stage
#
# **Problem Description**
# Create and print an aggregation `$sort` stage that sorts by `average_marks` descending.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$sort': {'average_marks': -1}}`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q24. Build a Small Aggregation Pipeline
#
# **Problem Description**
# Create and print a three-stage pipeline using `$match`, `$group`, and `$sort`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `[{'$match':`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q25. Handle a Missing Field Safely
#
# **Problem Description**
# Write code that reads `email` from a document using `.get()` and prints the value.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `None`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q26. Create an Environment Variable Config Pattern
#
# **Problem Description**
# Write a short example that reads a MongoDB URI from an environment variable and prints it.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `mongodb://localhost:27017/`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q27. Build an Atlas URI Example
#
# **Problem Description**
# Store and print an example MongoDB Atlas URI string.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `mongodb+srv://`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q28. Create an Index Specification
#
# **Problem Description**
# Create and print an index specification for the `email` field in ascending order.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `[('email', 1)]`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q29. Write a Collection Helper Function
#
# **Problem Description**
# Write a helper function that returns a collection object from a client, database name, and collection name, then print the collection name.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `students`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# ## Q30. Show a Try-Except-Finally Client Pattern
#
# **Problem Description**
# Write a short MongoDB connection pattern that creates a client, prints success, handles errors, and closes the client.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `Client closed`
#
# **Constraints**
# Handle document flexibility, aggregation, and update semantics carefully.

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ## Q31. Student Profile Workflow
#
# **Problem Description**
# Create MongoDB-style student documents, print the filter for Python learners, and print an update that adds 5 marks to Aman.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'course': 'Python'}`
#
# **Constraints**
# Write the problem like a small application task using MongoDB collections and documents.

# %% [markdown]
# ## Q32. Inventory Low Stock Filter
#
# **Problem Description**
# Create and print a filter that returns inventory documents where `qty` is less than `10`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'qty': {'$lt': 10}}`
#
# **Constraints**
# Write the problem like a small application task using MongoDB collections and documents.

# %% [markdown]
# ## Q33. Employee Salary Aggregation
#
# **Problem Description**
# Create and print a group stage that totals salary by department.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$group': {'_id': '$department', 'total_salary': {'$sum': '$salary'}}}`
#
# **Constraints**
# Write the problem like a small application task using MongoDB collections and documents.

# %% [markdown]
# ## Q34. Blog Tag Update
#
# **Problem Description**
# Create and print an update operation that adds a new tag to a blog post's `tags` array without duplicates.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'$addToSet': {'tags': 'python'}}`
#
# **Constraints**
# Write the problem like a small application task using MongoDB collections and documents.

# %% [markdown]
# ## Q35. Safe Login Lookup Helper
#
# **Problem Description**
# Write a helper function that returns a MongoDB login filter for a user email, then print the filter for `user@example.com`.
#
# **Input Format**
# `No external input.` Use fixed values inside the script unless stated otherwise.
#
# **Output Format**
# Print the requested MongoDB code pattern, dictionary, list, helper result, or status line.
#
# **Sample Input**
# `None`
#
# **Sample Output**
# `{'email': 'user@example.com'}`
#
# **Constraints**
# Write the problem like a small application task using MongoDB collections and documents.
