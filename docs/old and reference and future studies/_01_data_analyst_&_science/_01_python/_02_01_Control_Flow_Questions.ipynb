# %% [markdown]
# # Python Control Flow Questions
#
# This notebook contains only problems. Try solving before opening the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. Positive or Negative
#
# **Problem description:** Check whether an integer is positive, negative, or zero.
#
# **Input format:** `n: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# Positive
# ```
#
# **Constraints:** n can be any integer.

# %%
def positive_or_negative(n: int) -> str:
    pass

# %% [markdown]
# ## Q2. Even or Odd
#
# **Problem description:** Check whether a number is even or odd.
#
# **Input format:** `n: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# n = 8
# ```
#
# **Sample Output:**
# ```python
# Even
# ```
#
# **Constraints:** n can be any integer.

# %%
def even_or_odd(n: int) -> str:
    pass

# %% [markdown]
# ## Q3. Pass or Fail
#
# **Problem description:** Return Pass if marks are at least 40, otherwise Fail.
#
# **Input format:** `marks: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# marks = 55
# ```
#
# **Sample Output:**
# ```python
# Pass
# ```
#
# **Constraints:** 0 <= marks <= 100.

# %%
def pass_or_fail(marks: int) -> str:
    pass

# %% [markdown]
# ## Q4. Maximum of Two
#
# **Problem description:** Return the larger of two numbers.
#
# **Input format:** `a: int, b: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# a = 4, b = 9
# ```
#
# **Sample Output:**
# ```python
# 9
# ```
#
# **Constraints:** a and b are integers.

# %%
def maximum_of_two(a: int, b: int) -> int:
    pass

# %% [markdown]
# ## Q5. Maximum of Three
#
# **Problem description:** Return the largest of three numbers.
#
# **Input format:** `a: int, b: int, c: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# a = 4, b = 9, c = 2
# ```
#
# **Sample Output:**
# ```python
# 9
# ```
#
# **Constraints:** a, b, c are integers.

# %%
def maximum_of_three(a: int, b: int, c: int) -> int:
    pass

# %% [markdown]
# ## Q6. Vowel or Consonant
#
# **Problem description:** Check whether a single alphabet character is a vowel or consonant.
#
# **Input format:** `ch: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# ch = 'a'
# ```
#
# **Sample Output:**
# ```python
# Vowel
# ```
#
# **Constraints:** ch length is 1.

# %%
def vowel_or_consonant(ch: str) -> str:
    pass

# %% [markdown]
# ## Q7. Print 1 to N
#
# **Problem description:** Return a list of numbers from 1 to n.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 3, 4, 5]
# ```
#
# **Constraints:** n >= 0.

# %%
def print_1_to_n(n: int) -> list[int]:
    pass

# %% [markdown]
# ## Q8. Sum 1 to N
#
# **Problem description:** Return the sum of numbers from 1 to n.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# 15
# ```
#
# **Constraints:** n >= 0.

# %%
def sum_1_to_n(n: int) -> int:
    pass

# %% [markdown]
# ## Q9. Count Digits
#
# **Problem description:** Return the number of digits in a non-negative integer.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 1205
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** n >= 0.

# %%
def count_digits(n: int) -> int:
    pass

# %% [markdown]
# ## Q10. Multiplication Table
#
# **Problem description:** Return the first 10 multiples of n.
#
# **Input format:** `n: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n = 3
# ```
#
# **Sample Output:**
# ```python
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30]
# ```
#
# **Constraints:** n is an integer.

# %%
def multiplication_table(n: int) -> list[int]:
    pass

# %% [markdown]
# # Section 2: Intermediate

# %% [markdown]
# ## Q11. Grade Calculator
#
# **Problem description:** Return A/B/C/D/Fail based on marks.
#
# **Input format:** `marks: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# marks = 82
# ```
#
# **Sample Output:**
# ```python
# B
# ```
#
# **Constraints:** 0 <= marks <= 100.

# %%
def grade_calculator(marks: int) -> str:
    pass

# %% [markdown]
# ## Q12. Leap Year
#
# **Problem description:** Check if a year is a leap year.
#
# **Input format:** `year: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# year = 2024
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** year > 0.

# %%
def leap_year(year: int) -> bool:
    pass

# %% [markdown]
# ## Q13. Login Validator
#
# **Problem description:** Validate username and password using multiple conditions.
#
# **Input format:** `username: str, password: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# username='admin', password='1234'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Non-empty strings.

# %%
def login_validator(username: str, password: str) -> bool:
    pass

# %% [markdown]
# ## Q14. Discount Calculator
#
# **Problem description:** Calculate final price using tiered discount rules.
#
# **Input format:** `amount: float`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# amount = 2000
# ```
#
# **Sample Output:**
# ```python
# 1800.0
# ```
#
# **Constraints:** amount >= 0.

# %%
def discount_calculator(amount: float) -> float:
    pass

# %% [markdown]
# ## Q15. Number Classification
#
# **Problem description:** Classify a number as zero, positive-even, positive-odd, negative-even, or negative-odd.
#
# **Input format:** `n: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# n = -4
# ```
#
# **Sample Output:**
# ```python
# Negative Even
# ```
#
# **Constraints:** n is integer.

# %%
def number_classification(n: int) -> str:
    pass

# %% [markdown]
# ## Q16. Find First Divisible
#
# **Problem description:** Return the first number divisible by k from a list.
#
# **Input format:** `nums: list[int], k: int`
#
# **Output format:** `int | None`
#
# **Sample Input:**
# ```python
# nums=[5, 9, 12], k=3
# ```
#
# **Sample Output:**
# ```python
# 9
# ```
#
# **Constraints:** k != 0.

# %%
def find_first_divisible(nums: list[int], k: int) -> int | None:
    pass

# %% [markdown]
# ## Q17. Skip Multiples
#
# **Problem description:** Return numbers from 1 to n except multiples of skip.
#
# **Input format:** `n: int, skip: int`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# n=7, skip=3
# ```
#
# **Sample Output:**
# ```python
# [1, 2, 4, 5, 7]
# ```
#
# **Constraints:** n >= 0, skip > 0.

# %%
def skip_multiples(n: int, skip: int) -> list[int]:
    pass

# %% [markdown]
# ## Q18. Password Strength
#
# **Problem description:** Classify a password as Weak, Medium, or Strong.
#
# **Input format:** `password: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# password='Abc12345'
# ```
#
# **Sample Output:**
# ```python
# Strong
# ```
#
# **Constraints:** Password is string.

# %%
def password_strength(password: str) -> str:
    pass

# %% [markdown]
# ## Q19. Menu Action
#
# **Problem description:** Return action text for menu option 1, 2, 3, otherwise Invalid.
#
# **Input format:** `choice: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# choice = 2
# ```
#
# **Sample Output:**
# ```python
# Withdraw
# ```
#
# **Constraints:** choice is integer.

# %%
def menu_action(choice: int) -> str:
    pass

# %% [markdown]
# ## Q20. Prime Check
#
# **Problem description:** Return True if n is prime.
#
# **Input format:** `n: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# n = 17
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** n >= 0.

# %%
def prime_check(n: int) -> bool:
    pass

# %% [markdown]
# # Section 3: Advanced

# %% [markdown]
# ## Q21. FizzBuzz List
#
# **Problem description:** Return FizzBuzz values from 1 to n.
#
# **Input format:** `n: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# n = 5
# ```
#
# **Sample Output:**
# ```python
# ['1', '2', 'Fizz', '4', 'Buzz']
# ```
#
# **Constraints:** n >= 0.

# %%
def fizzbuzz_list(n: int) -> list[str]:
    pass

# %% [markdown]
# ## Q22. Reverse Integer
#
# **Problem description:** Reverse digits of an integer while preserving sign.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = -123
# ```
#
# **Sample Output:**
# ```python
# -321
# ```
#
# **Constraints:** n is integer.

# %%
def reverse_integer(n: int) -> int:
    pass

# %% [markdown]
# ## Q23. Palindrome Number
#
# **Problem description:** Check whether an integer reads the same backward.
#
# **Input format:** `n: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# n = 121
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** n is integer.

# %%
def palindrome_number(n: int) -> bool:
    pass

# %% [markdown]
# ## Q24. Longest Streak
#
# **Problem description:** Return longest consecutive streak of target value.
#
# **Input format:** `values: list[int], target: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# values=[1,1,2,1,1,1], target=1
# ```
#
# **Sample Output:**
# ```python
# 3
# ```
#
# **Constraints:** List may be empty.

# %%
def longest_streak(values: list[int], target: int) -> int:
    pass

# %% [markdown]
# ## Q25. First Non-Repeating Character
#
# **Problem description:** Return first character that appears once.
#
# **Input format:** `text: str`
#
# **Output format:** `str | None`
#
# **Sample Input:**
# ```python
# text='swiss'
# ```
#
# **Sample Output:**
# ```python
# 'w'
# ```
#
# **Constraints:** Text may be empty.

# %%
def first_non_repeating_character(text: str) -> str | None:
    pass

# %% [markdown]
# ## Q26. Balanced Parentheses
#
# **Problem description:** Return True if parentheses are balanced.
#
# **Input format:** `text: str`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# text='(()())'
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Only parentheses.

# %%
def balanced_parentheses(text: str) -> bool:
    pass

# %% [markdown]
# ## Q27. Find Missing Number
#
# **Problem description:** Numbers contain 0..n except one missing number. Return missing.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# nums=[3,0,1]
# ```
#
# **Sample Output:**
# ```python
# 2
# ```
#
# **Constraints:** Unique values.

# %%
def find_missing_number(nums: list[int]) -> int:
    pass

# %% [markdown]
# ## Q28. Collatz Steps
#
# **Problem description:** Return steps needed to reach 1 using Collatz rules.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 6
# ```
#
# **Sample Output:**
# ```python
# 8
# ```
#
# **Constraints:** n > 0.

# %%
def collatz_steps(n: int) -> int:
    pass

# %% [markdown]
# ## Q29. Second Largest
#
# **Problem description:** Return second largest distinct value.
#
# **Input format:** `nums: list[int]`
#
# **Output format:** `int | None`
#
# **Sample Input:**
# ```python
# nums=[4,1,7,7,3]
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** List may have duplicates.

# %%
def second_largest(nums: list[int]) -> int | None:
    pass

# %% [markdown]
# ## Q30. Sieve Prime Count
#
# **Problem description:** Count primes less than n.
#
# **Input format:** `n: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# n = 10
# ```
#
# **Sample Output:**
# ```python
# 4
# ```
#
# **Constraints:** n >= 0.

# %%
def sieve_prime_count(n: int) -> int:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. ATM Withdrawal
#
# **Problem description:** Return updated balance or error message.
#
# **Input format:** `balance: int, amount: int`
#
# **Output format:** `int | str`
#
# **Sample Input:**
# ```python
# balance=1000, amount=300
# ```
#
# **Sample Output:**
# ```python
# 700
# ```
#
# **Constraints:** amount > 0.

# %%
def atm_withdrawal(balance: int, amount: int) -> int | str:
    pass

# %% [markdown]
# ## Q32. Traffic Signal
#
# **Problem description:** Return driving instruction based on signal color.
#
# **Input format:** `signal: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# signal='red'
# ```
#
# **Sample Output:**
# ```python
# Stop
# ```
#
# **Constraints:** Signal is string.

# %%
def traffic_signal(signal: str) -> str:
    pass

# %% [markdown]
# ## Q33. Cart Free Shipping
#
# **Problem description:** Return True if cart qualifies for free shipping.
#
# **Input format:** `amount: float, is_member: bool`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# amount=499, is_member=True
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** amount >= 0.

# %%
def cart_free_shipping(amount: float, is_member: bool) -> bool:
    pass

# %% [markdown]
# ## Q34. Retry Failed Task
#
# **Problem description:** Simulate retry attempts until success attempt.
#
# **Input format:** `success_at: int, max_retries: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# success_at=3, max_retries=5
# ```
#
# **Sample Output:**
# ```python
# Success on attempt 3
# ```
#
# **Constraints:** Positive integers.

# %%
def retry_failed_task(success_at: int, max_retries: int) -> str:
    pass

# %% [markdown]
# ## Q35. Ticket Pricing
#
# **Problem description:** Return ticket price based on age and student status.
#
# **Input format:** `age: int, is_student: bool`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# age=20, is_student=True
# ```
#
# **Sample Output:**
# ```python
# 120
# ```
#
# **Constraints:** age >= 0.

# %%
def ticket_pricing(age: int, is_student: bool) -> int:
    pass
