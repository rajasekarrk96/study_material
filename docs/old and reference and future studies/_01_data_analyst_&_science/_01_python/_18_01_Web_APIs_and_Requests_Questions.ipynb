# %% [markdown]
# # Python Web APIs and Requests Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. HTTP Method Meaning
#
# **Problem description:** Return the meaning of the HTTP method `GET` as a short string.
#
# **Input format:** `unused: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# 'fetch data'
# ```
#
# **Constraints:** Return a short readable phrase.

# %%
def http_method_meaning(unused: int) -> str:
    pass

# %% [markdown]
# ## Q2. Status Code Success Check
#
# **Problem description:** Return True if a status code is in the 200 range, otherwise False.
#
# **Input format:** `status_code: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# status_code = 200
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Use integer comparisons only.

# %%
def status_code_success_check(status_code: int) -> bool:
    pass

# %% [markdown]
# ## Q3. Query Parameter Dict
#
# **Problem description:** Create and return a query parameter dictionary with `page` and `search` keys.
#
# **Input format:** `page: int, search: str`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# page = 2, search = 'python'
# ```
#
# **Sample Output:**
# ```python
# {'page': 2, 'search': 'python'}
# ```
#
# **Constraints:** Return a plain dictionary.

# %%
def query_parameter_dict(page: int, search: str) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q4. Header Accept Json
#
# **Problem description:** Return a headers dictionary that requests JSON using the `Accept` header.
#
# **Input format:** `unused: int`
#
# **Output format:** `dict[str, str]`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# {'Accept': 'application/json'}
# ```
#
# **Constraints:** Return a plain dictionary.

# %%
def header_accept_json(unused: int) -> dict[str, str]:
    pass

# %% [markdown]
# ## Q5. Extract Status Message
#
# **Problem description:** Given a small response dictionary containing `status_code`, return `'Success'` for 200 and `'Failed'` otherwise.
#
# **Input format:** `response: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# response = {'status_code': 200}
# ```
#
# **Sample Output:**
# ```python
# 'Success'
# ```
#
# **Constraints:** The dictionary contains the `status_code` key.

# %%
def extract_status_message(response: dict) -> str:
    pass

# %% [markdown]
# ## Q6. Json Field Read
#
# **Problem description:** Given parsed API JSON with a `name` key, return the name value.
#
# **Input format:** `data: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# data = {'name': 'Asha'}
# ```
#
# **Sample Output:**
# ```python
# 'Asha'
# ```
#
# **Constraints:** The key exists.

# %%
def json_field_read(data: dict) -> str:
    pass

# %% [markdown]
# ## Q7. List User Names
#
# **Problem description:** Given a list of user dictionaries, return a list of their `name` values.
#
# **Input format:** `users: list[dict]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# users = [{'name': 'Asha'}, {'name': 'Ravi'}]
# ```
#
# **Sample Output:**
# ```python
# ['Asha', 'Ravi']
# ```
#
# **Constraints:** Every dictionary has a `name` key.

# %%
def list_user_names(users: list[dict]) -> list[str]:
    pass

# %% [markdown]
# ## Q8. Missing Field Safe Read
#
# **Problem description:** Use `dict.get()` to return `city` from a record or `'Unknown'` if missing.
#
# **Input format:** `record: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# record = {'name': 'Asha'}
# ```
#
# **Sample Output:**
# ```python
# 'Unknown'
# ```
#
# **Constraints:** Use a safe default.

# %%
def missing_field_safe_read(record: dict) -> str:
    pass

# %% [markdown]
# ## Q9. Payload Build
#
# **Problem description:** Return a JSON-style payload dictionary for creating a task with `title` and `completed` keys.
#
# **Input format:** `title: str`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# title = 'Learn APIs'
# ```
#
# **Sample Output:**
# ```python
# {'title': 'Learn APIs', 'completed': False}
# ```
#
# **Constraints:** Set `completed` to False.

# %%
def payload_build(title: str) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q10. No Content Check
#
# **Problem description:** Return True if a status code is `204`, otherwise False.
#
# **Input format:** `status_code: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# status_code = 204
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Use exact status-code comparison.

# %%
def no_content_check(status_code: int) -> bool:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Pagination Summary
#
# **Problem description:** Given `page`, `per_page`, and `total`, return a pagination dictionary.
#
# **Input format:** `page: int, per_page: int, total: int`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# page = 1, per_page = 20, total = 95
# ```
#
# **Sample Output:**
# ```python
# {'page': 1, 'per_page': 20, 'total': 95}
# ```
#
# **Constraints:** Return all three values.

# %%
def pagination_summary(page: int, per_page: int, total: int) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q12. Filter Success Responses
#
# **Problem description:** Given a list of response dictionaries with `status_code`, return only those in the 200 range.
#
# **Input format:** `responses: list[dict]`
#
# **Output format:** `list[dict]`
#
# **Sample Input:**
# ```python
# responses = [{'status_code': 200}, {'status_code': 404}, {'status_code': 201}]
# ```
#
# **Sample Output:**
# ```python
# [{'status_code': 200}, {'status_code': 201}]
# ```
#
# **Constraints:** Preserve original order.

# %%
def filter_success_responses(responses: list[dict]) -> list[dict]:
    pass

# %% [markdown]
# ## Q13. Extract Nested User Names
#
# **Problem description:** Given API JSON like `{'users': [{'name': ...}, ...]}`, return the list of names.
#
# **Input format:** `data: dict`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# data = {'users': [{'name': 'Asha'}, {'name': 'Ravi'}]}
# ```
#
# **Sample Output:**
# ```python
# ['Asha', 'Ravi']
# ```
#
# **Constraints:** Assume the structure exists.

# %%
def extract_nested_user_names(data: dict) -> list[str]:
    pass

# %% [markdown]
# ## Q14. Status Code Group Label
#
# **Problem description:** Return `'client error'` for 400-range codes, `'server error'` for 500-range codes, and `'other'` otherwise.
#
# **Input format:** `status_code: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# status_code = 404
# ```
#
# **Sample Output:**
# ```python
# 'client error'
# ```
#
# **Constraints:** Use integer comparisons.

# %%
def status_code_group_label(status_code: int) -> str:
    pass

# %% [markdown]
# ## Q15. Build Auth Header
#
# **Problem description:** Return an Authorization header dictionary for a bearer token.
#
# **Input format:** `token: str`
#
# **Output format:** `dict[str, str]`
#
# **Sample Input:**
# ```python
# token = 'abc123'
# ```
#
# **Sample Output:**
# ```python
# {'Authorization': 'Bearer abc123'}
# ```
#
# **Constraints:** Use the Bearer format exactly.

# %%
def build_auth_header(token: str) -> dict[str, str]:
    pass

# %% [markdown]
# ## Q16. Extract First User City
#
# **Problem description:** Given parsed JSON with a `users` list, return the first user's city or `'Unknown'` if missing.
#
# **Input format:** `data: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# data = {'users': [{'name': 'Asha', 'city': 'Pune'}]}
# ```
#
# **Sample Output:**
# ```python
# 'Pune'
# ```
#
# **Constraints:** Use safe reads when possible.

# %%
def extract_first_user_city(data: dict) -> str:
    pass

# %% [markdown]
# ## Q17. Request Config Builder
#
# **Problem description:** Return a dictionary containing `url`, `params`, and `headers` for a simple API request.
#
# **Input format:** `url: str, page: int`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# url = 'https://api.example.com/users', page = 1
# ```
#
# **Sample Output:**
# ```python
# {'url': 'https://api.example.com/users', 'params': {'page': 1}, 'headers': {'Accept': 'application/json'}}
# ```
#
# **Constraints:** Use Accept JSON header.

# %%
def request_config_builder(url: str, page: int) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q18. Count Error Responses
#
# **Problem description:** Count how many response dictionaries have status codes 400 or higher.
#
# **Input format:** `responses: list[dict]`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# responses = [{'status_code': 200}, {'status_code': 404}, {'status_code': 500}]
# ```
#
# **Sample Output:**
# ```python
# 2
# ```
#
# **Constraints:** Every dictionary has a `status_code` key.

# %%
def count_error_responses(responses: list[dict]) -> int:
    pass

# %% [markdown]
# ## Q19. Normalize User Records
#
# **Problem description:** Convert API user dictionaries into a list of simplified dictionaries containing only `name` and `city`, defaulting city to `'Unknown'`.
#
# **Input format:** `users: list[dict]`
#
# **Output format:** `list[dict[str, str]]`
#
# **Sample Input:**
# ```python
# users = [{'name': 'Asha'}, {'name': 'Ravi', 'city': 'Delhi'}]
# ```
#
# **Sample Output:**
# ```python
# [{'name': 'Asha', 'city': 'Unknown'}, {'name': 'Ravi', 'city': 'Delhi'}]
# ```
#
# **Constraints:** Preserve original order.

# %%
def normalize_user_records(users: list[dict]) -> list[dict[str, str]]:
    pass

# %% [markdown]
# ## Q20. Check Retry Worthy
#
# **Problem description:** Return True if a status code is one of 429, 500, 502, 503, or 504.
#
# **Input format:** `status_code: int`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# status_code = 503
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Use a membership check.

# %%
def check_retry_worthy(status_code: int) -> bool:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Response Summary Builder
#
# **Problem description:** Given a response dictionary with `status_code` and `data`, return a summary dictionary with keys `ok`, `status_code`, and `item_count`.
#
# **Input format:** `response: dict`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# response = {'status_code': 200, 'data': [1, 2, 3]}
# ```
#
# **Sample Output:**
# ```python
# {'ok': True, 'status_code': 200, 'item_count': 3}
# ```
#
# **Constraints:** Treat 200-range codes as ok.

# %%
def response_summary_builder(response: dict) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q22. Paginated Name Extractor
#
# **Problem description:** Given a list of page dictionaries each containing `users`, return one flat list of all user names.
#
# **Input format:** `pages: list[dict]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# pages = [{'users': [{'name': 'A'}]}, {'users': [{'name': 'B'}, {'name': 'C'}]}]
# ```
#
# **Sample Output:**
# ```python
# ['A', 'B', 'C']
# ```
#
# **Constraints:** Preserve page order and user order.

# %%
def paginated_name_extractor(pages: list[dict]) -> list[str]:
    pass

# %% [markdown]
# ## Q23. Error Message Builder
#
# **Problem description:** Given a response dictionary with `status_code` and optional `error`, return a formatted error message string like `404: Not Found`.
#
# **Input format:** `response: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# response = {'status_code': 404, 'error': 'Not Found'}
# ```
#
# **Sample Output:**
# ```python
# '404: Not Found'
# ```
#
# **Constraints:** Use `'Unknown error'` when `error` is missing.

# %%
def error_message_builder(response: dict) -> str:
    pass

# %% [markdown]
# ## Q24. Merge Default And User Headers
#
# **Problem description:** Merge default headers and user headers into one dictionary where user headers override defaults.
#
# **Input format:** `defaults: dict, custom: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# defaults = {'Accept': 'application/json'}, custom = {'Authorization': 'Bearer x'}
# ```
#
# **Sample Output:**
# ```python
# {'Accept': 'application/json', 'Authorization': 'Bearer x'}
# ```
#
# **Constraints:** Use dictionary merging or update logic.

# %%
def merge_default_and_user_headers(defaults: dict, custom: dict) -> dict:
    pass

# %% [markdown]
# ## Q25. Extract Unique Cities
#
# **Problem description:** Given API user dictionaries, return a sorted list of unique city names, using `'Unknown'` for missing cities.
#
# **Input format:** `users: list[dict]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# users = [{'name': 'Asha'}, {'name': 'Ravi', 'city': 'Delhi'}, {'name': 'Mia', 'city': 'Delhi'}]
# ```
#
# **Sample Output:**
# ```python
# ['Delhi', 'Unknown']
# ```
#
# **Constraints:** Return sorted unique values.

# %%
def extract_unique_cities(users: list[dict]) -> list[str]:
    pass

# %% [markdown]
# ## Q26. Validate Api Response Shape
#
# **Problem description:** Return True only if a response dictionary has keys `status_code` and `data`.
#
# **Input format:** `response: dict`
#
# **Output format:** `bool`
#
# **Sample Input:**
# ```python
# response = {'status_code': 200, 'data': []}
# ```
#
# **Sample Output:**
# ```python
# True
# ```
#
# **Constraints:** Both keys must exist.

# %%
def validate_api_response_shape(response: dict) -> bool:
    pass

# %% [markdown]
# ## Q27. Build Patch Payload
#
# **Problem description:** Given optional `name` and `city` values, build a PATCH payload dictionary containing only non-None fields.
#
# **Input format:** `name: str | None, city: str | None`
#
# **Output format:** `dict[str, str]`
#
# **Sample Input:**
# ```python
# name = 'Asha', city = None
# ```
#
# **Sample Output:**
# ```python
# {'name': 'Asha'}
# ```
#
# **Constraints:** Exclude fields whose value is None.

# %%
def build_patch_payload(name: str | None, city: str | None) -> dict[str, str]:
    pass

# %% [markdown]
# ## Q28. Rate Limit Message
#
# **Problem description:** Given a headers dictionary containing `X-RateLimit-Remaining`, return a formatted string like `Remaining: 5`.
#
# **Input format:** `headers: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# headers = {'X-RateLimit-Remaining': '5'}
# ```
#
# **Sample Output:**
# ```python
# 'Remaining: 5'
# ```
#
# **Constraints:** Use `'Remaining: Unknown'` if the header is missing.

# %%
def rate_limit_message(headers: dict) -> str:
    pass

# %% [markdown]
# ## Q29. Api Result Grouping
#
# **Problem description:** Given a list of API result dictionaries with `status_code`, return a dictionary counting `success`, `client_error`, and `server_error` groups.
#
# **Input format:** `responses: list[dict]`
#
# **Output format:** `dict[str, int]`
#
# **Sample Input:**
# ```python
# responses = [{'status_code': 200}, {'status_code': 404}, {'status_code': 500}, {'status_code': 201}]
# ```
#
# **Sample Output:**
# ```python
# {'success': 2, 'client_error': 1, 'server_error': 1}
# ```
#
# **Constraints:** Ignore other status-code groups.

# %%
def api_result_grouping(responses: list[dict]) -> dict[str, int]:
    pass

# %% [markdown]
# ## Q30. Transform Todo Records
#
# **Problem description:** Given todo dictionaries from an API, return a list of strings like `title [done]` or `title [pending]` based on the boolean `completed` field.
#
# **Input format:** `todos: list[dict]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# todos = [{'title': 'Learn APIs', 'completed': False}, {'title': 'Practice', 'completed': True}]
# ```
#
# **Sample Output:**
# ```python
# ['Learn APIs [pending]', 'Practice [done]']
# ```
#
# **Constraints:** Assume both keys exist.

# %%
def transform_todo_records(todos: list[dict]) -> list[str]:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. Api User Summary
#
# **Problem description:** Given parsed API JSON with a `users` list, return a summary string like `2 users: Asha, Ravi`.
#
# **Input format:** `data: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# data = {'users': [{'name': 'Asha'}, {'name': 'Ravi'}]}
# ```
#
# **Sample Output:**
# ```python
# '2 users: Asha, Ravi'
# ```
#
# **Constraints:** Assume every user has a name.

# %%
def api_user_summary(data: dict) -> str:
    pass

# %% [markdown]
# ## Q32. Search Request Builder
#
# **Problem description:** Build a request configuration dictionary for a search API including URL, query parameters, and JSON accept header.
#
# **Input format:** `base_url: str, query: str, page: int`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# base_url = 'https://api.example.com/search', query = 'python', page = 1
# ```
#
# **Sample Output:**
# ```python
# {'url': 'https://api.example.com/search', 'params': {'q': 'python', 'page': 1}, 'headers': {'Accept': 'application/json'}}
# ```
#
# **Constraints:** Use `q` as the query parameter name.

# %%
def search_request_builder(base_url: str, query: str, page: int) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q33. Safe Product Extractor
#
# **Problem description:** Given API JSON with optional `products`, return a list of product names safely, or an empty list if the key is missing.
#
# **Input format:** `data: dict`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# data = {'products': [{'name': 'Book'}, {'name': 'Pen'}]}
# ```
#
# **Sample Output:**
# ```python
# ['Book', 'Pen']
# ```
#
# **Constraints:** Use safe access patterns.

# %%
def safe_product_extractor(data: dict) -> list[str]:
    pass

# %% [markdown]
# ## Q34. Webhook Event Formatter
#
# **Problem description:** Given a webhook event dictionary with `type` and `id`, return a formatted string like `order.created -> 101`.
#
# **Input format:** `event: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# event = {'type': 'order.created', 'id': 101}
# ```
#
# **Sample Output:**
# ```python
# 'order.created -> 101'
# ```
#
# **Constraints:** Assume both keys exist.

# %%
def webhook_event_formatter(event: dict) -> str:
    pass

# %% [markdown]
# ## Q35. Simple Retry Queue
#
# **Problem description:** Given a list of failed response dictionaries, return the list of `id` values whose status codes are retry-worthy (429, 500, 502, 503, 504).
#
# **Input format:** `responses: list[dict]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# responses = [{'id': 1, 'status_code': 404}, {'id': 2, 'status_code': 503}, {'id': 3, 'status_code': 500}]
# ```
#
# **Sample Output:**
# ```python
# [2, 3]
# ```
#
# **Constraints:** Preserve original order.

# %%
def simple_retry_queue(responses: list[dict]) -> list[int]:
    pass
