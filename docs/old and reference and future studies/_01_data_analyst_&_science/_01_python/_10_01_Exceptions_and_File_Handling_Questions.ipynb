# %% [markdown]
# # Exceptions and File Handling with XLSX Questions
#
# This notebook contains structured practice questions from beginner to advanced level.
#
# No solutions are included in this notebook.

# %% [markdown]
# # Basic Questions

# %% [markdown]
# ### Q1. Convert String to Integer Safely
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that converts a string to an integer. Return `'Invalid'` if conversion fails.
#
# **Input format:**
# One string.
#
# **Output format:**
# An integer or the string `Invalid`.
#
# **Sample Input:**
# ```text
# 42
# ```
#
# **Sample Output:**
# ```text
# 42
# ```
#
# **Constraints:**
# Input may be numeric or non-numeric text.

# %%
def safe_int(text: str):
    pass

# %% [markdown]
# ### Q2. Handle Division by Zero
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that divides two numbers and returns `'Cannot divide by zero'` when the divisor is zero.
#
# **Input format:**
# Two integers.
#
# **Output format:**
# A float or a string.
#
# **Sample Input:**
# ```text
# 10 0
# ```
#
# **Sample Output:**
# ```text
# Cannot divide by zero
# ```
#
# **Constraints:**
# Divisor may be zero.

# %%
def safe_divide(a: int, b: int):
    pass

# %% [markdown]
# ### Q3. Open Missing File Safely
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that tries to read a file and returns `'File not found'` if the file does not exist.
#
# **Input format:**
# One file name string.
#
# **Output format:**
# File text or an error string.
#
# **Sample Input:**
# ```text
# missing.txt
# ```
#
# **Sample Output:**
# ```text
# File not found
# ```
#
# **Constraints:**
# The file may not exist.

# %%
def read_file_safely(file_name: str):
    pass

# %% [markdown]
# ### Q4. Write One Line to File
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that creates a text file and writes one line into it.
#
# **Input format:**
# One file name and one string.
#
# **Output format:**
# The written file content.
#
# **Sample Input:**
# ```text
# demo.txt and Hello
# ```
#
# **Sample Output:**
# ```text
# Hello
# ```
#
# **Constraints:**
# Use UTF-8 encoding.

# %%
def write_one_line(file_name: str, text: str) -> str:
    pass

# %% [markdown]
# ### Q5. Read All File Content
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that reads all text from a file and returns it.
#
# **Input format:**
# One existing file name.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# sample.txt
# ```
#
# **Sample Output:**
# ```text
# entire file content
# ```
#
# **Constraints:**
# Assume the file exists in the sample.

# %%
def read_all_text(file_name: str) -> str:
    pass

# %% [markdown]
# ### Q6. Append Text to File
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that appends one line to an existing file and returns the final file content.
#
# **Input format:**
# One file name and one string.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# log.txt and second line
# ```
#
# **Sample Output:**
# ```text
# first line\nsecond line
# ```
#
# **Constraints:**
# Use append mode.

# %%
def append_text(file_name: str, text: str) -> str:
    pass

# %% [markdown]
# ### Q7. Check ValueError with Float
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that converts a string to float and returns `0.0` if conversion fails.
#
# **Input format:**
# One string.
#
# **Output format:**
# A float.
#
# **Sample Input:**
# ```text
# bad
# ```
#
# **Sample Output:**
# ```text
# 0.0
# ```
#
# **Constraints:**
# Input may not be numeric.

# %%
def safe_float(text: str) -> float:
    pass

# %% [markdown]
# ### Q8. Count Lines in File
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that returns how many lines are present in a text file.
#
# **Input format:**
# One file name.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# notes.txt
# ```
#
# **Sample Output:**
# ```text
# 3
# ```
#
# **Constraints:**
# Assume the file exists in the sample.

# %%
def count_lines(file_name: str) -> int:
    pass

# %% [markdown]
# ### Q9. Return Finally Message
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that returns `'done'` from a `finally` block after attempting a conversion.
#
# **Input format:**
# One string.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# abc
# ```
#
# **Sample Output:**
# ```text
# done
# ```
#
# **Constraints:**
# Use `try`, `except`, and `finally`.

# %%
def finally_demo(text: str) -> str:
    pass

# %% [markdown]
# ### Q10. Raise Negative Age Error
#
# **Level:** Basic
#
# **Problem description:**
# Write a function that raises `ValueError` when age is negative, otherwise returns the age.
#
# **Input format:**
# One integer age.
#
# **Output format:**
# One integer or an exception.
#
# **Sample Input:**
# ```text
# -5
# ```
#
# **Sample Output:**
# ```text
# ValueError
# ```
#
# **Constraints:**
# Age can be negative in bad input.

# %%
def validate_age(age: int) -> int:
    pass

# %% [markdown]
# # Intermediate Questions

# %% [markdown]
# ### Q11. Read Integers and Sum
#
# **Level:** Intermediate
#
# **Problem description:**
# Read a file containing one value per line, ignore invalid lines, and return the sum of valid integers.
#
# **Input format:**
# One file name.
#
# **Output format:**
# One integer.
#
# **Sample Input:**
# ```text
# numbers.txt
# ```
#
# **Sample Output:**
# ```text
# 60
# ```
#
# **Constraints:**
# Some lines may be invalid.

# %%
def sum_valid_integers(file_name: str) -> int:
    pass

# %% [markdown]
# ### Q12. Custom Exception for Salary
#
# **Level:** Intermediate
#
# **Problem description:**
# Create a custom exception and use it to reject negative salary values.
#
# **Input format:**
# One integer salary.
#
# **Output format:**
# One integer or a custom exception.
#
# **Sample Input:**
# ```text
# -1000
# ```
#
# **Sample Output:**
# ```text
# InvalidSalaryError
# ```
#
# **Constraints:**
# Salary must be non-negative.

# %%
class InvalidSalaryError(Exception):
    pass

def set_salary(amount: int) -> int:
    pass

# %% [markdown]
# ### Q13. Context Manager Read First Line
#
# **Level:** Intermediate
#
# **Problem description:**
# Use a context manager to read and return only the first line of a file.
#
# **Input format:**
# One file name.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# demo.txt
# ```
#
# **Sample Output:**
# ```text
# first line
# ```
#
# **Constraints:**
# Assume the file exists.

# %%
def read_first_line(file_name: str) -> str:
    pass

# %% [markdown]
# ### Q14. Copy File Content
#
# **Level:** Intermediate
#
# **Problem description:**
# Read text from one file and write the same text into another file.
#
# **Input format:**
# Two file names.
#
# **Output format:**
# The copied text.
#
# **Sample Input:**
# ```text
# source.txt target.txt
# ```
#
# **Sample Output:**
# ```text
# same as source content
# ```
#
# **Constraints:**
# Use UTF-8 encoding.

# %%
def copy_text_file(source_name: str, target_name: str) -> str:
    pass

# %% [markdown]
# ### Q15. Parse CSV-Like Line
#
# **Level:** Intermediate
#
# **Problem description:**
# Given a comma-separated string, split it, strip spaces, and return the cleaned list.
#
# **Input format:**
# One string line.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# apple, banana , orange
# ```
#
# **Sample Output:**
# ```text
# ['apple', 'banana', 'orange']
# ```
#
# **Constraints:**
# The line may contain extra spaces.

# %%
def parse_csv_like_line(line: str) -> list[str]:
    pass

# %% [markdown]
# ### Q16. Safe Dictionary Key Access
#
# **Level:** Intermediate
#
# **Problem description:**
# Return the value for a key in a dictionary, or `'Missing'` if the key is absent.
#
# **Input format:**
# One dictionary and one key.
#
# **Output format:**
# A value or a string.
#
# **Sample Input:**
# ```text
# {'a': 1} and 'b'
# ```
#
# **Sample Output:**
# ```text
# Missing
# ```
#
# **Constraints:**
# The key may not exist.

# %%
def safe_key_lookup(data: dict, key):
    pass

# %% [markdown]
# ### Q17. Log Errors to File
#
# **Level:** Intermediate
#
# **Problem description:**
# Write a function that catches an error and appends the error message to a log file.
#
# **Input format:**
# One bad input and one log file name.
#
# **Output format:**
# Logged file content.
#
# **Sample Input:**
# ```text
# abc and errors.txt
# ```
#
# **Sample Output:**
# ```text
# invalid literal...
# ```
#
# **Constraints:**
# Use append mode.

# %%
def log_conversion_error(text: str, log_file: str) -> str:
    pass

# %% [markdown]
# ### Q18. Simulate XLSX Rows Cleanup
#
# **Level:** Intermediate
#
# **Problem description:**
# Given spreadsheet-like row dictionaries with string numbers, convert valid values and skip bad rows.
#
# **Input format:**
# A list of dictionaries.
#
# **Output format:**
# A cleaned list of dictionaries.
#
# **Sample Input:**
# ```text
# [{'name': 'A', 'sales': '10'}, {'name': 'B', 'sales': 'bad'}]
# ```
#
# **Sample Output:**
# ```text
# [{'name': 'A', 'sales': 10}]
# ```
#
# **Constraints:**
# Each row has `name` and `sales`.

# %%
def clean_sales_rows(rows: list[dict]) -> list[dict]:
    pass

# %% [markdown]
# ### Q19. Readlines and Strip
#
# **Level:** Intermediate
#
# **Problem description:**
# Return all non-empty stripped lines from a file.
#
# **Input format:**
# One file name.
#
# **Output format:**
# A list of strings.
#
# **Sample Input:**
# ```text
# items.txt
# ```
#
# **Sample Output:**
# ```text
# ['apple', 'banana']
# ```
#
# **Constraints:**
# Some lines may be blank.

# %%
def stripped_non_empty_lines(file_name: str) -> list[str]:
    pass

# %% [markdown]
# ### Q20. Safe Delete Simulation
#
# **Level:** Intermediate
#
# **Problem description:**
# Given a file name, return `'Deleted'` if it exists and is removed, otherwise `'File not found'`.
#
# **Input format:**
# One file name.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# temp.txt
# ```
#
# **Sample Output:**
# ```text
# Deleted
# ```
#
# **Constraints:**
# Use file existence checks.

# %%
def safe_delete(file_name: str) -> str:
    pass

# %% [markdown]
# # Advanced Questions

# %% [markdown]
# ### Q21. Retry Conversion with Fallback
#
# **Level:** Advanced
#
# **Problem description:**
# Try to convert a list of strings to integers. If one fails, use a fallback integer instead.
#
# **Input format:**
# A list of strings and one fallback integer.
#
# **Output format:**
# A list of integers.
#
# **Sample Input:**
# ```text
# ['10', 'x', '20'] and 0
# ```
#
# **Sample Output:**
# ```text
# [10, 0, 20]
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def convert_with_fallback(values: list[str], fallback: int) -> list[int]:
    pass

# %% [markdown]
# ### Q22. Mini File Statistics
#
# **Level:** Advanced
#
# **Problem description:**
# Return a dictionary with line count, word count, and character count for a text file.
#
# **Input format:**
# One file name.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# report.txt
# ```
#
# **Sample Output:**
# ```text
# {'lines': 3, 'words': 8, 'characters': 42}
# ```
#
# **Constraints:**
# Assume the file exists.

# %%
def file_statistics(file_name: str) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q23. Custom Context Manager
#
# **Level:** Advanced
#
# **Problem description:**
# Create a class-based context manager that writes entering and exiting messages to a log file.
#
# **Input format:**
# One log file name.
#
# **Output format:**
# Final log file content.
#
# **Sample Input:**
# ```text
# session.txt
# ```
#
# **Sample Output:**
# ```text
# Entering\nExiting
# ```
#
# **Constraints:**
# Use `__enter__` and `__exit__`.

# %%
class FileSession:
    pass

# %% [markdown]
# ### Q24. Nested Data Extraction
#
# **Level:** Advanced
#
# **Problem description:**
# Given nested dictionaries that simulate parsed spreadsheet or JSON data, safely extract a deeply nested value or return `'Missing'`.
#
# **Input format:**
# One nested dictionary.
#
# **Output format:**
# One value or a string.
#
# **Sample Input:**
# ```text
# {'report': {'sheet': {'sales': 100}}}
# ```
#
# **Sample Output:**
# ```text
# 100
# ```
#
# **Constraints:**
# Keys may be missing at any level.

# %%
def nested_extract(data: dict):
    pass

# %% [markdown]
# ### Q25. Batch File Merger
#
# **Level:** Advanced
#
# **Problem description:**
# Read multiple text files and merge their content into one output file.
#
# **Input format:**
# A list of input file names and one output file name.
#
# **Output format:**
# Merged file content.
#
# **Sample Input:**
# ```text
# ['a.txt', 'b.txt'] and out.txt
# ```
#
# **Sample Output:**
# ```text
# content of a + content of b
# ```
#
# **Constraints:**
# All sample files exist.

# %%
def merge_files(input_files: list[str], output_file: str) -> str:
    pass

# %% [markdown]
# ### Q26. Exception Summary Report
#
# **Level:** Advanced
#
# **Problem description:**
# Process several inputs, count how many conversions succeeded and failed, and return a summary dictionary.
#
# **Input format:**
# A list of strings.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# ['10', 'x', '20', 'bad']
# ```
#
# **Sample Output:**
# ```text
# {'success': 2, 'failed': 2}
# ```
#
# **Constraints:**
# List length is between 0 and 1000.

# %%
def conversion_summary(values: list[str]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q27. Spreadsheet Column Total
#
# **Level:** Advanced
#
# **Problem description:**
# Given spreadsheet-like rows, return the total of one named numeric column while skipping invalid entries.
#
# **Input format:**
# A list of dictionaries and one column name.
#
# **Output format:**
# One integer total.
#
# **Sample Input:**
# ```text
# [{'sales': '10'}, {'sales': 'bad'}, {'sales': '25'}] and sales
# ```
#
# **Sample Output:**
# ```text
# 35
# ```
#
# **Constraints:**
# The column may be missing or invalid in some rows.

# %%
def column_total(rows: list[dict], column: str) -> int:
    pass

# %% [markdown]
# ### Q28. Write JSON Report
#
# **Level:** Advanced
#
# **Problem description:**
# Create a JSON file from a dictionary and then read it back into Python.
#
# **Input format:**
# One file name and one dictionary.
#
# **Output format:**
# One dictionary.
#
# **Sample Input:**
# ```text
# report.json and {'total': 50}
# ```
#
# **Sample Output:**
# ```text
# {'total': 50}
# ```
#
# **Constraints:**
# Use the json module.

# %%
def write_and_read_json(file_name: str, data: dict) -> dict:
    pass

# %% [markdown]
# ### Q29. Graceful HTML Tag Finder
#
# **Level:** Advanced
#
# **Problem description:**
# Given HTML text, return the text between `<h1>` tags if present, otherwise return `'Not found'`.
#
# **Input format:**
# One HTML string.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# <h1>Python</h1>
# ```
#
# **Sample Output:**
# ```text
# Python
# ```
#
# **Constraints:**
# The tag may be missing.

# %%
def find_h1_text(html: str) -> str:
    pass

# %% [markdown]
# ### Q30. Raise on Empty File
#
# **Level:** Advanced
#
# **Problem description:**
# Read a file and raise `ValueError` if it is empty after stripping whitespace.
#
# **Input format:**
# One file name.
#
# **Output format:**
# File content or an exception.
#
# **Sample Input:**
# ```text
# empty.txt
# ```
#
# **Sample Output:**
# ```text
# ValueError
# ```
#
# **Constraints:**
# The file may contain only spaces or newlines.

# %%
def require_non_empty_file(file_name: str) -> str:
    pass

# %% [markdown]
# # Real-world Problems

# %% [markdown]
# ### Q31. Expense Report Cleaner
#
# **Level:** Real-world
#
# **Problem description:**
# Read expense values from a file, skip invalid lines, and write a summary report with total and skipped count.
#
# **Input format:**
# An input file name and an output file name.
#
# **Output format:**
# Summary file content.
#
# **Sample Input:**
# ```text
# expenses.txt and summary.txt
# ```
#
# **Sample Output:**
# ```text
# Total: ...\nSkipped: ...
# ```
#
# **Constraints:**
# Some lines may be invalid.

# %%
def expense_report_cleaner(input_file: str, output_file: str) -> str:
    pass

# %% [markdown]
# ### Q32. User Signup Validator
#
# **Level:** Real-world
#
# **Problem description:**
# Validate username, age, and email; raise clear errors for bad values and return a success dictionary for valid input.
#
# **Input format:**
# One username, one age, and one email.
#
# **Output format:**
# A dictionary or an exception.
#
# **Sample Input:**
# ```text
# Asha 21 a@example.com
# ```
#
# **Sample Output:**
# ```text
# {'username': 'Asha', 'age': 21, 'email': 'a@example.com'}
# ```
#
# **Constraints:**
# Username is non-empty, age non-negative, email must contain `@`.

# %%
def validate_signup(username: str, age: int, email: str) -> dict:
    pass

# %% [markdown]
# ### Q33. Spreadsheet Sales Summary
#
# **Level:** Real-world
#
# **Problem description:**
# Given rows from a spreadsheet, clean numeric sales values and return total sales plus valid row count.
#
# **Input format:**
# A list of row dictionaries.
#
# **Output format:**
# A dictionary.
#
# **Sample Input:**
# ```text
# [{'sales': '100'}, {'sales': 'bad'}, {'sales': '50'}]
# ```
#
# **Sample Output:**
# ```text
# {'total': 150, 'valid_rows': 2}
# ```
#
# **Constraints:**
# Some rows may be invalid.

# %%
def spreadsheet_sales_summary(rows: list[dict]) -> dict[str, int]:
    pass

# %% [markdown]
# ### Q34. Log Parsing Tool
#
# **Level:** Real-world
#
# **Problem description:**
# Read a log file, count lines containing `ERROR`, and write a short error summary file.
#
# **Input format:**
# One input log file and one output file.
#
# **Output format:**
# Summary file content.
#
# **Sample Input:**
# ```text
# app.log and error_summary.txt
# ```
#
# **Sample Output:**
# ```text
# ERROR count: 3
# ```
#
# **Constraints:**
# Input file exists in the sample.

# %%
def log_parsing_tool(log_file: str, summary_file: str) -> str:
    pass

# %% [markdown]
# ### Q35. Article Exporter
#
# **Level:** Real-world
#
# **Problem description:**
# Given article dictionaries with `title` and `url`, write them to a text file in `title - url` format and return the file content.
#
# **Input format:**
# A list of dictionaries and one output file.
#
# **Output format:**
# One string.
#
# **Sample Input:**
# ```text
# [{'title': 'Python', 'url': 'https://example.com'}] and articles.txt
# ```
#
# **Sample Output:**
# ```text
# Python - https://example.com
# ```
#
# **Constraints:**
# Every dictionary contains `title` and `url`.

# %%
def export_articles(articles: list[dict], output_file: str) -> str:
    pass
