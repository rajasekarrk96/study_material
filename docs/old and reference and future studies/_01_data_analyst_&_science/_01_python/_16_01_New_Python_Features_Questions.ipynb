# %% [markdown]
# # Python New Python Features Questions
#
# No solutions here. Solve first, then open the answers notebook.

# %% [markdown]
# # Section 1: Basic Questions

# %% [markdown]
# ## Q1. F String Greeting
#
# **Problem description:** Use an f-string to return `Hello, <name>`.
#
# **Input format:** `name: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Asha'
# ```
#
# **Sample Output:**
# ```python
# 'Hello, Asha'
# ```
#
# **Constraints:** The input is a non-empty string.

# %%
def f_string_greeting(name: str) -> str:
    pass

# %% [markdown]
# ## Q2. F String Expression
#
# **Problem description:** Use an f-string to return the square of a number inside a message string.
#
# **Input format:** `number: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# number = 4
# ```
#
# **Sample Output:**
# ```python
# 'Square is 16'
# ```
#
# **Constraints:** The number is an integer.

# %%
def f_string_expression(number: int) -> str:
    pass

# %% [markdown]
# ## Q3. Numeric Underscore Value
#
# **Problem description:** Store a number using underscore separators and return its integer value.
#
# **Input format:** `unused: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# 1000000
# ```
#
# **Constraints:** Return the numeric value only.

# %%
def numeric_underscore_value(unused: int) -> int:
    pass

# %% [markdown]
# ## Q4. Extended Unpack Middle
#
# **Problem description:** Use extended iterable unpacking to return the middle values of a list.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3, 4, 5]
# ```
#
# **Sample Output:**
# ```python
# [2, 3, 4]
# ```
#
# **Constraints:** The list has at least three items.

# %%
def extended_unpack_middle(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q5. Dictionary Merge
#
# **Problem description:** Use the dictionary merge operator `|` to combine two dictionaries and return the result.
#
# **Input format:** `a: dict, b: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# a = {'x': 1}, b = {'y': 2}
# ```
#
# **Sample Output:**
# ```python
# {'x': 1, 'y': 2}
# ```
#
# **Constraints:** Later keys override earlier ones.

# %%
def dictionary_merge(a: dict, b: dict) -> dict:
    pass

# %% [markdown]
# ## Q6. Walrus Length Check
#
# **Problem description:** Use the walrus operator to assign the length of a string and return that length when it is greater than 3, otherwise return 0.
#
# **Input format:** `text: str`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# text = 'python'
# ```
#
# **Sample Output:**
# ```python
# 6
# ```
#
# **Constraints:** The text may be empty.

# %%
def walrus_length_check(text: str) -> int:
    pass

# %% [markdown]
# ## Q7. Typed Add Function
#
# **Problem description:** Write a function with type hints that adds two integers and returns the result.
#
# **Input format:** `a: int, b: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# a = 2, b = 5
# ```
#
# **Sample Output:**
# ```python
# 7
# ```
#
# **Constraints:** Both inputs are integers.

# %%
def typed_add_function(a: int, b: int) -> int:
    pass

# %% [markdown]
# ## Q8. Union Type Describe
#
# **Problem description:** Use a function annotated with `int | str` and return `Value: <input>`.
#
# **Input format:** `value: int | str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# value = 'python'
# ```
#
# **Sample Output:**
# ```python
# 'Value: python'
# ```
#
# **Constraints:** The input is either an integer or a string.

# %%
def union_type_describe(value: int | str) -> str:
    pass

# %% [markdown]
# ## Q9. Dataclass Create
#
# **Problem description:** Create a dataclass `Student` with `name` and `score`, build one object, and return the score.
#
# **Input format:** `name: str, score: int`
#
# **Output format:** `int`
#
# **Sample Input:**
# ```python
# name = 'Asha', score = 95
# ```
#
# **Sample Output:**
# ```python
# 95
# ```
#
# **Constraints:** Return the numeric score field.

# %%
def dataclass_create(name: str, score: int) -> int:
    pass

# %% [markdown]
# ## Q10. Pathlib Join
#
# **Problem description:** Use `pathlib.Path` to join folder and file parts and return the resulting path string.
#
# **Input format:** `folder: str, filename: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# folder = 'reports', filename = 'a.txt'
# ```
#
# **Sample Output:**
# ```python
# 'reports\\a.txt' or platform equivalent
# ```
#
# **Constraints:** Use `Path(folder) / filename`.

# %%
def pathlib_join(folder: str, filename: str) -> str:
    pass

# %% [markdown]
# # Section 2: Intermediate Questions

# %% [markdown]
# ## Q11. Dataclass Default Status
#
# **Problem description:** Create a dataclass with a default `status='pending'` field and return that status for a new object.
#
# **Input format:** `title: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# title = 'Read notebook'
# ```
#
# **Sample Output:**
# ```python
# 'pending'
# ```
#
# **Constraints:** Use a default field value.

# %%
def dataclass_default_status(title: str) -> str:
    pass

# %% [markdown]
# ## Q12. Keyword Only Name
#
# **Problem description:** Define a function with keyword-only parameters `first` and `last` and return the full name.
#
# **Input format:** `first: str, last: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# first = 'Asha', last = 'Sharma'
# ```
#
# **Sample Output:**
# ```python
# 'Asha Sharma'
# ```
#
# **Constraints:** Call the function with keyword arguments.

# %%
def keyword_only_name(first: str, last: str) -> str:
    pass

# %% [markdown]
# ## Q13. Positional Only Divide
#
# **Problem description:** Define a function with positional-only parameters and return the division result.
#
# **Input format:** `a: int, b: int`
#
# **Output format:** `float`
#
# **Sample Input:**
# ```python
# a = 10, b = 2
# ```
#
# **Sample Output:**
# ```python
# 5.0
# ```
#
# **Constraints:** Use `/` in the function signature.

# %%
def positional_only_divide(a: int, b: int) -> float:
    pass

# %% [markdown]
# ## Q14. Match Command
#
# **Problem description:** Use structural pattern matching to return `'Starting'` for `'start'`, `'Stopping'` for `'stop'`, and `'Unknown'` otherwise.
#
# **Input format:** `command: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# command = 'start'
# ```
#
# **Sample Output:**
# ```python
# 'Starting'
# ```
#
# **Constraints:** Handle unmatched commands with `_`.

# %%
def match_command(command: str) -> str:
    pass

# %% [markdown]
# ## Q15. Match Tuple Event
#
# **Problem description:** Use pattern matching on a tuple like `('move', x, y)` and return `Move to x, y`.
#
# **Input format:** `event: tuple`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# event = ('move', 10, 20)
# ```
#
# **Sample Output:**
# ```python
# 'Move to 10, 20'
# ```
#
# **Constraints:** Return `'Unknown event'` for other patterns.

# %%
def match_tuple_event(event: tuple) -> str:
    pass

# %% [markdown]
# ## Q16. Zip Strict Pairs
#
# **Problem description:** Use `zip(strict=True)` to pair two equal-length lists and return the list of pairs.
#
# **Input format:** `names: list[str], scores: list[int]`
#
# **Output format:** `list[tuple[str, int]]`
#
# **Sample Input:**
# ```python
# names = ['A', 'B'], scores = [90, 80]
# ```
#
# **Sample Output:**
# ```python
# [('A', 90), ('B', 80)]
# ```
#
# **Constraints:** Assume equal lengths for this task.

# %%
def zip_strict_pairs(names: list[str], scores: list[int]) -> list[tuple[str, int]]:
    pass

# %% [markdown]
# ## Q17. Dataclass Mutable Default Safe
#
# **Problem description:** Use `field(default_factory=list)` in a dataclass and return the default empty list from a new object.
#
# **Input format:** `unused: int`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# unused = 0
# ```
#
# **Sample Output:**
# ```python
# []
# ```
#
# **Constraints:** Avoid shared mutable defaults.

# %%
def dataclass_mutable_default_safe(unused: int) -> list[str]:
    pass

# %% [markdown]
# ## Q18. Pathlib Suffix
#
# **Problem description:** Use `Path.suffix` to return the file extension of a path string.
#
# **Input format:** `path_text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# path_text = 'notes/report.txt'
# ```
#
# **Sample Output:**
# ```python
# '.txt'
# ```
#
# **Constraints:** The path points to a file.

# %%
def pathlib_suffix(path_text: str) -> str:
    pass

# %% [markdown]
# ## Q19. Dictionary Merge Override
#
# **Problem description:** Merge two dictionaries with overlapping keys using `|` and return the merged result.
#
# **Input format:** `a: dict, b: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# a = {'x': 1}, b = {'x': 5, 'y': 2}
# ```
#
# **Sample Output:**
# ```python
# {'x': 5, 'y': 2}
# ```
#
# **Constraints:** Keys from the right dictionary override left values.

# %%
def dictionary_merge_override(a: dict, b: dict) -> dict:
    pass

# %% [markdown]
# ## Q20. Walrus In Loop
#
# **Problem description:** Use the walrus operator in a loop-like pattern to collect lengths of non-empty words and return the list of lengths.
#
# **Input format:** `words: list[str]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# words = ['python', '', 'sql']
# ```
#
# **Sample Output:**
# ```python
# [6, 3]
# ```
#
# **Constraints:** Ignore empty strings.

# %%
def walrus_in_loop(words: list[str]) -> list[int]:
    pass

# %% [markdown]
# # Section 3: Advanced Questions

# %% [markdown]
# ## Q21. Dataclass Sort By Score
#
# **Problem description:** Use a dataclass to represent students, then return student names sorted by score descending.
#
# **Input format:** `records: list[tuple[str, int]]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# records = [('A', 80), ('B', 95), ('C', 88)]
# ```
#
# **Sample Output:**
# ```python
# ['B', 'C', 'A']
# ```
#
# **Constraints:** The list may be empty.

# %%
def dataclass_sort_by_score(records: list[tuple[str, int]]) -> list[str]:
    pass

# %% [markdown]
# ## Q22. Pattern Match Point
#
# **Problem description:** Use structural pattern matching on a dictionary like `{'type': 'point', 'x': 3, 'y': 4}` and return `Point(3, 4)`.
#
# **Input format:** `data: dict`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# data = {'type': 'point', 'x': 3, 'y': 4}
# ```
#
# **Sample Output:**
# ```python
# 'Point(3, 4)'
# ```
#
# **Constraints:** Return `'Unknown'` for other structures.

# %%
def pattern_match_point(data: dict) -> str:
    pass

# %% [markdown]
# ## Q23. Modern Type Hint Function
#
# **Problem description:** Write a function with the return type `list[int]` that returns squares of input integers.
#
# **Input format:** `items: list[int]`
#
# **Output format:** `list[int]`
#
# **Sample Input:**
# ```python
# items = [1, 2, 3]
# ```
#
# **Sample Output:**
# ```python
# [1, 4, 9]
# ```
#
# **Constraints:** The list may be empty.

# %%
def modern_type_hint_function(items: list[int]) -> list[int]:
    pass

# %% [markdown]
# ## Q24. Pathlib Read Write
#
# **Problem description:** Use `Path.write_text` and `Path.read_text` to save and read text from a local file, then return the read text.
#
# **Input format:** `text: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# text = 'hello'
# ```
#
# **Sample Output:**
# ```python
# 'hello'
# ```
#
# **Constraints:** Use a local file in the current folder.

# %%
def pathlib_read_write(text: str) -> str:
    pass

# %% [markdown]
# ## Q25. Match Role Access
#
# **Problem description:** Use pattern matching on a role string to return `'full'` for `'admin'`, `'limited'` for `'user'`, and `'none'` otherwise.
#
# **Input format:** `role: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# role = 'user'
# ```
#
# **Sample Output:**
# ```python
# 'limited'
# ```
#
# **Constraints:** Handle unmatched roles with `_`.

# %%
def match_role_access(role: str) -> str:
    pass

# %% [markdown]
# ## Q26. Dataclass As Dict Like Access
#
# **Problem description:** Create a dataclass with `name` and `age`, then return a normal dictionary using those values.
#
# **Input format:** `name: str, age: int`
#
# **Output format:** `dict[str, object]`
#
# **Sample Input:**
# ```python
# name = 'Asha', age = 22
# ```
#
# **Sample Output:**
# ```python
# {'name': 'Asha', 'age': 22}
# ```
#
# **Constraints:** Return a plain dictionary.

# %%
def dataclass_as_dict_like_access(name: str, age: int) -> dict[str, object]:
    pass

# %% [markdown]
# ## Q27. Union Type Safe Parse
#
# **Problem description:** Write a function annotated to return `int | None` that tries to parse a string to int and returns None on failure.
#
# **Input format:** `text: str`
#
# **Output format:** `int | None`
#
# **Sample Input:**
# ```python
# text = '42'
# ```
#
# **Sample Output:**
# ```python
# 42
# ```
#
# **Constraints:** Return None for invalid integers.

# %%
def union_type_safe_parse(text: str) -> int | None:
    pass

# %% [markdown]
# ## Q28. F String Table Row
#
# **Problem description:** Use an f-string with width formatting to return a row like `'Asha      | 95'`.
#
# **Input format:** `name: str, score: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Asha', score = 95
# ```
#
# **Sample Output:**
# ```python
# 'Asha      | 95'
# ```
#
# **Constraints:** Left-align the name in width 10.

# %%
def f_string_table_row(name: str, score: int) -> str:
    pass

# %% [markdown]
# ## Q29. Walrus Filter Values
#
# **Problem description:** Use the walrus operator to collect only strings whose stripped length is at least 3, and return the cleaned strings.
#
# **Input format:** `items: list[str]`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# items = ['  py ', ' a ', ' sql ']
# ```
#
# **Sample Output:**
# ```python
# ['py', 'sql']
# ```
#
# **Constraints:** Return stripped values only.

# %%
def walrus_filter_values(items: list[str]) -> list[str]:
    pass

# %% [markdown]
# ## Q30. Keyword Only Config
#
# **Problem description:** Define a function with keyword-only parameters `host` and `port` and return `host:port`.
#
# **Input format:** `host: str, port: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# host = 'localhost', port = 8000
# ```
#
# **Sample Output:**
# ```python
# 'localhost:8000'
# ```
#
# **Constraints:** Call with keyword arguments.

# %%
def keyword_only_config(host: str, port: int) -> str:
    pass

# %% [markdown]
# # Section 4: Real-world Problems

# %% [markdown]
# ## Q31. User Summary Dataclass
#
# **Problem description:** Create a dataclass for a user with `name` and `city`, then return a formatted summary string using an f-string.
#
# **Input format:** `name: str, city: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# name = 'Asha', city = 'Pune'
# ```
#
# **Sample Output:**
# ```python
# 'Asha lives in Pune'
# ```
#
# **Constraints:** Use a dataclass and an f-string.

# %%
def user_summary_dataclass(name: str, city: str) -> str:
    pass

# %% [markdown]
# ## Q32. Modern Report Path
#
# **Problem description:** Use `pathlib` to build a report path from folder, topic, and extension and return the path string.
#
# **Input format:** `folder: str, topic: str, extension: str`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# folder = 'reports', topic = 'python', extension = '.txt'
# ```
#
# **Sample Output:**
# ```python
# 'reports\\python.txt' or platform equivalent
# ```
#
# **Constraints:** Build the filename from topic + extension.

# %%
def modern_report_path(folder: str, topic: str, extension: str) -> str:
    pass

# %% [markdown]
# ## Q33. Pattern Match API Status
#
# **Problem description:** Use pattern matching on integer status codes to return `'success'` for 200, `'not found'` for 404, and `'error'` otherwise.
#
# **Input format:** `status: int`
#
# **Output format:** `str`
#
# **Sample Input:**
# ```python
# status = 404
# ```
#
# **Sample Output:**
# ```python
# 'not found'
# ```
#
# **Constraints:** Handle unmatched values with `_`.

# %%
def pattern_match_api_status(status: int) -> str:
    pass

# %% [markdown]
# ## Q34. Safe Settings Merge
#
# **Problem description:** Merge default settings and user settings with the modern dictionary merge operator and return the result.
#
# **Input format:** `defaults: dict, user: dict`
#
# **Output format:** `dict`
#
# **Sample Input:**
# ```python
# defaults = {'theme': 'light', 'font': 'medium'}, user = {'font': 'large'}
# ```
#
# **Sample Output:**
# ```python
# {'theme': 'light', 'font': 'large'}
# ```
#
# **Constraints:** User settings should override defaults.

# %%
def safe_settings_merge(defaults: dict, user: dict) -> dict:
    pass

# %% [markdown]
# ## Q35. Dataclass Task List
#
# **Problem description:** Create a dataclass task model with a safe default tags list, add one tag, and return the tags list.
#
# **Input format:** `title: str, tag: str`
#
# **Output format:** `list[str]`
#
# **Sample Input:**
# ```python
# title = 'Study', tag = 'python'
# ```
#
# **Sample Output:**
# ```python
# ['python']
# ```
#
# **Constraints:** Use `field(default_factory=list)`.

# %%
def dataclass_task_list(title: str, tag: str) -> list[str]:
    pass
