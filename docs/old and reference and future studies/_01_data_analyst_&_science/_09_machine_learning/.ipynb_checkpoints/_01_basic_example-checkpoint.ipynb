# %%
python and python libraies
import numpy
import pandas
from sklearn import datasets

# %%
from sklearn import datasets
_data=datasets.load_iris()
#print(_data)
X=_data.data[:,:2] 
x_count=len(X.flat)
x_min=X[:,0].min() - .5
x_max=X[:,0].min() + .5
x_mean=X[:,0].mean()
print(x_count,x_min,x_max,x_mean)
# Out:
# 300 3.8 4.8 5.843333333333334
