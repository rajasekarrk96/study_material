# %% [markdown]
# # Notebook Title
#
# Write the topic name here.

# %% [markdown]
# ## Learning Objectives
#
# - Objective 1
# - Objective 2
# - Objective 3

# %% [markdown]
# ## Core Concept Notes
#
# Write the main explanation in simple language first, then add more detail.

# %% [markdown]
# ## Key Terms
#
# - Term 1: definition
# - Term 2: definition
# - Term 3: definition

# %% [markdown]
# ## Example Prompts
#
# ### Basic Example
# ```text
# Write a simple example here.
# ```
#
# ### Better Example
# ```text
# Write an improved example here.
# ```

# %% [markdown]
# ## Good vs Bad Prompt Design
#
# Show one weak prompt and one stronger rewritten prompt.

# %% [markdown]
# ## Reusable Template
#
# ```text
# Role:
# Task:
# Context:
# Constraints:
# Output Format:
# ```

# %% [markdown]
# ## Practice Exercises
#
# 1. Exercise 1
# 2. Exercise 2
# 3. Exercise 3

# %% [markdown]
# ## Common Mistakes
#
# - Mistake 1
# - Mistake 2
# - Mistake 3

# %% [markdown]
# ## Summary
#
# Add a short recap of the notebook here.

# %%
# Optional practice cell
# Paste prompt experiments here.
